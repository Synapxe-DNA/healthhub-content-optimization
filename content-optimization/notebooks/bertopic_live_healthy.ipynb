# %%
# %load_ext kedro.ipython

# %%
import numpy as np
import pandas as pd
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from bertopic.representation import MaximalMarginalRelevance  # KeyBERTInspired
from bertopic.vectorizers import ClassTfidfTransformer
from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from umap import UMAP

# %%
df = catalog.load("merged_data")
content_category = "live-healthy-articles"
df = df.query(
    "content_category == @content_category"
).reset_index(drop=True)
df.head(2)
# Out:
# [09/13/24 16:42:37] INFO     Loading data from merged_data (ParquetDataset)...                  ]8;id=681015;file://c:\Users\Joycelyn\anaconda3\envs\genai-hh\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=838305;file://c:\Users\Joycelyn\anaconda3\envs\genai-hh\Lib\site-packages\kedro\io\data_catalog.py#508\508]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#         id                                       content_name  \
# 0  1444475                    Weight, BMI and Health Problems
# 1  1445137  7-month-baby Diet: An Authoritative Guide by O...
#
#                                                title article_category_names  \
# 0                    Weight, BMI and Health Problems    Food and Nutrition,
# 1  7-month-baby Diet: An Authoritative Guide by O...    Food and Nutrition,
#
#                                      cover_image_url  \
# 0  https://ch-api.healthhub.sg/api/public/content...
# 1  https://ch-api.healthhub.sg/api/public/content...
#
#                                             full_url  \
# 0  https://www.healthhub.sg/live-healthy/weight_p...
# 1  https://www.healthhub.sg/live-healthy/meal-ide...
#
#                                            full_url2  \
# 0  www.healthhub.sg/live-healthy/weight_putting_m...
# 1   www.healthhub.sg/live-healthy/meal-ideas-month-7
#
#                                    friendly_url  \
# 0  weight_putting_me_at_risk_of_health_problems
# 1                            meal-ideas-month-7
#
#                                 category_description  \
# 0  What’s your Body Mass Index (BMI)? Learn how t...
# 1  Your little one is now 7 months of age. Should...
#
#                                         content_body  ...  \
# 0  b'<div class="ExternalClassE93BEC3784C545A286B...  ...
# 1  b'<div class="ExternalClass46E64333542C4D8CBEA...  ...
#
#                               extracted_content_body             l1_mappings  \
# 0  What's a Healthy Body Mass Index?\nWe have all...  Well-being & Lifestyle
# 1  By Health Promotion Board in collaboration wit...  Well-being & Lifestyle
#
#                 l2_mappings page_views engagement_rate  bounce_rate  \
# 0  Food, Diet and Nutrition      41994        0.688354     0.311646
# 1  Food, Diet and Nutrition      38812        0.693181     0.306819
#
#    exit_rate  scroll_percentage percentage_total_views  \
# 0   0.491689           0.364433               0.018035
# 1   0.870324           0.381544               0.016669
#
#    cumulative_percentage_total_views
# 0                           0.018035
# 1                           0.034704
#
# [2 rows x 39 columns]

# %%
df = df.dropna(subset=["extracted_content_body"])
docs = df["extracted_content_body"].to_list()
doc_titles = df["title"].to_list()
len(docs)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 1153

# %% [markdown]
# ## Without hyperparameters tuning

# %%
# Step 1 - Extract embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Step 2 - Reduce dimensionality
umap_model = UMAP(
    n_neighbors=15,
    n_components=5,
    min_dist=0.0,
    metric="cosine",
    low_memory=False,
    random_state=42,
)

# Step 3 - Cluster reduced embeddings
hdbscan_model = HDBSCAN(
    min_samples=5,
    min_cluster_size=15,
    metric="euclidean",  # manhattan
    cluster_selection_method="leaf",
    prediction_data=True,
)

# Step 4 - Tokenize topics
vectorizer_model = CountVectorizer(stop_words="english", ngram_range=(1, 1))

# Step 5 - Create topic representation
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True) #to reduce the impact of frequent words

# Step 6 - (Optional) Fine-tune topic representations with
# a `bertopic.representation` model
representation_model = KeyBERTInspired()
# representation_model = MaximalMarginalRelevance(diversity=0.3)

# All steps together
topic_model = BERTopic(
    embedding_model=embedding_model,  # Step 1 - Extract embeddings
    umap_model=umap_model,  # Step 2 - Reduce dimensionality
    hdbscan_model=hdbscan_model,  # Step 3 - Cluster reduced embeddings
    vectorizer_model=vectorizer_model,  # Step 4 - Tokenize topics
    ctfidf_model=ctfidf_model,  # Step 5 - Extract topic words
    representation_model=representation_model,  # Step 6 - (Optional) Fine-tune topic represenations
    # nr_topics=15,  # default is none, will auto reduce topics using HDBSCAN
)

# %%
topics, probs = topic_model.fit_transform(docs)

# %%
result = topic_model.get_topic_info()
result.to_csv("bertopic_live_healthy_ngram1_keybert.csv")

# %%
top_topics = topic_model.get_topic_freq()["Topic"].tolist()
embeddings = topic_model.umap_model.embedding_
hover_data = [
    f"{title} - Topic {topic}"
    for title, topic in zip(doc_titles, topics)
]
visualization = topic_model.visualize_documents(
    hover_data,
    reduced_embeddings=embeddings,
    topics=top_topics,
    title="Topics",
)
visualization.show()

# %% [markdown]
# ## With hyperparameter tuning

# %%
embeddings = topic_model.umap_model.embedding_  # reduced embeddings from umap

best_score = 0

for min_cluster_size in range(2, 11):
    for min_samples in range(1, 11):
        for cluster_selection_method in ["eom", "leaf"]:
            for metric in ["euclidean", "manhattan"]:
                # for each combination of parameters of hdbscan
                hdb = HDBSCAN(
                    min_cluster_size=min_cluster_size,
                    min_samples=min_samples,
                    cluster_selection_method=cluster_selection_method,
                    metric=metric,
                    gen_min_span_tree=True,
                ).fit(embeddings)
                # DBCV score
                score = hdb.relative_validity_
                if score > best_score:
                    best_score = score
                    best_parameters = {
                        "min_cluster_size": min_cluster_size,
                        "min_samples": min_samples,
                        "cluster_selection_method": cluster_selection_method,
                        "metric": metric,
                    }

print(f"Best DBCV score: {best_score:.3f}")
print(f"Best parameters: {best_parameters}")
# Out:
# Best DBCV score: 0.337
# Best parameters: {'min_cluster_size': 8, 'min_samples': 3, 'cluster_selection_method': 'eom', 'metric': 'manhattan'}

# %%
# Step 1 - Extract embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Step 2 - Reduce dimensionality
umap_model = UMAP(
    n_neighbors=15,
    n_components=5,
    min_dist=0.0,
    metric="cosine",
    low_memory=False,
    random_state=42,
)

# Step 3 - Cluster reduced embeddings
hdbscan_model = HDBSCAN(
    min_samples=best_parameters["min_samples"],
    min_cluster_size=best_parameters["min_cluster_size"],
    metric=best_parameters["metric"], 
    cluster_selection_method=best_parameters["cluster_selection_method"],
    prediction_data=True,
)

# Step 4 - Tokenize topics
vectorizer_model = CountVectorizer(stop_words="english", ngram_range=(1, 2))

# Step 5 - Create topic representation
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True) #to reduce the impact of frequent words

# Step 6 - (Optional) Fine-tune topic representations with
# a `bertopic.representation` model
# representation_model = KeyBERTInspired()
representation_model = MaximalMarginalRelevance(diversity=0.3)

# All steps together
topic_model = BERTopic(
    embedding_model=embedding_model,  # Step 1 - Extract embeddings
    umap_model=umap_model,  # Step 2 - Reduce dimensionality
    hdbscan_model=hdbscan_model,  # Step 3 - Cluster reduced embeddings
    vectorizer_model=vectorizer_model,  # Step 4 - Tokenize topics
    ctfidf_model=ctfidf_model,  # Step 5 - Extract topic words
    representation_model=representation_model,  # Step 6 - (Optional) Fine-tune topic represenations
    # nr_topics=15,  # default is none, will auto reduce topics using HDBSCAN
)

# %%
topics, probs = topic_model.fit_transform(docs)

# %%
result = topic_model.get_topic_info()
result
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     Topic  Count                                               Name  \
# 0      -1    218               -1_healthier_rice_vegetables_healthy
# 1       0     51             0_stress_esteem_self esteem_resilience
# 2       1     49                1_type diabetes_blood sugar_gdm_tea
# 3       2     42                 2_influenza_vaccines_fever_rubella
# 4       3     37           3_screen time_activities_children_skills
# 5       4     36                             4_tbsp_sauce_fry_serve
# 6       5     32               5_dental_tooth decay_baby teeth_gums
# 7       6     29                     6_bmi_obesity_obese_percentile
# 8       7     29            7_quit smoking_withdrawal_milestone_nrt
# 9       8     28                 8_hawker_dishes_healthy plate_rice
# 10      9     24  9_dementia_person dementia_caregivers_persons ...
# 11     10     24                  10_kids_snack_meals_eating habits
# 12     11     23    11_leg_principal physiotherapist_repeat_muscles
# 13     12     21  12_depression_confinement practices_postnatal ...
# 14     13     20         13_physical activity_workouts_fitness_walk
# 15     14     20             14_lasik_eye care_astigmatism_cataract
# 16     15     20              15_pregnancy_folic acid_vitamin_foods
# 17     16     19    16_cord blood_thalassemia_ultrasound scan_twins
# 18     17     17  17_meal family_mouthwatering selection_selecti...
# 19     18     16        18_milk_breastfeeding_breast milk_cows milk
# 20     19     16     19_binge drinking_liver_alcohol abuse_feb 2022
# 21     20     16          20_trails_trekking_instragram post_nparks
# 22     21     15  21_patients_hand wrist_wrist conditions_compar...
# 23     22     15  22_toddlers_developmental_toys_developmental m...
# 24     23     14           23_new year_chinese new_raw fish_holiday
# 25     24     14  24_developing normally_happening baby_baby dev...
# 26     25     13   25_solids_solid food_childhood nutrition_feeding
# 27     26     12          26_choking_playground_teach child_hazards
# 28     27     12  27_contraception_fathers_infant care_domestic ...
# 29     28     12               28_tobacco_cigarettes_smokers_vaping
# 30     29     12  29_exercises_flexibility_physical activity_act...
# 31     30     12      30_bereavement_multidisciplinary_lpa_deceased
# 32     31     12          31_mental health_support_stigma_mdm emily
# 33     32     12  32_exercises_exercising_exercise pregnancy_pre...
# 34     33     12  33_baby sleep_bedtime routine_routine baby_pil...
# 35     34     11                       34_drugs_drug abuse_teen_tel
# 36     35     11                35_products_hsa_health products_cpm
# 37     36     11  36_1d2d downloads_heathhub sleep_hpb iss_downl...
# 38     37     11              37_pregnancy_discharge_urine_symptoms
# 39     38     11   38_motivation_workout_exercise_physical activity
# 40     39     10             39_dysphagia_ageing_swallowing_elderly
# 41     40     10          40_trans fat_oils_saturated fat_types fat
# 42     41     10           41_epidural_cervix_contractions_delivery
# 43     42     10  42_fall prevention_prevention_elderly_falls el...
# 44     43     10             43_protein_vegetarian_vegetarians_nuts
# 45     44     10                44_mushrooms_flavour_turmeric_spice
# 46     45      9  45_weight loss_metabolism_calorie_weight manag...
# 47     46      9         46_cook dish_hcs cook_cook_choose products
# 48     47      9  47_happening baby_hospital happening_developin...
# 49     48      9       48_cesarean_cesarean section_episiotomy_vbac
# 50     49      8  49_jaundice_hospital happening_bilirubin_baby ...
# 51     50      8   50_physical activity_netball_team sports_fitness
# 52     51      8          51_hiv testing_stis_www hsa_sexual health
# 53     52      8      52_blood pressure_medicines_hypertension_ptca
# 54     53      8            53_sperm_fertility_ovulation_conception
# 55     54      8  54_colorectal cancer_colonoscopy_melanoma_scre...
#
#                                        Representation  \
# 0   [healthier, rice, vegetables, healthy, healthh...
# 1   [stress, esteem, self esteem, resilience, anxi...
# 2   [type diabetes, blood sugar, gdm, tea, gestati...
# 3   [influenza, vaccines, fever, rubella, vaccinat...
# 4   [screen time, activities, children, skills, ga...
# 5   [tbsp, sauce, fry, serve, garlic, chopped, oni...
# 6   [dental, tooth decay, baby teeth, gums, caviti...
# 7   [bmi, obesity, obese, percentile, abdominal ob...
# 8   [quit smoking, withdrawal, milestone, nrt, cra...
# 9   [hawker, dishes, healthy plate, rice, eat, qua...
# 10  [dementia, person dementia, caregivers, person...
# 11  [kids, snack, meals, eating habits, vegetables...
# 12  [leg, principal physiotherapist, repeat, muscl...
# 13  [depression, confinement practices, postnatal ...
# 14  [physical activity, workouts, fitness, walk, s...
# 15  [lasik, eye care, astigmatism, cataract, spect...
# 16  [pregnancy, folic acid, vitamin, foods, pregna...
# 17  [cord blood, thalassemia, ultrasound scan, twi...
# 18  [meal family, mouthwatering selection, selecti...
# 19  [milk, breastfeeding, breast milk, cows milk, ...
# 20  [binge drinking, liver, alcohol abuse, feb 202...
# 21  [trails, trekking, instragram post, nparks, ww...
# 22  [patients, hand wrist, wrist conditions, compa...
# 23  [toddlers, developmental, toys, developmental ...
# 24  [new year, chinese new, raw fish, holiday, yu ...
# 25  [developing normally, happening baby, baby dev...
# 26  [solids, solid food, childhood nutrition, feed...
# 27  [choking, playground, teach child, hazards, em...
# 28  [contraception, fathers, infant care, domestic...
# 29  [tobacco, cigarettes, smokers, vaping, nicotin...
# 30  [exercises, flexibility, physical activity, ac...
# 31  [bereavement, multidisciplinary, lpa, deceased...
# 32  [mental health, support, stigma, mdm emily, de...
# 33  [exercises, exercising, exercise pregnancy, pr...
# 34  [baby sleep, bedtime routine, routine baby, pi...
# 35  [drugs, drug abuse, teen, tel, narcotics, nps,...
# 36  [products, hsa, health products, cpm, health s...
# 37  [1d2d downloads, heathhub sleep, hpb iss, down...
# 38  [pregnancy, discharge, urine, symptoms, amniot...
# 39  [motivation, workout, exercise, physical activ...
# 40  [dysphagia, ageing, swallowing, elderly, demen...
# 41  [trans fat, oils, saturated fat, types fat, om...
# 42  [epidural, cervix, contractions, delivery, pai...
# 43  [fall prevention, prevention, elderly, falls e...
# 44  [protein, vegetarian, vegetarians, nuts, veget...
# 45  [mushrooms, flavour, turmeric, spice, recipe, ...
# 46  [weight loss, metabolism, calorie, weight mana...
# 47  [cook dish, hcs cook, cook, choose products, b...
# 48  [happening baby, hospital happening, developin...
# 49  [cesarean, cesarean section, episiotomy, vbac,...
# 50  [jaundice, hospital happening, bilirubin, baby...
# 51  [physical activity, netball, team sports, fitn...
# 52  [hiv testing, stis, www hsa, sexual health, sc...
# 53  [blood pressure, medicines, hypertension, ptca...
# 54  [sperm, fertility, ovulation, conception, sexu...
