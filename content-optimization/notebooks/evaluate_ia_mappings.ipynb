# %%
# %load_ext kedro.ipython
# Out:
# [08/05/24 17:35:57] INFO     Registered line magic '%reload_kedro'                                   ]8;id=650014;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=447844;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#58\58]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=506348;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=542275;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#60\60]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=390295;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=584718;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#171\171]8;;\
#                              /Users/issacj/Desktop/Synapxe/healthhub-content-optimization/content-o
#                              ptimization.
#                              To set a different path, run '%reload_kedro <project_root>'
# [08/05/24 17:35:57] INFO     Kedro project Content Optimization                                     ]8;id=834046;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=12752;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#141\141]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=314137;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=591962;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#142\142]8;;\
#                              'pipelines'
# [08/05/24 17:35:58] INFO     Registered line magic 'run_viz'                                        ]8;id=218396;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=213507;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#148\148]8;;\

# %%
# ruff: noqa: F821
catalog.list()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'all_contents',
#     'missing_contents',
#     'all_contents_standardized',
#     'all_contents_added',
#     'all_contents_extracted',
#     'all_extracted_text',
#     'all_contents_mapped',
#     'merged_data',
#     'raw_word_counts',
#     'log_word_counts',
#     'flag_for_removal_by_type',
#     'recipes_data',
#     'filtered_data_with_keywords',
#     'parameters',
#     'params:cfg',
#     'params:cfg.option',
#     'params:cfg.contributor',
#     'params:cfg.to_remove',
#     'params:selection_options',
#     'params:selection_options.only_confirmed',
#     'params:selection_options.all',
#     'params:keywords',
#     'params:keywords.model',
#     'params:keywords.spacy_pipeline',
#     'params:keywords.stop_words',
#     'params:keywords.workers',
#     'params:keywords.use_mmr',
#     'params:keywords.diversity',
#     'params:keywords.top_n',
#     'params:columns_to_keep',
#     'params:columns_to_keep.cost-and-financing',
#     'params:columns_to_keep.diseases-and-conditions',
#     'params:columns_to_keep.health-statistics',
#     'params:columns_to_keep.live-healthy-articles',
#     'params:columns_to_keep.medical-care-and-facilities',
#     'params:columns_to_keep.medications',
#     'params:columns_to_keep.program-sub-pages',
#     'params:columns_to_keep.programs',
#     'params:columns_to_keep.support-group-and-others',
#     'params:columns_to_add',
#     'params:columns_to_add.program-sub-pages',
#     'params:columns_to_add.programs',
#     'params:default_columns',
#     'params:word_count_cutoff',
#     'params:whitelist',
#     'params:l1_mappings',
#     'params:l1_mappings.medical-care-and-facilities',
#     'params:l1_mappings.medical-care-and-facilities.Support & Tools',
#     'params:l1_mappings.live-healthy-articles',
#     'params:l1_mappings.live-healthy-articles.Well-being & Lifestyle',
#     'params:l1_mappings.live-healthy-articles.Highlights & Insights',
#     'params:l1_mappings.live-healthy-articles.Well-being & Lifestyle_imputed',
#     'params:l1_mappings.diseases-and-conditions',
#     'params:l1_mappings.diseases-and-conditions.Health Conditions',
#     'params:l1_mappings.cost-and-financing',
#     'params:l1_mappings.cost-and-financing.Support & Tools',
#     'params:l2_mappings',
#     'params:l2_mappings.medical-care-and-facilities',
#     'params:l2_mappings.medical-care-and-facilities.Support and Care Programmes',
#     'params:l2_mappings.live-healthy-articles',
#     'params:l2_mappings.live-healthy-articles.Exercise and Fitness',
#     'params:l2_mappings.live-healthy-articles.Food, Diet and Nutrition',
#     'params:l2_mappings.live-healthy-articles.Personal Care',
#     'params:l2_mappings.live-healthy-articles.Mental Wellness',
#     'params:l2_mappings.live-healthy-articles.Child and Teen Health',
#     'params:l2_mappings.live-healthy-articles.Pregnancy and Infant Health',
#     'params:l2_mappings.live-healthy-articles.Sexual Health and Caregiving',
#     'params:l2_mappings.live-healthy-articles.Substance Addiction',
#     'params:l2_mappings.live-healthy-articles.Travel Health',
#     'params:l2_mappings.live-healthy-articles.Health Safety Advisory',
#     'params:l2_mappings.cost-and-financing',
#     'params:l2_mappings.cost-and-financing.Cost and Financing',
#     'params:updated_urls',
#     'params:updated_urls.live-healthy-articles',
#     'params:updated_urls.live-healthy-articles.1445601',
#     'params:updated_urls.live-healthy-articles.1445603',
#     'params:updated_urls.live-healthy-articles.1445556',
#     'params:updated_urls.live-healthy-articles.1445543',
#     'params:updated_urls.live-healthy-articles.1445673'
# ]

# %%
merged_data = catalog.load("merged_data")

display(merged_data)
# Out:
#                     INFO     Loading data from merged_data (ParquetDataset)...                  ]8;id=456448;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=567975;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/io/data_catalog.py#508\508]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                      content_name  \
# 0     1435040           Breast Screening Subsidies in Singapore
# 1     1435071                   Marriage and Parenthood Schemes
# 2     1434993                                          MediSave
# 3     1435031  Hospital Bills Financial Assistance in Singapore
# 4     1435043   Community Health Assist Scheme (CHAS) Singapore
# ...       ...                                               ...
# 2608  1440763         Heart Failure Transitional Care Programme
# 2609  1440791              Brain and Head Injury Support Groups
# 2610  1440768                      Ambulatory Nutrition Support
# 2611  1440766              LapBandits Support Group (Singapore)
# 2612  1440762              Cardiac Rehabilitation Support Group
#
#                                                  title  \
# 0              Breast Screening Subsidies in Singapore
# 1                      Marriage and Parenthood Schemes
# 2                                             MediSave
# 3     Hospital Bills Financial Assistance in Singapore
# 4      Community Health Assist Scheme (CHAS) Singapore
# ...                                                ...
# 2608         Heart Failure Transitional Care Programme
# 2609              Brain and Head Injury Support Groups
# 2610                      Ambulatory Nutrition Support
# 2611              LapBandits Support Group (Singapore)
# 2612              Cardiac Rehabilitation Support Group
#
#          article_category_names  \
# 0     Conditions and Illnesses,
# 1                    Body Care,
# 2        Alerts and Advisories,
# 3                    Body Care,
# 4        Alerts and Advisories,
# ...                         ...
# 2608  Conditions and Illnesses,
# 2609     Alerts and Advisories,
# 2610  Conditions and Illnesses,
# 2611                 Body Care,
# 2612  Conditions and Illnesses,
#
#                                         cover_image_url  \
# 0     https://ch-api.healthhub.sg/api/public/content...
# 1     https://ch-api.healthhub.sg/api/public/content...
# 2     https://ch-api.healthhub.sg/api/public/content...
# 3     https://ch-api.healthhub.sg/api/public/content...
# 4     https://ch-api.healthhub.sg/api/public/content...
# ...                                                 ...
# 2608  https://ch-api.healthhub.sg/api/public/content...
# 2609  https://ch-api.healthhub.sg/api/public/content...
# 2610  https://ch-api.healthhub.sg/api/public/content...
# 2611  https://ch-api.healthhub.sg/api/public/content...
# 2612  https://ch-api.healthhub.sg/api/public/content...
#
#                                                full_url  \
# 0     https://www.healthhub.sg/a-z/costs-and-financi...
# 1     https://www.healthhub.sg/a-z/costs-and-financi...
# 2     https://www.healthhub.sg/a-z/costs-and-financi...
# 3     https://www.healthhub.sg/a-z/costs-and-financi...
# 4     https://www.healthhub.sg/a-z/costs-and-financi...
# ...                                                 ...
# 2608  https://www.healthhub.sg/a-z/support-groups-an...
# 2609  https://www.healthhub.sg/a-z/support-groups-an...
# 2610  https://www.healthhub.sg/a-z/support-groups-an...
# 2611  https://www.healthhub.sg/a-z/support-groups-an...
# 2612  https://www.healthhub.sg/a-z/support-groups-an...
#
#                                               full_url2  \
# 0     www.healthhub.sg/a-z/costs-and-financing/breas...
# 1     www.healthhub.sg/a-z/costs-and-financing/marri...
# 2     www.healthhub.sg/a-z/costs-and-financing/medisave
# 3     www.healthhub.sg/a-z/costs-and-financing/finan...
# 4         www.healthhub.sg/a-z/costs-and-financing/chas
# ...                                                 ...
# 2608  www.healthhub.sg/a-z/support-groups-and-others...
# 2609  www.healthhub.sg/a-z/support-groups-and-others...
# 2610  www.healthhub.sg/a-z/support-groups-and-others...
# 2611  www.healthhub.sg/a-z/support-groups-and-others...
# 2612  www.healthhub.sg/a-z/support-groups-and-others...
#
#                                            friendly_url  \
# 0                     breast-cancer-screening-subsidies
# 1                            marriage_parenthood_scheme
# 2                                              medisave
# 3     financial-assistance-for-local-patients-in-sin...
# 4                                                  chas
# ...                                                 ...
# 2608      transitional-care-programme-for-heart-failure
# 2609                             2015-NNI-support-group
# 2610                       ambulatory-nutrition-support
# 2611                 singapore-lapbandits-support-group
# 2612  cardiac-rehabilitation-support-group-local-exe...
#
#                                    category_description  \
# 0     Here’s all you need to know about breast cance...
# 1     New parents and couples looking to conceive ca...
# 2     MediSave is the national medical savings schem...
# 3     Having trouble paying your medical bill? Here’...
# 4     With a CHAS card, all Singapore citizens can r...
# ...                                                 ...
# 2608  The team from NUHCS gives support to heart fai...
# 2609  Read on for a list of brain injury support gro...
# 2610  Read about the ambulatory support benefits one...
# 2611  Have you just undergone bariatric surgery for ...
# 2612  Looking to improve your caregiving skills for ...
#
#                                            content_body  ... has_image  \
# 0     b'<div class="ExternalClass07C58E0D957B4AA7B14...  ...     False
# 1     b'<div class="ExternalClassE1D82270F17241E4955...  ...     False
# 2     b'<div class="ExternalClass67AD25F1F8B64B349E5...  ...     False
# 3     b'<div class="ExternalClassE335708125E743FDAA3...  ...     False
# 4     b'<h2>What is the Community Health Assist Sche...  ...      True
# ...                                                 ...  ...       ...
# 2608  b'<div class="ExternalClassFC126593610D4F0587A...  ...      True
# 2609  b'<div class="ExternalClass7C92735B78174928B28...  ...     False
# 2610  b'<div class="ExternalClass3FABAC9D59A64BCAB96...  ...     False
# 2611  b'<div class="ExternalClassA4C749C7DB7647FBB6D...  ...     False
# 2612  b'<div class="ExternalClassD4367205B11F4638BFF...  ...     False
#
#                                        related_sections  \
# 0                      [Cancer Facts You Cannot Ignore]
# 1     [MediSave, Baby Bonus - What You Need to Know,...
# 2     [A Way to Reduce Outpatient Cost for Chronic D...
# 3                                                    []
# 4     [All Pioneer Generation (PG) and Merdeka Gener...
# ...                                                 ...
# 2608                                                 []
# 2609                                                 []
# 2610                                                 []
# 2611                                                 []
# 2612                                                 []
#
#                                        extracted_tables  \
# 0     [[[National Healthcare Group (NHG) Polyclinics...
# 1     [[[Delivery Procedure, No. of Days of Hospital...
# 2                                                  None
# 3                                                  None
# 4     [[[CHAS Criteria, CHAS Green, CHAS Orange, CHA...
# ...                                                 ...
# 2608                                               None
# 2609                                               None
# 2610                                               None
# 2611                                               None
# 2612                                               None
#
#                               extracted_raw_html_tables  \
# 0     [<table cellspacing="0" class="ms-rteTable-def...
# 1     [<table style="font-weight:400;margin-left:aut...
# 2                                                  None
# 3                                                  None
# 4     [<table><tbody><tr><td><strong>CHAS Criteria</...
# ...                                                 ...
# 2608                                               None
# 2609                                               None
# 2610                                               None
# 2611                                               None
# 2612                                               None
#
#                                         extracted_links  \
# 0     [[Cancer Facts You Cannot Ignore, https://www....
# 1     [[How to Submit Claims, https://crms.moh.gov.s...
# 2     [[A Way to Reduce Outpatient Cost for Chronics...
# 3     [[Medifund, https://www.healthhub.sg/a-z/costs...
# 4     [[www.chas.sg/apply, https://www.chas.sg/apply...
# ...                                                 ...
# 2608  [[charles_wu@nuhs.edu.sg, mailto: charles_wu@n...
# 2609  [[here, https://www.nni.com.sg/patient-care/br...
# 2610  [[Nutrition and Dietetics, https://www.healthh...
# 2611                                                 []
# 2612                                                 []
#
#                                       extracted_headers  \
# 0     [[Breast Cancer Screening, h2], [Subsidy for M...
# 1     [[MediSave Maternity Package, h2], [Examples o...
# 2     [[, h2], [What is MediSave?, h2], [Contributin...
# 3     [[Medifund: Hospital Bill Payment Assistance, ...
# 4     [[What is the Community Health Assist Scheme (...
# ...                                                 ...
# 2608  [[Transitional Care for Heart Failure Patients...
# 2609  [[, h2], [Brain Tumour Society (Singapore), h2...
# 2610  [[The Importance of Ambulatory Nutrition Suppo...
# 2611  [[About Khoo Teck Puat Hospitals LapBandits Su...
# 2612  [[Cardiac Rehabilitation Support Group Activit...
#
#                                        extracted_images  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4     [[chas blue card, https://ch-api.healthhub.sg/...
# ...                                                 ...
# 2608  [[Transitional care, amongst other things, pro...
# 2609                                                 []
# 2610                                                 []
# 2611                                                 []
# 2612                                                 []
#
#                                  extracted_content_body      l1_mappings  \
# 0     Breast cancer is the number one cancer among w...  Support & Tools
# 1     MediSave Maternity Package\nWith the MediSave ...             None
# 2     What is MediSave?\nMediSave, introduced in Apr...             None
# 3     Patients or family members who have difficulty...             None
# 4     What is the Community Health Assist Scheme (CH...             None
# ...                                                 ...              ...
# 2608  Heart failure is the leading cause of rehospit...             None
# 2609  Brain Tumour Society (Singapore)\nThe Brain Tu...             None
# 2610  The Importance of Ambulatory Nutrition Support...             None
# 2611  About Khoo Teck Puat Hospitals LapBandits Supp...             None
# 2612  If you are caring for a loved one with cardiov...             None
#
#              l2_mappings
# 0     Cost and Financing
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# ...                  ...
# 2608                None
# 2609                None
# 2610                None
# 2611                None
# 2612                None
#
# [2613 rows x 39 columns]

# %%
df = merged_data[
    [
        "id",
        "content_name",
        "title",
        "full_url",
        "content_body",
        "extracted_content_body",
        "pr_name",
        "date_modified",
        "content_category",
        "article_category_names",
        "l1_mappings",
        "l2_mappings",
    ]
]

df = df[
    df["content_category"].isin(
        [
            "cost-and-financing",
            "diseases-and-conditions",
            "live-healthy-articles",
            "medical-care-and-facilities",
            "support-group-and-others",
        ]
    )
]

display(df)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                      content_name  \
# 0     1435040           Breast Screening Subsidies in Singapore
# 1     1435071                   Marriage and Parenthood Schemes
# 2     1434993                                          MediSave
# 3     1435031  Hospital Bills Financial Assistance in Singapore
# 4     1435043   Community Health Assist Scheme (CHAS) Singapore
# ...       ...                                               ...
# 2608  1440763         Heart Failure Transitional Care Programme
# 2609  1440791              Brain and Head Injury Support Groups
# 2610  1440768                      Ambulatory Nutrition Support
# 2611  1440766              LapBandits Support Group (Singapore)
# 2612  1440762              Cardiac Rehabilitation Support Group
#
#                                                  title  \
# 0              Breast Screening Subsidies in Singapore
# 1                      Marriage and Parenthood Schemes
# 2                                             MediSave
# 3     Hospital Bills Financial Assistance in Singapore
# 4      Community Health Assist Scheme (CHAS) Singapore
# ...                                                ...
# 2608         Heart Failure Transitional Care Programme
# 2609              Brain and Head Injury Support Groups
# 2610                      Ambulatory Nutrition Support
# 2611              LapBandits Support Group (Singapore)
# 2612              Cardiac Rehabilitation Support Group
#
#                                                full_url  \
# 0     https://www.healthhub.sg/a-z/costs-and-financi...
# 1     https://www.healthhub.sg/a-z/costs-and-financi...
# 2     https://www.healthhub.sg/a-z/costs-and-financi...
# 3     https://www.healthhub.sg/a-z/costs-and-financi...
# 4     https://www.healthhub.sg/a-z/costs-and-financi...
# ...                                                 ...
# 2608  https://www.healthhub.sg/a-z/support-groups-an...
# 2609  https://www.healthhub.sg/a-z/support-groups-an...
# 2610  https://www.healthhub.sg/a-z/support-groups-an...
# 2611  https://www.healthhub.sg/a-z/support-groups-an...
# 2612  https://www.healthhub.sg/a-z/support-groups-an...
#
#                                            content_body  \
# 0     b'<div class="ExternalClass07C58E0D957B4AA7B14...
# 1     b'<div class="ExternalClassE1D82270F17241E4955...
# 2     b'<div class="ExternalClass67AD25F1F8B64B349E5...
# 3     b'<div class="ExternalClassE335708125E743FDAA3...
# 4     b'<h2>What is the Community Health Assist Sche...
# ...                                                 ...
# 2608  b'<div class="ExternalClassFC126593610D4F0587A...
# 2609  b'<div class="ExternalClass7C92735B78174928B28...
# 2610  b'<div class="ExternalClass3FABAC9D59A64BCAB96...
# 2611  b'<div class="ExternalClassA4C749C7DB7647FBB6D...
# 2612  b'<div class="ExternalClassD4367205B11F4638BFF...
#
#                                  extracted_content_body  \
# 0     Breast cancer is the number one cancer among w...
# 1     MediSave Maternity Package\nWith the MediSave ...
# 2     What is MediSave?\nMediSave, introduced in Apr...
# 3     Patients or family members who have difficulty...
# 4     What is the Community Health Assist Scheme (CH...
# ...                                                 ...
# 2608  Heart failure is the leading cause of rehospit...
# 2609  Brain Tumour Society (Singapore)\nThe Brain Tu...
# 2610  The Importance of Ambulatory Nutrition Support...
# 2611  About Khoo Teck Puat Hospitals LapBandits Supp...
# 2612  If you are caring for a loved one with cardiov...
#
#                                           pr_name  \
# 0                          Health Promotion Board
# 1                              Ministry of Health
# 2                              Ministry of Health
# 3                         Khoo Teck Puat Hospital
# 4                                            CHAS
# ...                                           ...
# 2608  National University Heart Centre, Singapore
# 2609              National Neuroscience Institute
# 2610                 National University Hospital
# 2611                      Khoo Teck Puat Hospital
# 2612                 National University Hospital
#
#                      date_modified          content_category  \
# 0     2023-08-08T05:27:42.0000000Z        cost-and-financing
# 1     2021-11-02T05:46:52.0000000Z        cost-and-financing
# 2     2019-01-29T05:06:22.0000000Z        cost-and-financing
# 3     2019-09-13T03:08:41.0000000Z        cost-and-financing
# 4     2022-09-30T10:44:05.0000000Z        cost-and-financing
# ...                            ...                       ...
# 2608  2021-12-21T03:07:24.0000000Z  support-group-and-others
# 2609  2019-09-13T02:35:52.0000000Z  support-group-and-others
# 2610  2021-05-25T02:27:00.0000000Z  support-group-and-others
# 2611  2020-11-02T04:38:01.0000000Z  support-group-and-others
# 2612  2019-09-13T02:35:52.0000000Z  support-group-and-others
#
#          article_category_names      l1_mappings         l2_mappings
# 0     Conditions and Illnesses,  Support & Tools  Cost and Financing
# 1                    Body Care,             None                None
# 2        Alerts and Advisories,             None                None
# 3                    Body Care,             None                None
# 4        Alerts and Advisories,             None                None
# ...                         ...              ...                 ...
# 2608  Conditions and Illnesses,             None                None
# 2609     Alerts and Advisories,             None                None
# 2610  Conditions and Illnesses,             None                None
# 2611                 Body Care,             None                None
# 2612  Conditions and Illnesses,             None                None
#
# [1580 rows x 12 columns]

# %%
null_df = df[(df["l1_mappings"].isnull()) & (df["l2_mappings"].isnull())]

display(null_df)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                      content_name  \
# 1     1435071                   Marriage and Parenthood Schemes
# 2     1434993                                          MediSave
# 3     1435031  Hospital Bills Financial Assistance in Singapore
# 4     1435043   Community Health Assist Scheme (CHAS) Singapore
# 5     1435005      Enhancement for Active Seniors (EASE) by HDB
# ...       ...                                               ...
# 2608  1440763         Heart Failure Transitional Care Programme
# 2609  1440791              Brain and Head Injury Support Groups
# 2610  1440768                      Ambulatory Nutrition Support
# 2611  1440766              LapBandits Support Group (Singapore)
# 2612  1440762              Cardiac Rehabilitation Support Group
#
#                                                  title  \
# 1                      Marriage and Parenthood Schemes
# 2                                             MediSave
# 3     Hospital Bills Financial Assistance in Singapore
# 4      Community Health Assist Scheme (CHAS) Singapore
# 5         Enhancement for Active Seniors (EASE) by HDB
# ...                                                ...
# 2608         Heart Failure Transitional Care Programme
# 2609              Brain and Head Injury Support Groups
# 2610                      Ambulatory Nutrition Support
# 2611              LapBandits Support Group (Singapore)
# 2612              Cardiac Rehabilitation Support Group
#
#                                                full_url  \
# 1     https://www.healthhub.sg/a-z/costs-and-financi...
# 2     https://www.healthhub.sg/a-z/costs-and-financi...
# 3     https://www.healthhub.sg/a-z/costs-and-financi...
# 4     https://www.healthhub.sg/a-z/costs-and-financi...
# 5     https://www.healthhub.sg/a-z/costs-and-financi...
# ...                                                 ...
# 2608  https://www.healthhub.sg/a-z/support-groups-an...
# 2609  https://www.healthhub.sg/a-z/support-groups-an...
# 2610  https://www.healthhub.sg/a-z/support-groups-an...
# 2611  https://www.healthhub.sg/a-z/support-groups-an...
# 2612  https://www.healthhub.sg/a-z/support-groups-an...
#
#                                            content_body  \
# 1     b'<div class="ExternalClassE1D82270F17241E4955...
# 2     b'<div class="ExternalClass67AD25F1F8B64B349E5...
# 3     b'<div class="ExternalClassE335708125E743FDAA3...
# 4     b'<h2>What is the Community Health Assist Sche...
# 5     b'<div class="ExternalClass26C3FCBE3D3D46728E8...
# ...                                                 ...
# 2608  b'<div class="ExternalClassFC126593610D4F0587A...
# 2609  b'<div class="ExternalClass7C92735B78174928B28...
# 2610  b'<div class="ExternalClass3FABAC9D59A64BCAB96...
# 2611  b'<div class="ExternalClassA4C749C7DB7647FBB6D...
# 2612  b'<div class="ExternalClassD4367205B11F4638BFF...
#
#                                  extracted_content_body  \
# 1     MediSave Maternity Package\nWith the MediSave ...
# 2     What is MediSave?\nMediSave, introduced in Apr...
# 3     Patients or family members who have difficulty...
# 4     What is the Community Health Assist Scheme (CH...
# 5     Introduction to the Enhancement for Active Sen...
# ...                                                 ...
# 2608  Heart failure is the leading cause of rehospit...
# 2609  Brain Tumour Society (Singapore)\nThe Brain Tu...
# 2610  The Importance of Ambulatory Nutrition Support...
# 2611  About Khoo Teck Puat Hospitals LapBandits Supp...
# 2612  If you are caring for a loved one with cardiov...
#
#                                           pr_name  \
# 1                              Ministry of Health
# 2                              Ministry of Health
# 3                         Khoo Teck Puat Hospital
# 4                                            CHAS
# 5                      Agency for Integrated Care
# ...                                           ...
# 2608  National University Heart Centre, Singapore
# 2609              National Neuroscience Institute
# 2610                 National University Hospital
# 2611                      Khoo Teck Puat Hospital
# 2612                 National University Hospital
#
#                      date_modified          content_category  \
# 1     2021-11-02T05:46:52.0000000Z        cost-and-financing
# 2     2019-01-29T05:06:22.0000000Z        cost-and-financing
# 3     2019-09-13T03:08:41.0000000Z        cost-and-financing
# 4     2022-09-30T10:44:05.0000000Z        cost-and-financing
# 5     2020-08-10T02:56:22.0000000Z        cost-and-financing
# ...                            ...                       ...
# 2608  2021-12-21T03:07:24.0000000Z  support-group-and-others
# 2609  2019-09-13T02:35:52.0000000Z  support-group-and-others
# 2610  2021-05-25T02:27:00.0000000Z  support-group-and-others
# 2611  2020-11-02T04:38:01.0000000Z  support-group-and-others
# 2612  2019-09-13T02:35:52.0000000Z  support-group-and-others
#
#                                  article_category_names l1_mappings  \
# 1                                            Body Care,        None
# 2                                Alerts and Advisories,        None
# 3                                            Body Care,        None
# 4                                Alerts and Advisories,        None
# 5     Senior Health and Caregiving,Alerts and Adviso...        None
# ...                                                 ...         ...
# 2608                          Conditions and Illnesses,        None
# 2609                             Alerts and Advisories,        None
# 2610                          Conditions and Illnesses,        None
# 2611                                         Body Care,        None
# 2612                          Conditions and Illnesses,        None
#
#      l2_mappings
# 1           None
# 2           None
# 3           None
# 4           None
# 5           None
# ...          ...
# 2608        None
# 2609        None
# 2610        None
# 2611        None
# 2612        None
#
# [332 rows x 12 columns]

# %%
null_df_counts = (
    null_df.groupby(by=["content_category", "article_category_names"], dropna=False)
    .size()
    .sort_values(ascending=False)
)

null_df_counts
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# content_category             article_category_names
# live-healthy-articles        NaN                                                       155
# diseases-and-conditions      NaN                                                        57
# live-healthy-articles        Senior Health and Caregiving,                              21
# medical-care-and-facilities  Conditions and Illnesses,                                  15
# live-healthy-articles        Sexual Health and Relationships,                           15
# medical-care-and-facilities  Senior Health and Caregiving,                               9
# support-group-and-others     Conditions and Illnesses,                                   7
# cost-and-financing           Alerts and Advisories,                                      7
# diseases-and-conditions      Chronic Illnesses,                                          4
# cost-and-financing           NaN                                                         4
#                              Senior Health and Caregiving,                               4
#                              Body Care,                                                  3
# medical-care-and-facilities  Alerts and Advisories,                                      3
# diseases-and-conditions      Intoxicates and Addictions,                                 2
# medical-care-and-facilities  NaN                                                         2
# diseases-and-conditions      Mind and Balance,                                           2
# medical-care-and-facilities  Child and Teen Health,                                      2
#                              Senior Health and Caregiving,Alerts and Advisories,         2
# support-group-and-others     Senior Health and Caregiving,                               2
#                              Conditions and Illnesses,Alerts and Advisories,             1
# cost-and-financing           Body Care,Senior Health and Caregiving,                     1
# support-group-and-others     Body Care,                                                  1
#                              Conditions and Illnesses,Senior Health and Caregiving,      1
#                              Alerts and Advisories,                                      1
# medical-care-and-facilities  Senior Health and Caregiving,Conditions and Illnesses,      1
#                              Food and Nutrition,                                         1
# cost-and-financing           Chronic Illnesses,                                          1
# medical-care-and-facilities  Mind and Balance,                                           1
#                              Intoxicates and Addictions,                                 1
#                              FIGHT and Travel Health,                                    1
#                              Exercise and Fitness,                                       1
#                              Conditions and Illnesses,Senior Health and Caregiving,      1
# cost-and-financing           Senior Health and Caregiving,Alerts and Advisories,         1
# diseases-and-conditions      Senior Health and Caregiving,                               1
# support-group-and-others     NaN                                                         1
# dtype: int64

# %%
null_mappings = list(null_df_counts.keys())

# %%
for categories in null_mappings:
    print(categories)
# Out:
# ('live-healthy-articles', nan)
# ('diseases-and-conditions', nan)
# ('live-healthy-articles', 'Senior Health and Caregiving,')
# ('medical-care-and-facilities', 'Conditions and Illnesses,')
# ('live-healthy-articles', 'Sexual Health and Relationships,')
# ('medical-care-and-facilities', 'Senior Health and Caregiving,')
# ('support-group-and-others', 'Conditions and Illnesses,')
# ('cost-and-financing', 'Alerts and Advisories,')
# ('diseases-and-conditions', 'Chronic Illnesses,')
# ('cost-and-financing', nan)
# ('cost-and-financing', 'Senior Health and Caregiving,')
# ('cost-and-financing', 'Body Care,')
# ('medical-care-and-facilities', 'Alerts and Advisories,')
# ('diseases-and-conditions', 'Intoxicates and Addictions,')
# ('medical-care-and-facilities', nan)
# ('diseases-and-conditions', 'Mind and Balance,')
# ('medical-care-and-facilities', 'Child and Teen Health,')
# ('medical-care-and-facilities', 'Senior Health and Caregiving,Alerts and Advisories,')
# ('support-group-and-others', 'Senior Health and Caregiving,')
# ('support-group-and-others', 'Conditions and Illnesses,Alerts and Advisories,')
# ('cost-and-financing', 'Body Care,Senior Health and Caregiving,')
# ('support-group-and-others', 'Body Care,')
# ('support-group-and-others', 'Conditions and Illnesses,Senior Health and Caregiving,')
# ('support-group-and-others', 'Alerts and Advisories,')
# ('medical-care-and-facilities', 'Senior Health and Caregiving,Conditions and Illnesses,')
# ('medical-care-and-facilities', 'Food and Nutrition,')
# ('cost-and-financing', 'Chronic Illnesses,')
# ('medical-care-and-facilities', 'Mind and Balance,')
# ('medical-care-and-facilities', 'Intoxicates and Addictions,')
# ('medical-care-and-facilities', 'FIGHT and Travel Health,')
# ('medical-care-and-facilities', 'Exercise and Fitness,')
# ('medical-care-and-facilities', 'Conditions and Illnesses,Senior Health and Caregiving,')
# ('cost-and-financing', 'Senior Health and Caregiving,Alerts and Advisories,')
# ('diseases-and-conditions', 'Senior Health and Caregiving,')
# ('support-group-and-others', nan)

# %%
def extract_unqiue_categories_dict(categories):
    result = {}
    for content_category, article_category_names in categories:
        if content_category not in result:
            result[content_category] = set()

        # Skip non-string values (e.g. nan)
        if not isinstance(article_category_names, str):
            print(content_category, article_category_names)
            continue

        article_categories = article_category_names.split(",")
        for article_category in article_categories:
            cleaned_category = article_category.strip()
            if cleaned_category != "":
                result[content_category].add(cleaned_category)

    for key, value in result.items():
        result[key] = sorted(list(value))

    return result


category_mappings = extract_unqiue_categories_dict(null_mappings)
print(category_mappings)
# Out:
# live-healthy-articles nan
# diseases-and-conditions nan
# cost-and-financing nan
# medical-care-and-facilities nan
# support-group-and-others nan
# {'live-healthy-articles': ['Senior Health and Caregiving', 'Sexual Health and Relationships'], 'diseases-and-conditions': ['Chronic Illnesses', 'Intoxicates and Addictions', 'Mind and Balance', 'Senior Health and Caregiving'], 'medical-care-and-facilities': ['Alerts and Advisories', 'Child and Teen Health', 'Conditions and Illnesses', 'Exercise and Fitness', 'FIGHT and Travel Health', 'Food and Nutrition', 'Intoxicates and Addictions', 'Mind and Balance', 'Senior Health and Caregiving'], 'support-group-and-others': ['Alerts and Advisories', 'Body Care', 'Conditions and Illnesses', 'Senior Health and Caregiving'], 'cost-and-financing': ['Alerts and Advisories', 'Body Care', 'Chronic Illnesses', 'Senior Health and Caregiving']}

# %%
for key, values in category_mappings.items():
    for sub_category in values:
        null_df_slice = null_df[
            (null_df["content_category"] == key)
            & (null_df["article_category_names"].str.contains(sub_category))
        ]
        print(f"Value Counts for {key}, {sub_category}:", null_df_slice.shape[0])
# Out:
# Value Counts for live-healthy-articles, Senior Health and Caregiving: 21
# Value Counts for live-healthy-articles, Sexual Health and Relationships: 15
# Value Counts for diseases-and-conditions, Chronic Illnesses: 4
# Value Counts for diseases-and-conditions, Intoxicates and Addictions: 2
# Value Counts for diseases-and-conditions, Mind and Balance: 2
# Value Counts for diseases-and-conditions, Senior Health and Caregiving: 1
# Value Counts for medical-care-and-facilities, Alerts and Advisories: 5
# Value Counts for medical-care-and-facilities, Child and Teen Health: 2
# Value Counts for medical-care-and-facilities, Conditions and Illnesses: 17
# Value Counts for medical-care-and-facilities, Exercise and Fitness: 1
# Value Counts for medical-care-and-facilities, FIGHT and Travel Health: 1
# Value Counts for medical-care-and-facilities, Food and Nutrition: 1
# Value Counts for medical-care-and-facilities, Intoxicates and Addictions: 1
# Value Counts for medical-care-and-facilities, Mind and Balance: 1
# Value Counts for medical-care-and-facilities, Senior Health and Caregiving: 13
# Value Counts for support-group-and-others, Alerts and Advisories: 2
# Value Counts for support-group-and-others, Body Care: 1
# Value Counts for support-group-and-others, Conditions and Illnesses: 9
# Value Counts for support-group-and-others, Senior Health and Caregiving: 3
# Value Counts for cost-and-financing, Alerts and Advisories: 8
# Value Counts for cost-and-financing, Body Care: 4
# Value Counts for cost-and-financing, Chronic Illnesses: 1
# Value Counts for cost-and-financing, Senior Health and Caregiving: 6

# %%
for key in category_mappings.keys():
    null_df_slice = null_df[
        (null_df["content_category"] == key)
        & (null_df["article_category_names"].isnull())
    ]
    print(f"Value Counts for {key}, null:", null_df_slice.shape[0])
# Out:
# Value Counts for live-healthy-articles, null: 155
# Value Counts for diseases-and-conditions, null: 57
# Value Counts for medical-care-and-facilities, null: 2
# Value Counts for support-group-and-others, null: 1
# Value Counts for cost-and-financing, null: 4

# %%
null_df.shape[0] - 219
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 113
