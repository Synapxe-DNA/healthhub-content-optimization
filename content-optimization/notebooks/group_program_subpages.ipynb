# %% [markdown]
# Purpose of this notebook is to group the urls by url hierarchy, according to the second level of the programmes (after `/programmes/`)
#
# Please check that there's a folder named `program-sub-pages` in this `notebooks` folder in order to store the created excels later on.
#
# Please run `get_program_subpages.ipynb` first to get the relevant excel file to run this notebook.
#
# Note:
# - Do not worry about the squiggly line under the dataframe variables, as I have defined the variables using global(). As long as the cells have been ran, there should be no issue.
#
# <hr>

# %% [markdown]
# ### Setup

# %%
import os
import pandas as pd

# %%
folder_path = 'program-sub-pages'
if not os.path.exists(folder_path):
    # If it doesn't exist, create the folder
    os.makedirs(folder_path)
    print(f"Folder created: {folder_path}")
else:
    print(f"Folder already exists: {folder_path}")
# Out:
# Folder already exists: program-sub-pages

# %% [markdown]
# Load Clean Dataset of Program Sub-pages URL

# %%
df = pd.read_excel(r"program-sub-pages\cleaned_programSubpages.xlsx", sheet_name=0)
# For more information & checking on the rows, you can look this (Optional):
# df_cols = df = pd.read_excel(r"program-sub-pages\cleaned_programSubpages.xlsx", sheet_name=1)
df
# Out:
#           id                                              title  \
# 0    1434688  Screen for Life - National Health Screening Pr...
# 1    1434612                      Live Well, Age Well Programme
# 2    1434660                                The Healthy 365 App
# 3    1434580                 Eat, Drink, Shop Healthy Challenge
# 4    1434657               Great things start when you MOVE IT!
# ..       ...                                                ...
# 359  1435127                   Types of diabetes | Diabetes Hub
# 360  1435167                       Hypoglycaemia | Diabetes Hub
# 361  1468676                                Program Sub level 1
# 362  1435215  If you have coronary heart disease | Diabetes Hub
# 363  1434815                                            level-3
#
#                                               full_url  \
# 0    https://www.healthhub.sg/programmes/Screen_for...
# 1              https://www.healthhub.sg/programmes/AAP
# 2    https://www.healthhub.sg/programmes/healthyliving
# 3    https://www.healthhub.sg/programmes/eat-drink-...
# 4       https://www.healthhub.sg/programmes/LetsMoveIt
# ..                                                 ...
# 359  https://www.healthhub.sg/programmes/diabetes-h...
# 360  https://www.healthhub.sg/programmes/diabetes-h...
# 361  https://www.healthhub.sg/programmes/1test/sya-...
# 362  https://www.healthhub.sg/programmes/diabetes-h...
# 363  https://www.healthhub.sg/programmes/healthia/l...
#
#                                 extracted_content_body   content_category
# 0    We note that some users have experienced issue...           programs
# 1    By 7 February 2023, all users must perform a o...           programs
# 2    [https://go.gov.sg/useh365]  [https://go.gov.s...           programs
# 3    Menu   [#clear]\n\nMenu   [#clear]\n\nMenu   [...           programs
# 4    [https://go.gov.sg/h365-moveit]\n\nGet Moving ...           programs
# ..                                                 ...                ...
# 359  3 BEaTMS TO BEAT DIABETES [/programmes/diabete...  program-sub-pages
# 360  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
# 361  HealthHub\nRelaxation-ExerciseHealthhub\nList ...  program-sub-pages
# 362  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
# 363                           athis is level 3 content  program-sub-pages
#
# [364 rows x 5 columns]

# %% [markdown]
# <hr>
#
# ### Extraction of second level of URL hierarchy

# %%
# Duplicate df to keep original df unchanged
df_new = df

# %%
# Create new col to store extracted portion of url after '/programmes/'
df_new['secondLvl'] = df_new['full_url'].str.split('/programmes/').str[1].str.split('/').str[0]
df_new
# Out:
#           id                                              title  \
# 0    1434688  Screen for Life - National Health Screening Pr...
# 1    1434612                      Live Well, Age Well Programme
# 2    1434660                                The Healthy 365 App
# 3    1434580                 Eat, Drink, Shop Healthy Challenge
# 4    1434657               Great things start when you MOVE IT!
# ..       ...                                                ...
# 359  1435127                   Types of diabetes | Diabetes Hub
# 360  1435167                       Hypoglycaemia | Diabetes Hub
# 361  1468676                                Program Sub level 1
# 362  1435215  If you have coronary heart disease | Diabetes Hub
# 363  1434815                                            level-3
#
#                                               full_url  \
# 0    https://www.healthhub.sg/programmes/Screen_for...
# 1              https://www.healthhub.sg/programmes/AAP
# 2    https://www.healthhub.sg/programmes/healthyliving
# 3    https://www.healthhub.sg/programmes/eat-drink-...
# 4       https://www.healthhub.sg/programmes/LetsMoveIt
# ..                                                 ...
# 359  https://www.healthhub.sg/programmes/diabetes-h...
# 360  https://www.healthhub.sg/programmes/diabetes-h...
# 361  https://www.healthhub.sg/programmes/1test/sya-...
# 362  https://www.healthhub.sg/programmes/diabetes-h...
# 363  https://www.healthhub.sg/programmes/healthia/l...
#
#                                 extracted_content_body   content_category  \
# 0    We note that some users have experienced issue...           programs
# 1    By 7 February 2023, all users must perform a o...           programs
# 2    [https://go.gov.sg/useh365]  [https://go.gov.s...           programs
# 3    Menu   [#clear]\n\nMenu   [#clear]\n\nMenu   [...           programs
# 4    [https://go.gov.sg/h365-moveit]\n\nGet Moving ...           programs
# ..                                                 ...                ...
# 359  3 BEaTMS TO BEAT DIABETES [/programmes/diabete...  program-sub-pages
# 360  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
# 361  HealthHub\nRelaxation-ExerciseHealthhub\nList ...  program-sub-pages
# 362  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
# 363                           athis is level 3 content  program-sub-pages
#
#                             secondLvl
# 0                     Screen_for_Life
# 1                                 AAP
# 2                       healthyliving
# 3    eat-drink-shop-healthy-challenge
# 4                          LetsMoveIt
# ..                                ...
# 359                   diabetes-hub-v2
# 360                   diabetes-hub-v2
# 361                             1test
# 362                   diabetes-hub-v2
# 363                          healthia
#
# [364 rows x 6 columns]

# %% [markdown]
# <hr>
#
# ### Data Understanding
#
# - No. of unique values for `secondLvl` = No. of unique groups

# %%
df_new
# Out:
#           id                                              title  \
# 0    1434688  Screen for Life - National Health Screening Pr...
# 1    1434612                      Live Well, Age Well Programme
# 2    1434660                                The Healthy 365 App
# 3    1434580                 Eat, Drink, Shop Healthy Challenge
# 4    1434657               Great things start when you MOVE IT!
# ..       ...                                                ...
# 359  1435127                   Types of diabetes | Diabetes Hub
# 360  1435167                       Hypoglycaemia | Diabetes Hub
# 361  1468676                                Program Sub level 1
# 362  1435215  If you have coronary heart disease | Diabetes Hub
# 363  1434815                                            level-3
#
#                                               full_url  \
# 0    https://www.healthhub.sg/programmes/Screen_for...
# 1              https://www.healthhub.sg/programmes/AAP
# 2    https://www.healthhub.sg/programmes/healthyliving
# 3    https://www.healthhub.sg/programmes/eat-drink-...
# 4       https://www.healthhub.sg/programmes/LetsMoveIt
# ..                                                 ...
# 359  https://www.healthhub.sg/programmes/diabetes-h...
# 360  https://www.healthhub.sg/programmes/diabetes-h...
# 361  https://www.healthhub.sg/programmes/1test/sya-...
# 362  https://www.healthhub.sg/programmes/diabetes-h...
# 363  https://www.healthhub.sg/programmes/healthia/l...
#
#                                 extracted_content_body   content_category  \
# 0    We note that some users have experienced issue...           programs
# 1    By 7 February 2023, all users must perform a o...           programs
# 2    [https://go.gov.sg/useh365]  [https://go.gov.s...           programs
# 3    Menu   [#clear]\n\nMenu   [#clear]\n\nMenu   [...           programs
# 4    [https://go.gov.sg/h365-moveit]\n\nGet Moving ...           programs
# ..                                                 ...                ...
# 359  3 BEaTMS TO BEAT DIABETES [/programmes/diabete...  program-sub-pages
# 360  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
# 361  HealthHub\nRelaxation-ExerciseHealthhub\nList ...  program-sub-pages
# 362  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
# 363                           athis is level 3 content  program-sub-pages
#
#                             secondLvl
# 0                     Screen_for_Life
# 1                                 AAP
# 2                       healthyliving
# 3    eat-drink-shop-healthy-challenge
# 4                          LetsMoveIt
# ..                                ...
# 359                   diabetes-hub-v2
# 360                   diabetes-hub-v2
# 361                             1test
# 362                   diabetes-hub-v2
# 363                          healthia
#
# [364 rows x 6 columns]

# %% [markdown]
# Check the unqiue values for second level

# %%
unique_secondLvl = df_new['secondLvl'].unique()
unique_counts = df_new['secondLvl'].value_counts()
print(f"Number of unique values: {len(unique_secondLvl)}")
print("\nCounts for each unique value:\n", unique_counts)
# Out:
# Number of unique values: 67
#
# Counts for each unique value:
#  secondLvl
# parent-hub                     72
# MindSG                         71
# diabetes-hub                   41
# diabetes-hub-v2                25
# pressure-injury                14
#                                ..
# breast-cancer-screening         1
# healthy-pregnancy               1
# colorectal-cancer-screening     1
# personal-health-eservices       1
# Copy-of-1test                   1
# Name: count, Length: 66, dtype: int64

# %%
unique_secondLvl
# Out:
# array(['Screen_for_Life', 'AAP', 'healthyliving',
#        'eat-drink-shop-healthy-challenge', 'LetsMoveIt', 'hsg',
#        'parent-hub', 'nsc', 'nutrition-hub', 'vaccinate', 'diabetes-hub',
#        'school_dental_programme', 'healthhub-rewards',
#        'diabetes-mellitus', 'IQuit', 'hiv-prevention',
#        'children-health-ehb', 'MindSG', 'korangok',
#        'sexually-transmitted-infections', 'use-antibiotics-right',
#        'healthy-workplace-ecosystem', 'MoveIt', 'health-promoting-malls',
#        'strokehub', 'hygiene', 'StayWell', 'justcheckingin',
#        'howareyoudoing', 'EmotionsExplorer', 'preventive-health',
#        'pressure-injury', 'Fight_The_Spread', 'cervical-cancer-screening',
#        'breast-cancer-screening', 'healthy-pregnancy',
#        'colorectal-cancer-screening', 'personal-health-eservices',
#        'nsc-participating-outlets', 'lose_to_win', 'community-challenge',
#        'testestnew', 'healthytimeout', 'go-hunkle',
#        'nsc-silver-challenge', 'lower-calorie-meals-can-be-satisfying',
#        'national-steps-challenge-campus', 'ga-testing',
#        'CH-TestSync-20240313', 'swtss-shredder-prototype', '1test',
#        '1test-221123', 'wholegrains-food-truck',
#        'tampines-healthy-pathway', 'vaping', '1test-987backup',
#        'healthia', 'national-steps-challenge-youth', 'PDG-TestA', nan,
#        'indian_outreach', 'get-healthhub-track', 'healthhub--parenting',
#        'diabetes-hub-v2', '1test-Program', '10-fun-ways-to-get-active',
#        'Copy-of-1test'], dtype=object)

# %% [markdown]
# - Hence, for now 66 groups
# - There is one url with nan
# - Further analysis to understand groups, especially the smaller groups of 1/2

# %% [markdown]
# <hr>
#
# ### Form Grouped Dataframs

# %%
count = 1
grpList = []
# Create respective dfs for each unique group in `secondLvl`
for group in unique_secondLvl:
    if isinstance(group, str):
        # Replace invalid characters for variable name
        grpName = group.replace('-', '_').replace(' ', '_').replace('nan', 'NaN')
    else:
        grpName = 'NaN'
    # Create new df for each group
    globals()[f"df_{grpName}"] = df_new[df_new['secondLvl'] == group]
    print(f"{count}. Created df_{grpName}")
    grpList.append(f"df_{grpName}")
    count += 1

# Arrange grpList in descending order of count
grpList = sorted(grpList, key=lambda x: len(globals()[x]), reverse=True)
print("\n", grpList)
# Out:
# 1. Created df_Screen_for_Life
# 2. Created df_AAP
# 3. Created df_healthyliving
# 4. Created df_eat_drink_shop_healthy_challenge
# 5. Created df_LetsMoveIt
# 6. Created df_hsg
# 7. Created df_parent_hub
# 8. Created df_nsc
# 9. Created df_nutrition_hub
# 10. Created df_vaccinate
# 11. Created df_diabetes_hub
# 12. Created df_school_dental_programme
# 13. Created df_healthhub_rewards
# 14. Created df_diabetes_mellitus
# 15. Created df_IQuit
# 16. Created df_hiv_prevention
# 17. Created df_children_health_ehb
# 18. Created df_MindSG
# 19. Created df_korangok
# 20. Created df_sexually_transmitted_infections
# 21. Created df_use_antibiotics_right
# 22. Created df_healthy_workplace_ecosystem
# 23. Created df_MoveIt
# 24. Created df_health_promoting_malls
# 25. Created df_strokehub
# 26. Created df_hygiene
# 27. Created df_StayWell
# 28. Created df_justcheckingin
# 29. Created df_howareyoudoing
# 30. Created df_EmotionsExplorer
# 31. Created df_preventive_health
# 32. Created df_pressure_injury
# 33. Created df_Fight_The_Spread
# 34. Created df_cervical_cancer_screening
# 35. Created df_breast_cancer_screening
# 36. Created df_healthy_pregNaNcy
# 37. Created df_colorectal_cancer_screening
# 38. Created df_personal_health_eservices
# 39. Created df_nsc_participating_outlets
# 40. Created df_lose_to_win
# 41. Created df_community_challenge
# 42. Created df_testestnew
# 43. Created df_healthytimeout
# 44. Created df_go_hunkle
# 45. Created df_nsc_silver_challenge
# 46. Created df_lower_calorie_meals_can_be_satisfying
# 47. Created df_national_steps_challenge_campus
# 48. Created df_ga_testing
# 49. Created df_CH_TestSync_20240313
# 50. Created df_swtss_shredder_prototype
# 51. Created df_1test
# 52. Created df_1test_221123
# 53. Created df_wholegrains_food_truck
# 54. Created df_tampines_healthy_pathway
# 55. Created df_vaping
# 56. Created df_1test_987backup
# 57. Created df_healthia
# 58. Created df_national_steps_challenge_youth
# 59. Created df_PDG_TestA
# 60. Created df_NaN
# 61. Created df_indian_outreach
# 62. Created df_get_healthhub_track
# 63. Created df_healthhub__parenting
# 64. Created df_diabetes_hub_v2
# 65. Created df_1test_Program
# 66. Created df_10_fun_ways_to_get_active
# 67. Created df_Copy_of_1test
#
#  ['df_parent_hub', 'df_MindSG', 'df_diabetes_hub', 'df_diabetes_hub_v2', 'df_nsc', 'df_pressure_injury', 'df_nutrition_hub', 'df_LetsMoveIt', 'df_AAP', 'df_healthia', 'df_healthhub__parenting', 'df_IQuit', 'df_korangok', 'df_MoveIt', 'df_Screen_for_Life', 'df_ga_testing', 'df_1test', 'df_indian_outreach', 'df_10_fun_ways_to_get_active', 'df_healthhub_rewards', 'df_howareyoudoing', 'df_1test_221123', 'df_1test_Program', 'df_healthyliving', 'df_eat_drink_shop_healthy_challenge', 'df_hsg', 'df_vaccinate', 'df_school_dental_programme', 'df_diabetes_mellitus', 'df_hiv_prevention', 'df_children_health_ehb', 'df_sexually_transmitted_infections', 'df_use_antibiotics_right', 'df_healthy_workplace_ecosystem', 'df_health_promoting_malls', 'df_strokehub', 'df_hygiene', 'df_StayWell', 'df_justcheckingin', 'df_EmotionsExplorer', 'df_preventive_health', 'df_Fight_The_Spread', 'df_cervical_cancer_screening', 'df_breast_cancer_screening', 'df_healthy_pregNaNcy', 'df_colorectal_cancer_screening', 'df_personal_health_eservices', 'df_nsc_participating_outlets', 'df_lose_to_win', 'df_community_challenge', 'df_testestnew', 'df_healthytimeout', 'df_go_hunkle', 'df_nsc_silver_challenge', 'df_lower_calorie_meals_can_be_satisfying', 'df_national_steps_challenge_campus', 'df_CH_TestSync_20240313', 'df_swtss_shredder_prototype', 'df_wholegrains_food_truck', 'df_tampines_healthy_pathway', 'df_vaping', 'df_1test_987backup', 'df_national_steps_challenge_youth', 'df_PDG_TestA', 'df_get_healthhub_track', 'df_Copy_of_1test', 'df_NaN']

# %% [markdown]
# <hr>
#
# ### Group Understanding

# %%
# Loop through list & display  first few rows of each DataFrame
for df_name in grpList:
    index = grpList.index(df_name)
    print(f"{index+1}. DataFrame: {df_name}")
    globals()[df_name].info()
    display(globals()[df_name].head())
    print("*"*150)
# Out:
# 1. DataFrame: df_parent_hub
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 6 to 273
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      72 non-null     int64
#  1   title                   72 non-null     object
#  2   full_url                72 non-null     object
#  3   extracted_content_body  72 non-null     object
#  4   content_category        72 non-null     object
#  5   secondLvl               72 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 3.9+ KB
#          id                                             title  \
# 6   1453161                                        Parent Hub
# 63  1435221    Parent Hub: Student Immunisation And Screening
# 77  1434753              Parent Hub: 0-2 Years - Healthy Diet
# 79  1435359                             Parent Hub: 0-2 Years
# 80  1435231  Parent Hub: Student Health Centre, Dental Centre
#
#                                              full_url  \
# 6      https://www.healthhub.sg/programmes/parent-hub
# 63  https://www.healthhub.sg/programmes/parent-hub...
# 77  https://www.healthhub.sg/programmes/parent-hub...
# 79  https://www.healthhub.sg/programmes/parent-hub...
# 80  https://www.healthhub.sg/programmes/parent-hub...
#
#                                extracted_content_body   content_category  \
# 6   As parents, you can inspire your children to a...           programs
# 63  CHILD IMMUNISATION AND SCREENING SERVICES\nThe...  program-sub-pages
# 77  fo \n MEAL TIMES To view all content in this s...  program-sub-pages
# 79  Here's How to Team Up with Your Wife for Paren...  program-sub-pages
# 80  STUDENT HEALTH CENTRE AND STUDENT DENTAL CENTR...  program-sub-pages
#
#      secondLvl
# 6   parent-hub
# 63  parent-hub
# 77  parent-hub
# 79  parent-hub
# 80  parent-hub
# ******************************************************************************************************************************************************
# 2. DataFrame: df_MindSG
# <class 'pandas.core.frame.DataFrame'>
# Index: 71 entries, 18 to 310
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      71 non-null     int64
#  1   title                   71 non-null     object
#  2   full_url                71 non-null     object
#  3   extracted_content_body  71 non-null     object
#  4   content_category        71 non-null     object
#  5   secondLvl               71 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 3.9+ KB
#          id   title                                           full_url  \
# 18  1434644  MindSG         https://www.healthhub.sg/programmes/MindSG
# 61  1434919  MindSG  https://www.healthhub.sg/programmes/MindSG/Car...
# 67  1434871  MindSG  https://www.healthhub.sg/programmes/MindSG/Dis...
# 70  1435236  MindSG  https://www.healthhub.sg/programmes/MindSG/Sle...
# 71  1435243  MindSG  https://www.healthhub.sg/programmes/MindSG/See...
#
#                                extracted_content_body   content_category  \
# 18  Redirecting to Discover [/programmes/MindSG/Di...           programs
# 61  Caring for Ourselves\nSleeping Well\nSelect th...  program-sub-pages
# 67  Are we giving the right support?\nLearn how we...  program-sub-pages
# 70  [#helplines]  [#helplines]\n\nSleep Tracking F...  program-sub-pages
# 71  Seeking Support\nChoose what youd like to read...  program-sub-pages
#
#    secondLvl
# 18    MindSG
# 61    MindSG
# 67    MindSG
# 70    MindSG
# 71    MindSG
# ******************************************************************************************************************************************************
# 3. DataFrame: df_diabetes_hub
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, 10 to 303
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      41 non-null     int64
#  1   title                   41 non-null     object
#  2   full_url                41 non-null     object
#  3   extracted_content_body  41 non-null     object
#  4   content_category        41 non-null     object
#  5   secondLvl               41 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.2+ KB
#           id                                          title  \
# 10   1434652         3 Be's To Beat Diabetes | Diabetes Hub
# 11   1434614       Diabetes Hub: Guide to Managing Diabetes
# 106  1435164  Self-monitoring of blood sugar | Diabetes Hub
# 147  1435281       Diabetes Hub: Guide to Managing Diabetes
# 148  1435129                    Be Aware - What is diabetes
#
#                                               full_url  \
# 10    https://www.healthhub.sg/programmes/diabetes-hub
# 11    https://www.healthhub.sg/programmes/diabetes-hub
# 106  https://www.healthhub.sg/programmes/diabetes-h...
# 147  https://www.healthhub.sg/programmes/diabetes-h...
# 148  https://www.healthhub.sg/programmes/diabetes-h...
#
#                                 extracted_content_body   content_category  \
# 10   3 BES TO BEAT DIABETES [/programmes/diabetes-h...           programs
# 11   3 BES TO BEAT DIABETES [/programmes/diabetes-h...           programs
# 106  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
# 147  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
# 148  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
#
#         secondLvl
# 10   diabetes-hub
# 11   diabetes-hub
# 106  diabetes-hub
# 147  diabetes-hub
# 148  diabetes-hub
# ******************************************************************************************************************************************************
# 4. DataFrame: df_diabetes_hub_v2
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 322 to 362
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      25 non-null     int64
#  1   title                   25 non-null     object
#  2   full_url                25 non-null     object
#  3   extracted_content_body  25 non-null     object
#  4   content_category        25 non-null     object
#  5   secondLvl               25 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.4+ KB
#           id                                      title  \
# 322  1435175         Travelling overseas | Diabetes Hub
# 324  1435159               Sleeping well | Diabetes Hub
# 325  1435136              Healthy eating | Diabetes Hub
# 327  1435156          Stigma of diabetes | Diabetes Hub
# 328  1435147  Avoid smoking and drinking | Diabetes Hub
#
#                                               full_url  \
# 322  https://www.healthhub.sg/programmes/diabetes-h...
# 324  https://www.healthhub.sg/programmes/diabetes-h...
# 325  https://www.healthhub.sg/programmes/diabetes-h...
# 327  https://www.healthhub.sg/programmes/diabetes-h...
# 328  https://www.healthhub.sg/programmes/diabetes-h...
#
#                                 extracted_content_body   content_category  \
# 322  3 BEaTMS TO BEAT DIABETES [/programmes/diabete...  program-sub-pages
# 324  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
# 325  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
# 327  3 BES TO BEAT DIABETES [/programmes/diabetes-h...  program-sub-pages
# 328  3 BEaTMS TO BEAT DIABETES [/programmes/diabete...  program-sub-pages
#
#            secondLvl
# 322  diabetes-hub-v2
# 324  diabetes-hub-v2
# 325  diabetes-hub-v2
# 327  diabetes-hub-v2
# 328  diabetes-hub-v2
# ******************************************************************************************************************************************************
# 5. DataFrame: df_nsc
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 7 to 276
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      14 non-null     int64
#  1   title                   14 non-null     object
#  2   full_url                14 non-null     object
#  3   extracted_content_body  14 non-null     object
#  4   content_category        14 non-null     object
#  5   secondLvl               14 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 784.0+ bytes
#           id                      title  \
# 7    1453207  National Steps Challenge™
# 64   1434809  National Steps Challenge™
# 76   1434811  National Steps Challenge™
# 99   1434803  National Steps Challenge™
# 183  1434969  National Steps Challenge™
#
#                                               full_url  \
# 7              https://www.healthhub.sg/programmes/nsc
# 64   https://www.healthhub.sg/programmes/nsc/tracke...
# 76    https://www.healthhub.sg/programmes/nsc/support/
# 99   https://www.healthhub.sg/programmes/nsc/corpor...
# 183  https://www.healthhub.sg/programmes/nsc/corpor...
#
#                                 extracted_content_body   content_category  \
# 7    Previous [#nscMastheadCarousel] Next [#nscMast...           programs
# 64   < Previous [#nscMastheadCarousel] > Next [#nsc...  program-sub-pages
# 76   Previous [#nscMastheadCarousel] > Next [#nscMa...  program-sub-pages
# 99   < /> Previous [#nscMastheadCarousel] > Next [#...  program-sub-pages
# 183  <Previous [#nscMastheadCarousel] >Next [#nscMa...  program-sub-pages
#
#     secondLvl
# 7         nsc
# 64        nsc
# 76        nsc
# 99        nsc
# 183       nsc
# ******************************************************************************************************************************************************
# 6. DataFrame: df_pressure_injury
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 32 to 253
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      14 non-null     int64
#  1   title                   14 non-null     object
#  2   full_url                14 non-null     object
#  3   extracted_content_body  14 non-null     object
#  4   content_category        14 non-null     object
#  5   secondLvl               14 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 784.0+ bytes
#           id                title  \
# 32   1434628  Pressure Injury Hub
# 144  1435123  Pressure Injury Hub
# 180  1435275  Pressure Injury Hub
# 185  1435149  Pressure Injury Hub
# 231  1435116  Pressure Injury Hub
#
#                                               full_url  \
# 32   https://www.healthhub.sg/programmes/pressure-i...
# 144  https://www.healthhub.sg/programmes/pressure-i...
# 180  https://www.healthhub.sg/programmes/pressure-i...
# 185  https://www.healthhub.sg/programmes/pressure-i...
# 231  https://www.healthhub.sg/programmes/pressure-i...
#
#                                 extracted_content_body   content_category  \
# 32   Welcome to\n\nPressure Injury Hub\nA Pressure ...           programs
# 144  Menu - Pressure Injury Hub\n- Preventing Press...  program-sub-pages
# 180  Menu - Pressure Injury Hub\n- Preventing Press...  program-sub-pages
# 185  Menu - Pressure Injury Hub\n- Preventing Press...  program-sub-pages
# 231  Menu - Pressure Injury Hub\n- Preventing Press...  program-sub-pages
#
#            secondLvl
# 32   pressure-injury
# 144  pressure-injury
# 180  pressure-injury
# 185  pressure-injury
# 231  pressure-injury
# ******************************************************************************************************************************************************
# 7. DataFrame: df_nutrition_hub
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 8 to 279
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      12 non-null     int64
#  1   title                   12 non-null     object
#  2   full_url                12 non-null     object
#  3   extracted_content_body  12 non-null     object
#  4   content_category        12 non-null     object
#  5   secondLvl               12 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 672.0+ bytes
#          id                                       title  \
# 8   1434656  Nutrition Facts and Tips on Eating Healthy
# 65  1435018           Reduce Your Salt And Sugar Intake
# 66  1472348                                 Nutri-Grade
# 68  1435021         Make Healthy Food & Grocery Choices
# 69  1435017         Nutritious Foods For A Healthy Diet
#
#                                              full_url  \
# 8   https://www.healthhub.sg/programmes/nutrition-hub
# 65  https://www.healthhub.sg/programmes/nutrition-...
# 66  https://www.healthhub.sg/programmes/nutrition-...
# 68  https://www.healthhub.sg/programmes/nutrition-...
# 69  https://www.healthhub.sg/programmes/nutrition-...
#
#                                extracted_content_body   content_category  \
# 8   Menu   [#clear]\n\nMenu   [#clear]\n\nMenu   [...           programs
# 65  Menu  [#]  [#clear]\n\nMenu  [#]  [#clear]\n\n...  program-sub-pages
# 66  Menu   [#clear]\n\nMenu   [#clear]\n\nMenu   [...  program-sub-pages
# 68  Menu   [#clear]\n\nResources\nPick up useful t...  program-sub-pages
# 69  Menu   [#clear]\n\nEat More\nEat more nutritio...  program-sub-pages
#
#         secondLvl
# 8   nutrition-hub
# 65  nutrition-hub
# 66  nutrition-hub
# 68  nutrition-hub
# 69  nutrition-hub
# ******************************************************************************************************************************************************
# 8. DataFrame: df_LetsMoveIt
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 4 to 258
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      9 non-null      int64
#  1   title                   9 non-null      object
#  2   full_url                9 non-null      object
#  3   extracted_content_body  9 non-null      object
#  4   content_category        9 non-null      object
#  5   secondLvl               9 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 504.0+ bytes
#           id                                 title  \
# 4    1434657  Great things start when you MOVE IT!
# 62   1480345  Great things start when you MOVE IT!
# 100  1435259  Great things start when you MOVE IT!
# 113  1435239  Great things start when you MOVE IT!
# 119  1435229  Great things start when you MOVE IT!
#
#                                               full_url  \
# 4       https://www.healthhub.sg/programmes/LetsMoveIt
# 62   https://www.healthhub.sg/programmes/LetsMoveIt...
# 100  https://www.healthhub.sg/programmes/LetsMoveIt...
# 113  https://www.healthhub.sg/programmes/LetsMoveIt...
# 119  https://www.healthhub.sg/programmes/LetsMoveIt...
#
#                                 extracted_content_body   content_category  \
# 4    [https://go.gov.sg/h365-moveit]\n\nGet Moving ...           programs
# 62   [https://go.gov.sg/useh365]  [https://go.gov.s...  program-sub-pages
# 100  Your quick guide to book an event\nFor a pdf v...  program-sub-pages
# 113  Ready for a bigger challenge? Explore a variet...  program-sub-pages
# 119  Well done on taking the first steps to an acti...  program-sub-pages
#
#       secondLvl
# 4    LetsMoveIt
# 62   LetsMoveIt
# 100  LetsMoveIt
# 113  LetsMoveIt
# 119  LetsMoveIt
# ******************************************************************************************************************************************************
# 9. DataFrame: df_AAP
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 1 to 176
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      8 non-null      int64
#  1   title                   8 non-null      object
#  2   full_url                8 non-null      object
#  3   extracted_content_body  8 non-null      object
#  4   content_category        8 non-null      object
#  5   secondLvl               8 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 448.0+ bytes
#           id                                            title  \
# 1    1434612                    Live Well, Age Well Programme
# 85   1434907                           See, Hear & Eat Better
# 109  1434895          7 Easy Exercises to an Active Lifestyle
# 122  1434903                            You can spot a stroke
# 137  1434905  Age Healthier When You Cook Right And Eat Smart
#
#                                               full_url  \
# 1              https://www.healthhub.sg/programmes/AAP
# 85   https://www.healthhub.sg/programmes/AAP/functi...
# 109  https://www.healthhub.sg/programmes/AAP/easy-e...
# 122    https://www.healthhub.sg/programmes/AAP/stroke/
# 137  https://www.healthhub.sg/programmes/AAP/nutrit...
#
#                                 extracted_content_body   content_category  \
# 1    By 7 February 2023, all users must perform a o...           programs
# 85   Project Silver Screen is an affordable, nation...  program-sub-pages
# 109  Back to Healthy Ageing [/programmes/Healthy_Ag...  program-sub-pages
# 122  Back to Healthy Ageing [/programmes/Healthy_Ag...  program-sub-pages
# 137  Back to Healthy Ageing [http://www.healthhub.s...  program-sub-pages
#
#     secondLvl
# 1         AAP
# 85        AAP
# 109       AAP
# 122       AAP
# 137       AAP
# ******************************************************************************************************************************************************
# 10. DataFrame: df_healthia
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 57 to 363
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      7 non-null      int64
#  1   title                   7 non-null      object
#  2   full_url                7 non-null      object
#  3   extracted_content_body  7 non-null      object
#  4   content_category        7 non-null      object
#  5   secondLvl               7 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 392.0+ bytes
#           id                title  \
# 57   1434618             Healthia
# 323  1434805  Dr Kimberly Douglas
# 333  1434777             About Us
# 346  1434801              level-1
# 350  1434796             Our Team
#
#                                               full_url  \
# 57        https://www.healthhub.sg/programmes/healthia
# 323  https://www.healthhub.sg/programmes/healthia/d...
# 333  https://www.healthhub.sg/programmes/healthia/a...
# 346  https://www.healthhub.sg/programmes/healthia/l...
# 350  https://www.healthhub.sg/programmes/healthia/t...
#
#                                 extracted_content_body   content_category  \
# 57   [/programs/Lists/Programs/index.html]\n- Home\...           programs
# 323  [/programs/Lists/Program Sub Pages/index.html]...  program-sub-pages
# 333  [/programs/Lists/Program Sub Pages/index.html]...  program-sub-pages
# 346                           athis is level 1 content  program-sub-pages
# 350  [/programs/Lists/Program Sub Pages/index.html]...  program-sub-pages
#
#     secondLvl
# 57   healthia
# 323  healthia
# 333  healthia
# 346  healthia
# 350  healthia
# ******************************************************************************************************************************************************
# 11. DataFrame: df_healthhub__parenting
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 315 to 321
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      7 non-null      int64
#  1   title                   7 non-null      object
#  2   full_url                7 non-null      object
#  3   extracted_content_body  7 non-null      object
#  4   content_category        7 non-null      object
#  5   secondLvl               7 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 392.0+ bytes
#           id                                    title  \
# 315  1434831                  Be Gentle With Yourself
# 316  1434921                        Happy 1-Year Old!
# 317  1434889     Is Your Baby Throwing Things Around?
# 318  1434873                       Separation Anxiety
# 319  1434911  Time For Baby, Time For Mummy And Daddy
#
#                                               full_url  \
# 315  https://www.healthhub.sg/programmes/healthhub-...
# 316  https://www.healthhub.sg/programmes/healthhub-...
# 317  https://www.healthhub.sg/programmes/healthhub-...
# 318  https://www.healthhub.sg/programmes/healthhub-...
# 319  https://www.healthhub.sg/programmes/healthhub-...
#
#                                 extracted_content_body   content_category  \
# 315  Excited to hold your baby in your arms but fee...  program-sub-pages
# 316  Your baby is 1 year old! YouaTMve made it!\nFo...  program-sub-pages
# 317  Cannot determine when your baby is cute or nau...  program-sub-pages
# 318  Preparing to go back to work? Help baby cope w...  program-sub-pages
# 319  Is your baby anxious around strangers, clingin...  program-sub-pages
#
#                 secondLvl
# 315  healthhub--parenting
# 316  healthhub--parenting
# 317  healthhub--parenting
# 318  healthhub--parenting
# 319  healthhub--parenting
# ******************************************************************************************************************************************************
# 12. DataFrame: df_IQuit
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 15 to 305
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      6 non-null      int64
#  1   title                   6 non-null      object
#  2   full_url                6 non-null      object
#  3   extracted_content_body  6 non-null      object
#  4   content_category        6 non-null      object
#  5   secondLvl               6 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 336.0+ bytes
#           id             title  \
# 15   1434716  I Quit Programme
# 83   1435084              Vape
# 116  1435096              Vape
# 239  1500502              Vape
# 304  1476504              Vape
#
#                                               full_url  \
# 15           https://www.healthhub.sg/programmes/IQuit
# 83    https://www.healthhub.sg/programmes/IQuit/e-cig/
# 116  https://www.healthhub.sg/programmes/IQuit/e-ci...
# 239  https://www.healthhub.sg/programmes/IQuit/e-ci...
# 304  https://www.healthhub.sg/programmes/IQuit/e-ci...
#
#                                 extracted_content_body   content_category  \
# 15   Toggle to find out more.\nI Quit\nProgramme Al...           programs
# 83   Toggle to find out more. I Quit Programme [/pr...  program-sub-pages
# 116  Toggle to find out more. I Quit Programme [/pr...  program-sub-pages
# 239  I Quit Programme [/programmes/88/IQuit/#home]\...  program-sub-pages
# 304  I Quit Programme [/programmes/88/IQuit/#home]\...  program-sub-pages
#
#     secondLvl
# 15      IQuit
# 83      IQuit
# 116     IQuit
# 239     IQuit
# 304     IQuit
# ******************************************************************************************************************************************************
# 13. DataFrame: df_korangok
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 19 to 245
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      5 non-null      int64
#  1   title                   5 non-null      object
#  2   full_url                5 non-null      object
#  3   extracted_content_body  5 non-null      object
#  4   content_category        5 non-null      object
#  5   secondLvl               5 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 280.0+ bytes
#           id                                 title  \
# 19   1434636                            Korang OK?
# 161  1435115  Korang OK? - Fun Ways to Stay Active
# 240  1435109        Korang OK? - Mental Well-being
# 241  1435113           Korang OK? - IQuit for Good
# 245  1435111          Korang OK? - Screen for Life
#
#                                               full_url  \
# 19        https://www.healthhub.sg/programmes/korangok
# 161  https://www.healthhub.sg/programmes/korangok/f...
# 240  https://www.healthhub.sg/programmes/korangok/m...
# 241  https://www.healthhub.sg/programmes/korangok/q...
# 245  https://www.healthhub.sg/programmes/korangok/s...
#
#                                 extracted_content_body   content_category  \
# 19   [/programmes/korangok]\n- Home\n- Healthier Ch...           programs
# 161  [/programmes/korangok/]\n- Home\n- Healthier C...  program-sub-pages
# 240  [/programmes/korangok/]\n- Home\n- Healthier C...  program-sub-pages
# 241  [/programmes/korangok/]\n- Home\n- Healthier C...  program-sub-pages
# 245  [/programmes/korangok/]\n- Home\n- Healthier C...  program-sub-pages
#
#     secondLvl
# 19   korangok
# 161  korangok
# 240  korangok
# 241  korangok
# 245  korangok
# ******************************************************************************************************************************************************
# 14. DataFrame: df_MoveIt
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 23 to 311
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      5 non-null      int64
#  1   title                   5 non-null      object
#  2   full_url                5 non-null      object
#  3   extracted_content_body  5 non-null      object
#  4   content_category        5 non-null      object
#  5   secondLvl               5 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 280.0+ bytes
#           id                                 title  \
# 23   1434598  Great things start when you MOVE IT!
# 98   1435347  Great things start when you MOVE IT!
# 123  1435340  Great things start when you MOVE IT!
# 126  1434986  Great things start when you MOVE IT!
# 311  1435344  Great things start when you MOVE IT!
#
#                                               full_url  \
# 23          https://www.healthhub.sg/programmes/MoveIt
# 98   https://www.healthhub.sg/programmes/MoveIt/mov...
# 123  https://www.healthhub.sg/programmes/MoveIt/mov...
# 126  https://www.healthhub.sg/programmes/MoveIt/mov...
# 311  https://www.healthhub.sg/programmes/MoveIt/mov...
#
#                                 extracted_content_body   content_category  \
# 23   By 7 February 2023, all users must perform a o...           programs
# 98   Starting 12 July 2021, participants who do not...  program-sub-pages
# 123  Starting 12 July 2021, participants who do not...  program-sub-pages
# 126  Starting 12 July 2021, participants who do not...  program-sub-pages
# 311  In line with MOHs advisory on\n20 July 2021\no...  program-sub-pages
#
#     secondLvl
# 23     MoveIt
# 98     MoveIt
# 123    MoveIt
# 126    MoveIt
# 311    MoveIt
# ******************************************************************************************************************************************************
# 15. DataFrame: df_Screen_for_Life
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 93
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      4 non-null      int64
#  1   title                   4 non-null      object
#  2   full_url                4 non-null      object
#  3   extracted_content_body  4 non-null      object
#  4   content_category        4 non-null      object
#  5   secondLvl               4 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 224.0+ bytes
#          id                                              title  \
# 0   1434688  Screen for Life - National Health Screening Pr...
# 82  1435054  Screen for Life - National Health Screening Pr...
# 90  1435061  Screen for Life - National Health Screening Pr...
# 93  1435053  Screen for Life - National Health Screening Pr...
#
#                                              full_url  \
# 0   https://www.healthhub.sg/programmes/Screen_for...
# 82  https://www.healthhub.sg/programmes/Screen_for...
# 90  https://www.healthhub.sg/programmes/Screen_for...
# 93  https://www.healthhub.sg/programmes/Screen_for...
#
#                                extracted_content_body   content_category  \
# 0   We note that some users have experienced issue...           programs
# 82  START YOUR SCREENING JOURNEY HERE\n- 18 - 24 y...  program-sub-pages
# 90  We have received feedback from some members of...  program-sub-pages
# 93  Download our Screen for Life booklet: English ...  program-sub-pages
#
#           secondLvl
# 0   Screen_for_Life
# 82  Screen_for_Life
# 90  Screen_for_Life
# 93  Screen_for_Life
# ******************************************************************************************************************************************************
# 16. DataFrame: df_ga_testing
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 48 to 348
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      3 non-null      int64
#  1   title                   3 non-null      object
#  2   full_url                3 non-null      object
#  3   extracted_content_body  3 non-null      object
#  4   content_category        3 non-null      object
#  5   secondLvl               3 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 168.0+ bytes
#           id       title                                           full_url  \
# 48   1434640  GA-Testing     https://www.healthhub.sg/programmes/ga-testing
# 338  1435245   Persona B  https://www.healthhub.sg/programmes/ga-testing...
# 348  1435247   Persona A  https://www.healthhub.sg/programmes/ga-testing...
#
#                                 extracted_content_body   content_category  \
# 48   Social media share\nShare\npersona A:  [/progr...           programs
# 338                                                 a-  program-sub-pages
# 348                                                 a-  program-sub-pages
#
#       secondLvl
# 48   ga-testing
# 338  ga-testing
# 348  ga-testing
# ******************************************************************************************************************************************************
# 17. DataFrame: df_1test
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 51 to 361
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      3 non-null      int64
#  1   title                   3 non-null      object
#  2   full_url                3 non-null      object
#  3   extracted_content_body  3 non-null      object
#  4   content_category        3 non-null      object
#  5   secondLvl               3 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 168.0+ bytes
#           id                title  \
# 51   1468234           1test1test
# 337  1468237     1test-sub-sya333
# 361  1468676  Program Sub level 1
#
#                                               full_url  \
# 51           https://www.healthhub.sg/programmes/1test
# 337  https://www.healthhub.sg/programmes/1test/1tes...
# 361  https://www.healthhub.sg/programmes/1test/sya-...
#
#                                 extracted_content_body   content_category  \
# 51            test program entry - 15/11/2023\nabc 123           programs
# 337  Sub-program entry - 15/11/2023 - sya33333 [htt...  program-sub-pages
# 361  HealthHub\nRelaxation-ExerciseHealthhub\nList ...  program-sub-pages
#
#     secondLvl
# 51      1test
# 337     1test
# 361     1test
# ******************************************************************************************************************************************************
# 18. DataFrame: df_indian_outreach
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 247 to 313
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      3 non-null      int64
#  1   title                   3 non-null      object
#  2   full_url                3 non-null      object
#  3   extracted_content_body  3 non-null      object
#  4   content_category        3 non-null      object
#  5   secondLvl               3 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 168.0+ bytes
#           id                                     title  \
# 247  1434980  Take the first step with your loved ones
# 312  1434979  Take the first step with your loved ones
# 313  1434983  Take the first step with your loved ones
#
#                                               full_url  \
# 247  https://www.healthhub.sg/programmes/indian_out...
# 312  https://www.healthhub.sg/programmes/indian_out...
# 313  https://www.healthhub.sg/programmes/indian_out...
#
#                                 extracted_content_body   content_category  \
# 247  - Menu\n- Home\n- Healthy Eating\n- Physical A...  program-sub-pages
# 312  - Menu\n- Home\n- Healthy Eating\n- Physical A...  program-sub-pages
# 313  - Menu\n- Home\n- Healthy Eating\n- Physical A...  program-sub-pages
#
#            secondLvl
# 247  indian_outreach
# 312  indian_outreach
# 313  indian_outreach
# ******************************************************************************************************************************************************
# 19. DataFrame: df_10_fun_ways_to_get_active
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 343 to 354
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      3 non-null      int64
#  1   title                   3 non-null      object
#  2   full_url                3 non-null      object
#  3   extracted_content_body  3 non-null      object
#  4   content_category        3 non-null      object
#  5   secondLvl               3 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 168.0+ bytes
#           id                           title  \
# 343  1435336  test page level 1 - 14-10-2020
# 352  1435343    test page level 2-14-10-2020
# 354  1435339    test page level 3-14-10-2020
#
#                                               full_url extracted_content_body  \
# 343  https://www.healthhub.sg/programmes/10-fun-way...   athis is a test page
# 352  https://www.healthhub.sg/programmes/10-fun-way...     atest page level 2
# 354  https://www.healthhub.sg/programmes/10-fun-way...     atest page level 3
#
#       content_category                  secondLvl
# 343  program-sub-pages  10-fun-ways-to-get-active
# 352  program-sub-pages  10-fun-ways-to-get-active
# 354  program-sub-pages  10-fun-ways-to-get-active
# ******************************************************************************************************************************************************
# 20. DataFrame: df_healthhub_rewards
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 13 to 78
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      2 non-null      int64
#  1   title                   2 non-null      object
#  2   full_url                2 non-null      object
#  3   extracted_content_body  2 non-null      object
#  4   content_category        2 non-null      object
#  5   secondLvl               2 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 112.0+ bytes
#          id                  title  \
# 13  1434642  HPB Rewards Programme
# 78  1434795  HPB Rewards Programme
#
#                                              full_url  \
# 13  https://www.healthhub.sg/programmes/healthhub-...
# 78  https://www.healthhub.sg/programmes/healthhub-...
#
#                                extracted_content_body   content_category  \
# 13  By 7 February 2023, all users must perform a o...           programs
# 78  Frequently Asked Questions\n\nHPB Healthy 365 ...  program-sub-pages
#
#             secondLvl
# 13  healthhub-rewards
# 78  healthhub-rewards
# ******************************************************************************************************************************************************
# 21. DataFrame: df_howareyoudoing
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 29 to 202
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      2 non-null      int64
#  1   title                   2 non-null      object
#  2   full_url                2 non-null      object
#  3   extracted_content_body  2 non-null      object
#  4   content_category        2 non-null      object
#  5   secondLvl               2 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 112.0+ bytes
#           id                                     title  \
# 29   1434616  Take the first step with your loved ones
# 202  1434977  Take the first step with your loved ones
#
#                                               full_url  \
# 29   https://www.healthhub.sg/programmes/howareyoud...
# 202  https://www.healthhub.sg/programmes/howareyoud...
#
#                                 extracted_content_body   content_category  \
# 29   [https://form.gov.sg/6448dcba7765f10012211b34]...           programs
# 202  - Menu\n- Home\n- Healthy Eating\n- Physical A...  program-sub-pages
#
#           secondLvl
# 29   howareyoudoing
# 202  howareyoudoing
# ******************************************************************************************************************************************************
# 22. DataFrame: df_1test_221123
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 52 to 340
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      2 non-null      int64
#  1   title                   2 non-null      object
#  2   full_url                2 non-null      object
#  3   extracted_content_body  2 non-null      object
#  4   content_category        2 non-null      object
#  5   secondLvl               2 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 112.0+ bytes
#           id         title                                           full_url  \
# 52   1469303  1test 221123   https://www.healthhub.sg/programmes/1test-221123
# 340  1482060        test72  https://www.healthhub.sg/programmes/1test-2211...
#
#                                 extracted_content_body   content_category  \
# 52   meal-log-tool-faqs [https://ch-api.healthhub.s...           programs
# 340  School Beverage List Apr 2024 As of Mar 2024 [...  program-sub-pages
#
#         secondLvl
# 52   1test-221123
# 340  1test-221123
# ******************************************************************************************************************************************************
# 23. DataFrame: df_1test_Program
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 326 to 341
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      2 non-null      int64
#  1   title                   2 non-null      object
#  2   full_url                2 non-null      object
#  3   extracted_content_body  2 non-null      object
#  4   content_category        2 non-null      object
#  5   secondLvl               2 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 112.0+ bytes
#           id              title  \
# 326  1474295             1tes23
# 341  1468228  1test programsub1
#
#                                               full_url  \
# 326  https://www.healthhub.sg/programmes/1test-Prog...
# 341  https://www.healthhub.sg/programmes/1test-Prog...
#
#                                 extracted_content_body   content_category  \
# 326  EDSH_Challenge_Event_Locations [https://ch-api...  program-sub-pages
# 341  IQuit-Terms-and-Conditions_8Feb24 [https://ch-...  program-sub-pages
#
#          secondLvl
# 326  1test-Program
# 341  1test-Program
# ******************************************************************************************************************************************************
# 24. DataFrame: df_healthyliving
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 2 to 2
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#         id                title  \
# 2  1434660  The Healthy 365 App
#
#                                             full_url  \
# 2  https://www.healthhub.sg/programmes/healthyliving
#
#                               extracted_content_body content_category  \
# 2  [https://go.gov.sg/useh365]  [https://go.gov.s...         programs
#
#        secondLvl
# 2  healthyliving
# ******************************************************************************************************************************************************
# 25. DataFrame: df_eat_drink_shop_healthy_challenge
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 3 to 3
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#         id                               title  \
# 3  1434580  Eat, Drink, Shop Healthy Challenge
#
#                                             full_url  \
# 3  https://www.healthhub.sg/programmes/eat-drink-...
#
#                               extracted_content_body content_category  \
# 3  Menu   [#clear]\n\nMenu   [#clear]\n\nMenu   [...         programs
#
#                           secondLvl
# 3  eat-drink-shop-healthy-challenge
# ******************************************************************************************************************************************************
# 26. DataFrame: df_hsg
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 5 to 5
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#         id                               title  \
# 5  1434650  Healthier SG | Enrol via HealthHub
#
#                                   full_url  \
# 5  https://www.healthhub.sg/programmes/hsg
#
#                               extracted_content_body content_category  \
# 5  [#] \nHealthier You, with Healthier SG Enrol n...         programs
#
#   secondLvl
# 5       hsg
# ******************************************************************************************************************************************************
# 27. DataFrame: df_vaccinate
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 9 to 9
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#         id                                  title  \
# 9  1434610  STAY ONE STEP AHEAD WITH VACCINATIONS
#
#                                         full_url  \
# 9  https://www.healthhub.sg/programmes/vaccinate
#
#                               extracted_content_body content_category  \
# 9  65 years old and above?\nClick here to book yo...         programs
#
#    secondLvl
# 9  vaccinate
# ******************************************************************************************************************************************************
# 28. DataFrame: df_school_dental_programme
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 12 to 12
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id                            title  \
# 12  1434596  Youth Preventive Dental Service
#
#                                              full_url  \
# 12  https://www.healthhub.sg/programmes/school_den...
#
#                                extracted_content_body content_category  \
# 12  YPDS also provides free basic dental services ...         programs
#
#                   secondLvl
# 12  school_dental_programme
# ******************************************************************************************************************************************************
# 29. DataFrame: df_diabetes_mellitus
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 14 to 14
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id                title  \
# 14  1434708  Let’s BEAT Diabetes
#
#                                              full_url  \
# 14  https://www.healthhub.sg/programmes/diabetes-m...
#
#                                extracted_content_body content_category  \
# 14  [#smitha-popup-close]\n\nCan I Really Reverse ...         programs
#
#             secondLvl
# 14  diabetes-mellitus
# ******************************************************************************************************************************************************
# 30. DataFrame: df_hiv_prevention
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 16 to 16
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
# ...
#
#     secondLvl
# 44  go-hunkle
# ******************************************************************************************************************************************************
# 54. DataFrame: df_nsc_silver_challenge
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 45 to 45
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id                                       title  \
# 45  1434626  National Steps Challenge™ Silver Challenge
#
#                                              full_url  \
# 45  https://www.healthhub.sg/programmes/nsc-silver...
#
#                                extracted_content_body content_category  \
# 45  In line with MOHs advisory on\n20 July 2021\no...         programs
#
#                secondLvl
# 45  nsc-silver-challenge
# ******************************************************************************************************************************************************
# 55. DataFrame: df_lower_calorie_meals_can_be_satisfying
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 46 to 46
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id                                  title  \
# 46  1434576  Lower-calorie meals can be satisfying
#
#                                              full_url  \
# 46  https://www.healthhub.sg/programmes/lower-calo...
#
#                                extracted_content_body content_category  \
# 46  Lower in calories, just as satisfying\njust as...         programs
#
#                                 secondLvl
# 46  lower-calorie-meals-can-be-satisfying
# ******************************************************************************************************************************************************
# 56. DataFrame: df_national_steps_challenge_campus
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 47 to 47
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id                                       title  \
# 47  1434622  National Steps Challenge™ Campus Challenge
#
#                                              full_url  \
# 47  https://www.healthhub.sg/programmes/national-s...
#
#                                extracted_content_body content_category  \
# 47  The National Steps Challenge\nSeason 5 Campus ...         programs
#
#                           secondLvl
# 47  national-steps-challenge-campus
# ******************************************************************************************************************************************************
# 57. DataFrame: df_CH_TestSync_20240313
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 49 to 49
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id                 title  \
# 49  1489198  CH-TestSync-20240313
#
#                                              full_url extracted_content_body  \
# 49  https://www.healthhub.sg/programmes/CH-TestSyn...   CH-TestSync-20240313
#
#    content_category             secondLvl
# 49         programs  CH-TestSync-20240313
# ******************************************************************************************************************************************************
# 58. DataFrame: df_swtss_shredder_prototype
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 50 to 50
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id                     title  \
# 50  1434630  SWTSS Shredder Prototype
#
#                                              full_url  \
# 50  https://www.healthhub.sg/programmes/swtss-shre...
#
#                                extracted_content_body content_category  \
# 50  Click here for the latest COVID-19 UPDATES [ht...         programs
#
#                    secondLvl
# 50  swtss-shredder-prototype
# ******************************************************************************************************************************************************
# 59. DataFrame: df_wholegrains_food_truck
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 53 to 53
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id                   title  \
# 53  1434582  Wholegrains Food Truck
#
#                                              full_url  \
# 53  https://www.healthhub.sg/programmes/wholegrain...
#
#                                extracted_content_body content_category  \
# 53  [/programmes/42/get-healthy#what-is-wholegrain...         programs
#
#                  secondLvl
# 53  wholegrains-food-truck
# ******************************************************************************************************************************************************
# 60. DataFrame: df_tampines_healthy_pathway
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 54 to 54
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id                                title  \
# 54  1434674  Healthy Pathway & Healthy Community
#
#                                              full_url  \
# 54  https://www.healthhub.sg/programmes/tampines-h...
#
#                                extracted_content_body content_category  \
# 54  Every step you take gets you closer to great p...         programs
#
#                    secondLvl
# 54  tampines-healthy-pathway
# ******************************************************************************************************************************************************
# 61. DataFrame: df_vaping
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 55 to 55
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id         title                                    full_url  \
# 55  1434600  E-Cigarettes  https://www.healthhub.sg/programmes/vaping
#
#                                extracted_content_body content_category  \
# 55  What are E-cigarettes?\n\nInside an E-cigarett...         programs
#
#    secondLvl
# 55    vaping
# ******************************************************************************************************************************************************
# 62. DataFrame: df_1test_987backup
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 56 to 56
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id    title                                           full_url  \
# 56  1468627  1test-2  https://www.healthhub.sg/programmes/1test-987b...
#
#                                extracted_content_body content_category  \
# 56  FS Schedule Jun-Aug 2024 as at 10 Jun 2024 [ht...         programs
#
#           secondLvl
# 56  1test-987backup
# ******************************************************************************************************************************************************
# 63. DataFrame: df_national_steps_challenge_youth
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 58 to 58
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id                                      title  \
# 58  1434594  National Steps Challenge™ Youth Challenge
#
#                                              full_url  \
# 58  https://www.healthhub.sg/programmes/national-s...
#
#                                extracted_content_body content_category  \
# 58  The National Steps Challenge\nSeason 5 Youth C...         programs
#
#                          secondLvl
# 58  national-steps-challenge-youth
# ******************************************************************************************************************************************************
# 64. DataFrame: df_PDG_TestA
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 59 to 59
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#          id      title                                       full_url  \
# 59  1476359  PDG-TestA  https://www.healthhub.sg/programmes/PDG-TestA
#
#                                extracted_content_body content_category  \
# 59  Assets [https://ch-api.healthhub.sg/api/public...         programs
#
#     secondLvl
# 59  PDG-TestA
# ******************************************************************************************************************************************************
# 65. DataFrame: df_get_healthhub_track
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 314 to 314
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#           id title                                           full_url  \
# 314  1435311  FAQs  https://www.healthhub.sg/programmes/get-health...
#
#                                 extracted_content_body   content_category  \
# 314  HealthHub Track Login: Facebook and Email Logi...  program-sub-pages
#
#                secondLvl
# 314  get-healthhub-track
# ******************************************************************************************************************************************************
# 66. DataFrame: df_Copy_of_1test
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 353 to 353
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1 non-null      int64
#  1   title                   1 non-null      object
#  2   full_url                1 non-null      object
#  3   extracted_content_body  1 non-null      object
#  4   content_category        1 non-null      object
#  5   secondLvl               1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 56.0+ bytes
#           id         title                                           full_url  \
# 353  1470565  test article  https://www.healthhub.sg/programmes/Copy-of-1t...
#
#                                 extracted_content_body   content_category  \
# 353  Website List_As of 31 Oct 2023 [https://ch-api...  program-sub-pages
#
#          secondLvl
# 353  Copy-of-1test
# ******************************************************************************************************************************************************
# 67. DataFrame: df_NaN
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      0 non-null      int64
#  1   title                   0 non-null      object
#  2   full_url                0 non-null      object
#  3   extracted_content_body  0 non-null      object
#  4   content_category        0 non-null      object
#  5   secondLvl               0 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 0.0+ bytes
# Empty DataFrame
# Columns: [id, title, full_url, extracted_content_body, content_category, secondLvl]
# Index: []
# ******************************************************************************************************************************************************

# %% [markdown]
# #### Summary of each Group

# %% [markdown]
# Legend:
# - *, #, ~: to be grouped together
# - -: to be removed
#
# 1. parent-hub:              taking care of children
# 2. MindSG:                  mental well being
# 3. diabetes-hub:            *diabetes
# 4. diabetes-hub-v2:         *diabetes, url have 404 error, can combine with above group
# 5. pressure-injury:         pressure injury
# 6. nsc:                     national steps challenge
# 7. nutrition-hub:           nurition
# 8. LetsMoveIt:              #physical activity
# 9. AAP:                     live well, age well (elderly)
# 10. healthhub--parenting:    taking care of baby
# 11. IQuit:                   ~vaping
# 12. MoveIt:                  #physical activity
# 13. korangok:                malay community
# 14. indian_outreach:         indian community
# 15. Screen_for_Life:         screenings
# 16. healthia:                healthia clinic information (take note bcos info seems off)
# 17. 1test-Program:            - API test calls (remove)
# 18. 1test:                    - API test calls (remove)
# 19. 1test-221123:             - API test calls (remove)
# 20. healthhub-rewards:        hh rewards
# 21. get-healthhub-track:      hh track
# 22. howareyoudoing:           - menu list (remove)
# 23. Copy-of-1test:            ~parent child vaping
# 24. ga-testing                - gibbish content (remove)
# 25. 10-fun-ways-to-get-active - test content (remove)
#
# Hence, total expected a final of 16 groups.

# %% [markdown]
# <hr>
#
# ### Data Preparation
#
# Final Clean, Removal & Merge of Dfs

# %% [markdown]
# #### Initial Group List

# %%
print(len(grpList))
grpList
# Out:
# 67
# ['df_parent_hub',
#  'df_MindSG',
#  'df_diabetes_hub',
#  'df_diabetes_hub_v2',
#  'df_nsc',
#  'df_pressure_injury',
#  'df_nutrition_hub',
#  'df_LetsMoveIt',
#  'df_AAP',
#  'df_healthia',
#  'df_healthhub__parenting',
#  'df_IQuit',
#  'df_korangok',
#  'df_MoveIt',
#  'df_Screen_for_Life',
#  'df_ga_testing',
#  'df_1test',
#  'df_indian_outreach',
#  'df_10_fun_ways_to_get_active',
#  'df_healthhub_rewards',
#  'df_howareyoudoing',
#  'df_1test_221123',
#  'df_1test_Program',
#  'df_healthyliving',
#  'df_eat_drink_shop_healthy_challenge',
#  'df_hsg',
#  'df_vaccinate',
#  'df_school_dental_programme',
#  'df_diabetes_mellitus',
#  'df_hiv_prevention',
#  'df_children_health_ehb',
#  'df_sexually_transmitted_infections',
#  'df_use_antibiotics_right',
#  'df_healthy_workplace_ecosystem',
#  'df_health_promoting_malls',
#  'df_strokehub',
#  'df_hygiene',
#  'df_StayWell',
#  'df_justcheckingin',
#  'df_EmotionsExplorer',
#  'df_preventive_health',
#  'df_Fight_The_Spread',
#  'df_cervical_cancer_screening',
#  'df_breast_cancer_screening',
#  'df_healthy_pregNaNcy',
#  'df_colorectal_cancer_screening',
#  'df_personal_health_eservices',
#  'df_nsc_participating_outlets',
#  'df_lose_to_win',
#  'df_community_challenge',
#  'df_testestnew',
#  'df_healthytimeout',
#  'df_go_hunkle',
#  'df_nsc_silver_challenge',
#  'df_lower_calorie_meals_can_be_satisfying',
#  'df_national_steps_challenge_campus',
#  'df_CH_TestSync_20240313',
#  'df_swtss_shredder_prototype',
#  'df_wholegrains_food_truck',
#  'df_tampines_healthy_pathway',
#  'df_vaping',
#  'df_1test_987backup',
#  'df_national_steps_challenge_youth',
#  'df_PDG_TestA',
#  'df_get_healthhub_track',
#  'df_Copy_of_1test',
#  'df_NaN']

# %% [markdown]
# #### Removal of redundant groups
#
# After looking through how the characteristics of each groups/second level, I will be removing selected groups that are empty/extracted_content_body is irrelevant.

# %%
# To check cotent of selected removal of groups
# df_Copy_of_1test['extracted_content_body'].iloc[0]
# Out:
# 'Website List_As of 31 Oct 2023 [https://ch-api.healthhub.sg/api/public/content/209ba2981fb346898866c164540349c0] Synopsis: Learn proactive parenting strategies to discuss vaping with teenagers amid its rise in Singapore. Encourage open dialogue, offer support, identify root causes, dispel misconceptions, and provide access to professional help. Estimated read time: 4 mins\nWith the recent rise on youths vaping in Singapore, its important to broach this topic with your teenager early, even before they might encounter vaping or situations where their friends are vaping.\nBe Casual:\nYou can bring up the topic casually, like if you and your child see vaping content on social media, a vape report on the news, or someone vaping.\nBe Curious:\nAsk your child what they know or think about vaping. You might be surprised by how much they already know. Thank them for sharing their thoughts, fostering an open dialogue.\nBe Candid:\nThen, share your own feelings about vaping in a simple and open way. For example, you could say, "When I see people vaping, I worry about their health. Vaping has a lot of health risks and its not worth it. I want to help you figure out what to do if someone offers you a vape."\n\nIf your child is vaping, try to:\n\n1) Work with your child\nChildren are generally more receptive to listening when you engage them in problem solving together. Ask them what strategies might help them manage their urge to vape.\n- Be open about their suggestions.\n- Some ideas can include healthy activities such as drawing, playing games, or engaging in sports.\n- Encourage alternatives like healthy snacking or using fidget toys to distract themselves.\n\n- Be open about their suggestions.\n- Some ideas can include healthy activities such as drawing, playing games, or engaging in sports.\n- Encourage alternatives like healthy snacking or using fidget toys to distract themselves.\n\nFrom there, work out a feasible plan together and schedule in casual chats to check-in on their progress.\n\n2) Identify communication barriers\n\n2) Identify communication barriers\nAsk them what is it that they prefer not to hear from you. This will allow you to calibrate the way you engage your child to allow for effective 2-way communication. Here are some examples of unhelpful conversations starters:\n- Ive told you so many times not to do it, why do you continue to vape?\n- I dont understand, how hard is it to quit?\n- If you dont stop vaping, Ill stop your pocket money.\n\n- Ive told you so many times not to do it, why do you continue to vape?\n- I dont understand, how hard is it to quit?\n- If you dont stop vaping, Ill stop your pocket money.\n\nWhen your child talks to you, try to understand how they feel. Sometimes, you might have the urge to fix their problems right away or make light of how they\'re feeling. Instead, try to show your child that you understand, empathise and care by reflecting their sentiments back: Wow, that does sound difficult.\n\n3) Uncover the root causes for vaping\n\n3) Uncover the root causes for vaping\nOther than peer influence and peer pressure, could it be that your child is using vaping to distract himself/herself from other difficulties he/she is facing? Perhaps he/she is facing bullying in school, or stressed out from schoolwork. Perhaps he/she is feeling overwhelmed by family/ issues with friends. When teenagers are in distress, they may turn to extreme unhealthy coping methods such as vaping.\n\n4) Educate them on perceived reality vs actual reality\n\n4) Educate them on perceived reality vs actual reality\nYour child may feel like everyone around him/her is vaping and as a result, succumb under peer pressure. He or she may view vaping as an in-road to being part of a cool group. It\'s important for them to know that most people do not vape.\n\nIt\'s important for them to know that most people do not vape.\n\nIt\'s important for them to know that most people do not vape.\nConsider asking your child how many p ...

# %%
# Remove 17 groups
exclude = ['df_1test_Program', 'df_1test', 'df_1test_221123', 'df_howareyoudoing', 'df_healthia', 'df_indian_outreach', 'df_testestnew', 'df_10_fun_ways_to_get_active', 
           'df_EmotionsExplorer', 'df_healthy_pregNaNcy', 'df_CH_TestSync_20240313', 'df_ga_testing', 'df_korangok', 
           'df_swtss_shredder_prototype', 'df_wholegrains_food_truck', 'df_1test_987backup', 'df_PDG_TestA', 'df_NaN']
filtered_grpList = [df for df in grpList if df not in exclude]
print(len(filtered_grpList))
filtered_grpList
# Out:
# 50
# ['df_parent_hub',
#  'df_MindSG',
#  'df_diabetes_hub',
#  'df_diabetes_hub_v2',
#  'df_nsc',
#  'df_pressure_injury',
#  'df_nutrition_hub',
#  'df_LetsMoveIt',
#  'df_AAP',
#  'df_healthhub__parenting',
#  'df_IQuit',
#  'df_korangok',
#  'df_MoveIt',
#  'df_Screen_for_Life',
#  'df_healthhub_rewards',
#  'df_healthyliving',
#  'df_eat_drink_shop_healthy_challenge',
#  'df_hsg',
#  'df_vaccinate',
#  'df_school_dental_programme',
#  'df_diabetes_mellitus',
#  'df_hiv_prevention',
#  'df_children_health_ehb',
#  'df_sexually_transmitted_infections',
#  'df_use_antibiotics_right',
#  'df_healthy_workplace_ecosystem',
#  'df_health_promoting_malls',
#  'df_strokehub',
#  'df_hygiene',
#  'df_StayWell',
#  'df_justcheckingin',
#  'df_preventive_health',
#  'df_Fight_The_Spread',
#  'df_cervical_cancer_screening',
#  'df_breast_cancer_screening',
#  'df_colorectal_cancer_screening',
#  'df_personal_health_eservices',
#  'df_nsc_participating_outlets',
#  'df_lose_to_win',
#  'df_community_challenge',
#  'df_healthytimeout',
#  'df_go_hunkle',
#  'df_nsc_silver_challenge',
#  'df_lower_calorie_meals_can_be_satisfying',
#  'df_national_steps_challenge_campus',
#  'df_tampines_healthy_pathway',
#  'df_vaping',
#  'df_national_steps_challenge_youth',
#  'df_get_healthhub_track',
#  'df_Copy_of_1test']

# %% [markdown]
# #### Merge common groups together
#
# I will also be combining groups/second levels that are similar in content together, in order to reduce the number of groups and make the groups themselves more condense.

# %%
print(df_preventive_health['extracted_content_body'].iloc[0])
# Out:
# - Screen For Life
# - FIGHT the Spread
# - Lets B.E.A.T. Diabetes
# - Live Well, Age Well
# - HIV
#
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Live Active
# Turn up the fun with regular exercise and reduce your risk of falls, joint pain and stiffness. Learn More [/programmes/160/AAP#live-active]
# Live Enriched
# Get simple and useful tips on leading a healthier lifestyle from our workshops. Learn More [/programmes/160/AAP#live-enriched]
# Live Assured
# Enjoy regular screening at subsidised rates and improve your health outcomes with early detection. Learn More [/programmes/160/AAP#live-assured]
# Live Happy
# Surround yourself with positive energy - keep your mind active and explore new hobbies with friends. Learn More [/programmes/160/AAP#live-happy]
# Live Prepared
# Learn digital skills at our workshops and impress your loved ones as you prepare for a fulfilling retirement. Learn More [/programmes/160/AAP#live-prepared]
# Live Nourished
# Discover more about eating healthy to build stronger muscles and bones, and how to make it a daily habit. Learn More [/programmes/160/AAP#live-nourished]
# HIV Prevention
# Learn the ABCD of HIV prevention. With early and effective treatment, people living with HIV can still lead quality lives. Learn More [/programmes/107/hiv-prevention#home]
# - Screen For Life
# - FIGHT the Spread
# - Lets B.E.A.T. Diabetes
# - Live Well, Age Well
# - HIV
#
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Live Active
# Turn up the fun with regular exercise and reduce your risk of falls, joint pain and stiffness. Learn More [/programmes/160/AAP#live-active]
# Live Enriched
# Get simple and useful tips on leading a healthier lifestyle from our workshops. Learn More [/programmes/160/AAP#live-enriched]
# Live Assured
# Enjoy regular screening at subsidised rates and improve your health outcomes with early detection. Learn More [/programmes/160/AAP#live-assured]
# Live Happy
# Surround yourself with positive energy - keep your mind active and explore new hobbies with friends. Learn More [/programmes/160/AAP#live-happy]
# Live Prepared
# Learn digital skills at our workshops and impress your loved ones as you prepare for a fulfilling retirement. Learn More [/programmes/160/AAP#live-prepared]
# Live Nourished
# Discover more about eating healthy to build stronger muscles and bones, and how to make it a daily habit. Learn More [/programmes/160/AAP#live-nourished]
# HIV Prevention
# Learn the ABCD of HIV prevention. With early and effective treatment, people living with HIV can still lead quality lives. Learn More [/programmes/107/hiv-prevention#home]
# - Screen For Life
# - FIGHT the Spread
# - Lets B.E.A.T. Diabetes
# - Live Well, Age Well
# - HIV
#
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Live Active
# Turn up the fun with regular exercise and reduce your risk of falls, joint pain and stiffness. Learn More [/programmes/160/AAP#live-active]
# Live Enriched
# Get simple and useful tips on leading a healthier lifestyle from our workshops. Learn More [/programmes/160/AAP#live-enriched]
# Live Assured
# Enjoy regular screening at subsidised rates and improve your health outcomes with early detection. Learn More [/programmes/160/AAP#live-assured]
# Live Happy
# Surround yourself with positive energy - keep your mind active and explore new hobbies with friends. Learn More [/programmes/160/AAP#live-happy]
# Live Prepared
# Learn digital skills at our workshops and impress your loved ones as you prepare for a fulfilling retirement. Learn More [/programmes/160/AAP#live-prepared]
# Live Nourished
# Discover more about eating healthy to build stronger muscles and bones, and how to make it a daily habit. Learn More [/programmes/160/AAP#live-nourished]
# HIV Prevention
# Learn the ABCD of HIV prevention. With early and effective treatment, people living with HIV can still lead quality lives. Learn More [/programmes/107/hiv-prevention#home]
# - Screen For Life
# - FIGHT the Spread
# - Lets B.E.A.T. Diabetes
# - Live Well, Age Well
# - HIV
#
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Live Active
# Turn up the fun with regular exercise and reduce your risk of falls, joint pain and stiffness. Learn More [/programmes/160/AAP#live-active]
# Live Enriched
# Get simple and useful tips on leading a healthier lifestyle from our workshops. Learn More [/programmes/160/AAP#live-enriched]
# Live Assured
# Enjoy regular screening at subsidised rates and improve your health outcomes with early detection. Learn More [/programmes/160/AAP#live-assured]
# Live Happy
# Surround yourself with positive energy - keep your mind active and explore new hobbies with friends. Learn More [/programmes/160/AAP#live-happy]
# Live Prepared
# Learn digital skills at our workshops and impress your loved ones as you prepare for a fulfilling retirement. Learn More [/programmes/160/AAP#live-prepared]
# Live Nourished
# Discover more about eating healthy to build stronger muscles and bones, and how to make it a daily habit. Learn More [/programmes/160/AAP#live-nourished]
# HIV Prevention
# Learn the ABCD of HIV prevention. With early and effective treatment, people living with HIV can still lead quality lives. Learn More [/programmes/107/hiv-prevention#home]
# - Screen For Life
# - FIGHT the Spread
# - Lets B.E.A.T. Diabetes
# - Live Well, Age Well
# - HIV
#
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Live Active
# Turn up the fun with regular exercise and reduce your risk of falls, joint pain and stiffness. Learn More [/programmes/160/AAP#live-active]
# Live Enriched
# Get simple and useful tips on leading a healthier lifestyle from our workshops. Learn More [/programmes/160/AAP#live-enriched]
# Live Assured
# Enjoy regular screening at subsidised rates and improve your health outcomes with early detection. Learn More [/programmes/160/AAP#live-assured]
# Live Happy
# Surround yourself with positive energy - keep your mind active and explore new hobbies with friends. Learn More [/programmes/160/AAP#live-happy]
# Live Prepared
# Learn digital skills at our workshops and impress your loved ones as you prepare for a fulfilling retirement. Learn More [/programmes/160/AAP#live-prepared]
# Live Nourished
# Discover more about eating healthy to build stronger muscles and bones, and how to make it a daily habit. Learn More [/programmes/160/AAP#live-nourished]
# HIV Prevention
# Learn the ABCD of HIV prevention. With early and effective treatment, people living with HIV can still lead quality lives. Learn More [/programmes/107/hiv-prevention#home]
# - Screen For Life
# - FIGHT the Spread
# - Lets B.E.A.T. Diabetes
# - Live Well, Age Well
# - HIV
#
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Live Active
# Turn up the fun with regular exercise and reduce your risk of falls, joint pain and stiffness. Learn More [/programmes/160/AAP#live-active]
# Live Enriched
# Get simple and useful tips on leading a healthier lifestyle from our workshops. Learn More [/programmes/160/AAP#live-enriched]
# Live Assured
# Enjoy regular screening at subsidised rates and improve your health outcomes with early detection. Learn More [/programmes/160/AAP#live-assured]
# Live Happy
# Surround yourself with positive energy - keep your mind active and explore new hobbies with friends. Learn More [/programmes/160/AAP#live-happy]
# Live Prepared
# Learn digital skills at our workshops and impress your loved ones as you prepare for a fulfilling retirement. Learn More [/programmes/160/AAP#live-prepared]
# Live Nourished
# Discover more about eating healthy to build stronger muscles and bones, and how to make it a daily habit. Learn More [/programmes/160/AAP#live-nourished]
# HIV Prevention
# Learn the ABCD of HIV prevention. With early and effective treatment, people living with HIV can still lead quality lives. Learn More [/programmes/107/hiv-prevention#home]
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Breast Cancer Screening
# Explore how you can prepare for a mammogram, what to expect, and post-screening information. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_breast-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Cervical Cancer Screening
# Discover your recommended test (Pap or HPV) and learn how to prepare for it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_cervical-cancer]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Chronic Disease Screening
# Find out the diseases you can protect yourself against, the screening tests included, and post-screening details. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_chronic-diseases]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# Colorectal Cancer Screening
# Learn more about the Faecal Immunochemical Test (FIT) kit and how to use it. Learn More [/programmes/61/Screen_for_Life/screening-journey/?age_group=50-and-above&gender=female#50-and-above-female-find_colorectal-cancer]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# FAQs Have questions on the Screen for Life programme? Get more information here. Learn More [/programmes/61/Screen_for_Life/sfl-faqs#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Immunisation
# Getting vaccinated is your best defence against vaccine-preventable diseases like influenza and pneumococcal disease. Learn More [/programmes/163/vaccinate#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Hygiene
# Prevent the spread of germs by practising proper hand hygiene habits, such as doing the 8-step hand wash for 20 seconds. Learn More [/programmes/188/hygiene#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Antimicrobial Resistance (AMR)
# Misuse of antibiotics can lead to serious infections, longer recovery time, and ineffective future medical treatments. Learn More [/programmes/146/use-antibiotics-right#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Lets B.E.A.T. Diabetes
# Reduce your risk with early detection through regular health screening, adopting an active lifestyle and a healthy diet. Learn More [/programmes/87/diabetes-mellitus#home]
# Live Active
# Turn up the fun with regular exercise and reduce your risk of falls, joint pain and stiffness. Learn More [/programmes/160/AAP#live-active]
# Live Enriched
# Get simple and useful tips on leading a healthier lifestyle from our workshops. Learn More [/programmes/160/AAP#live-enriched]
# Live Assured
# Enjoy regular screening at subsidised rates and improve your health outcomes with early detection. Learn More [/programmes/160/AAP#live-assured]
# Live Happy
# Surround yourself with positive energy - keep your mind active and explore new hobbies with friends. Learn More [/programmes/160/AAP#live-happy]
# Live Prepared
# Learn digital skills at our workshops and impress your loved ones as you prepare for a fulfilling retirement. Learn More [/programmes/160/AAP#live-prepared]
# Live Nourished
# Discover more about eating healthy to build stronger muscles and bones, and how to make it a daily habit. Learn More [/programmes/160/AAP#live-nourished]
# Live Active
# Turn up the fun with regular exercise and reduce your risk of falls, joint pain and stiffness. Learn More [/programmes/160/AAP#live-active]
# Live Enriched
# Get simple and useful tips on leading a healthier lifestyle from our workshops. Learn More [/programmes/160/AAP#live-enriched]
# Live Assured
# Enjoy regular screening at subsidised rates and improve your health outcomes with early detection. Learn More [/programmes/160/AAP#live-assured]
# Live Happy
# Surround yourself with positive energy - keep your mind active and explore new hobbies with friends. Learn More [/programmes/160/AAP#live-happy]
# Live Prepared
# Learn digital skills at our workshops and impress your loved ones as you prepare for a fulfilling retirement. Learn More [/programmes/160/AAP#live-prepared]
# Live Nourished
# Discover more about eating healthy to build stronger muscles and bones, and how to make it a daily habit. Learn More [/programmes/160/AAP#live-nourished]
# Live Active
# Turn up the fun with regular exercise and reduce your risk of falls, joint pain and stiffness. Learn More [/programmes/160/AAP#live-active]
# Live Enriched
# Get simple and useful tips on leading a healthier lifestyle from our workshops. Learn More [/programmes/160/AAP#live-enriched]
# Live Assured
# Enjoy regular screening at subsidised rates and improve your health outcomes with early detection. Learn More [/programmes/160/AAP#live-assured]
# Live Happy
# Surround yourself with positive energy - keep your mind active and ex

# %%
# * Run once only
df_parent_hub_concatenated = pd.concat([df_parent_hub, df_healthhub__parenting, df_school_dental_programme, df_healthytimeout, df_children_health_ehb], axis=0)
df_MindSG_concatenated = pd.concat([df_MindSG, df_justcheckingin, df_StayWell], axis=0)
df_diabetes_hub_concatenated = pd.concat([df_diabetes_hub, df_diabetes_hub_v2, df_diabetes_mellitus], axis=0)
df_LetsMoveIt_concatenated = pd.concat([df_LetsMoveIt, df_MoveIt, df_lose_to_win, df_go_hunkle], axis=0)
df_nsc_concatenated = pd.concat([df_nsc, df_national_steps_challenge_youth, df_tampines_healthy_pathway, df_national_steps_challenge_campus, df_nsc_silver_challenge, df_community_challenge, df_nsc_participating_outlets, df_health_promoting_malls, df_healthy_workplace_ecosystem], axis=0)
df_iquit_concatenated = pd.concat([df_IQuit, df_vaping, df_Copy_of_1test], axis=0)
df_AAP_concatenated = pd.concat([df_AAP, df_strokehub], axis=0)
df_screen_for_life_concatenated = pd.concat([df_Screen_for_Life, df_colorectal_cancer_screening, df_breast_cancer_screening, df_cervical_cancer_screening, df_vaccinate, df_hsg, df_personal_health_eservices], axis=0)
df_nutrition_hub_concatenated = pd.concat([df_nutrition_hub, df_eat_drink_shop_healthy_challenge, df_lower_calorie_meals_can_be_satisfying], axis=0)
df_sti_concatenated = pd.concat([df_hiv_prevention, df_sexually_transmitted_infections], axis=0)
df_healthy365_concatenated = pd.concat([df_healthhub_rewards, df_healthyliving, df_get_healthhub_track], axis=0)
df_preventive_health_concatenated = pd.concat([df_Fight_The_Spread, df_use_antibiotics_right, df_preventive_health, df_hygiene], axis=0)

# df_hiv_prevention, df_sexually_transmitted_infections

newGrps = ['df_parent_hub_concatenated', 'df_MindSG_concatenated', 'df_diabetes_hub_concatenated', 'df_LetsMoveIt_concatenated', 
           'df_nsc_concatenated', 'df_iquit_concatenated', 'df_AAP_concatenated', 'df_screen_for_life_concatenated', 
           'df_nutrition_hub_concatenated', 'df_sti_concatenated', 'df_healthy365_concatenated', 'df_preventive_health_concatenated']
for grp in newGrps:
    print(grp)
    filtered_grpList.append(grp)

exclude_mergedGrps = ['df_parent_hub', 'df_healthhub__parenting', 'df_school_dental_programme', 'df_healthytimeout', 'df_children_health_ehb', 'df_MindSG', 'df_justcheckingin', 'df_StayWell',
                      'df_diabetes_hub', 'df_diabetes_hub_v2', 'df_diabetes_mellitus', 'df_LetsMoveIt', 'df_MoveIt', 'df_lose_to_win', 'df_go_hunkle', 
                      'df_nsc', 'df_national_steps_challenge_youth', 'df_tampines_healthy_pathway', 'df_national_steps_challenge_campus', 'df_nsc_silver_challenge', 'df_community_challenge', 'df_nsc_participating_outlets', 'df_health_promoting_malls', 'df_healthy_workplace_ecosystem',
                      'df_IQuit', 'df_vaping', 'df_Copy_of_1test', 'df_AAP', 'df_strokehub', 'df_Screen_for_Life', 'df_colorectal_cancer_screening', 'df_breast_cancer_screening', 'df_cervical_cancer_screening', 'df_vaccinate', 'df_hsg', 'df_personal_health_eservices', 'df_preventive_health',
                      'df_nutrition_hub', 'df_eat_drink_shop_healthy_challenge', 'df_lower_calorie_meals_can_be_satisfying', 
                      'df_hiv_prevention', 'df_sexually_transmitted_infections', 'df_healthhub_rewards', 'df_healthyliving', 'df_get_healthhub_track', 'df_use_antibiotics_right', 'df_Fight_The_Spread', 'df_hygiene']

print('Number of groups to be combined', len(exclude_mergedGrps))

final_grpList = [df for df in filtered_grpList if df not in exclude_mergedGrps]
len(final_grpList)
# Out:
# df_parent_hub_concatenated
# df_MindSG_concatenated
# df_diabetes_hub_concatenated
# df_LetsMoveIt_concatenated
# df_nsc_concatenated
# df_iquit_concatenated
# df_AAP_concatenated
# df_screen_for_life_concatenated
# df_nutrition_hub_concatenated
# df_sti_concatenated
# df_healthy365_concatenated
# df_preventive_health_concatenated
# 14

# %%
final_grpList
# Out:
# ['df_pressure_injury',
#  'df_korangok',
#  'df_parent_hub_concatenated',
#  'df_MindSG_concatenated',
#  'df_diabetes_hub_concatenated',
#  'df_LetsMoveIt_concatenated',
#  'df_nsc_concatenated',
#  'df_iquit_concatenated',
#  'df_AAP_concatenated',
#  'df_screen_for_life_concatenated',
#  'df_nutrition_hub_concatenated',
#  'df_sti_concatenated',
#  'df_healthy365_concatenated',
#  'df_preventive_health_concatenated']

# %% [markdown]
# #### Export to xlsx

# %%
# Sort DataFrame by their number of rows
sorted_final_grpList = sorted(final_grpList, key=lambda df_name: len(eval(df_name)), reverse=True)
print(sorted_final_grpList)
# Out:
# ['df_parent_hub_concatenated', 'df_MindSG_concatenated', 'df_diabetes_hub_concatenated', 'df_nsc_concatenated', 'df_LetsMoveIt_concatenated', 'df_pressure_injury', 'df_nutrition_hub_concatenated', 'df_screen_for_life_concatenated', 'df_AAP_concatenated', 'df_iquit_concatenated', 'df_korangok', 'df_healthy365_concatenated', 'df_preventive_health_concatenated', 'df_sti_concatenated']

# %%
# keys = DataFrame names, values = DataFrame objects
dataframes = {name: globals()[name] for name in sorted_final_grpList}

# Save all DataFrames to Excel file
with pd.ExcelWriter(r"program-sub-pages\grouped_programSubpages.xlsx", engine='xlsxwriter') as writer:
    for df_name, df in dataframes.items():
        sheet_name = df_name.replace('df_', '')
        df.to_excel(writer, sheet_name=sheet_name, index=False)

print("DataFrames saved to 'grouped_programSubpages.xlsx'.")
# Out:
# DataFrames saved to 'grouped_programSubpages.xlsx'.

# %% [markdown]
# #### Markdown Summary of final dataframes:

# %% [markdown]
# Total number of groups: 14
#
# - ✅ 'df_parent_hub_concatenated': parent + children + grandparents (mental well being, health, checkup)
#     - 'df_children_health_ehb'
# - ✅ 'df_MindSG': (mental well being)
#     - 'df_justcheckingin'
#     - 'df_healthytimeout'
# - ✅ 'df_diabetes_hub_concatenated': diabetes
# - ✅ 'df_nsc_concatenated': national steps challenge
# - ✅ 'df_pressure_injury',
# - ✅ 'df_LetsMoveIt_concatenated':
#     - 'df_go_hunkle'
#     - 'df_lose_to_win'
# - ✅ 'df_nutrition_hub_concatenated',
#     - 'df_lower_calorie_meals_can_be_satisfying'
# - ✅ 'df_AAP': live well, age well (elderly)
#     - 'df_strokehub'
# - ✅ 'df_screen_for_life_concatenated': functional screening, vaccination
#     - 'df_vaccinate'
#     - 'df_personal_health_eservices'
# - ✅ 'df_iquit_concatenated',
# - ✅ 'df_korangok',
# - ✅ 'df_healthy365'
#     - 'df_healthhub_rewards',
#     - 'df_get_healthhub_track'
#     - 'df_healthyliving'
# - ✅ 'df_sti':
#     - 'df_hiv_prevention',
#     - 'df_sexually_transmitted_infections',
# - ✅ 'df_preventive_health':
#     - 'df_antibiotics',
#     - 'df_hygiene',
#     - 'df_Fight_The_Spread',
#     - 'df_preventive_health'

# %% [markdown]
# <hr>
#
# ### Important Note: Further Manual Cleaning
#
# Further manual checking & cleaning was done on this excel file `grouped_programSubpages.xlsx`. It was found that some `extracted_content_body` did not make sense. As we will be performing topic/keyword modelling on this attribute, I have decided to remove such cases.
#
# Removed rows under the respective sheets in `grouped_programSubpages.xlsx` are as follows:
# 1. diabetes_hub_concatenated:
#     - rows with column `id`: `1435297`, `1435302` & `1435299`
#         - `extracted_content_body` is ‘aaa’ and ‘aa’ only
