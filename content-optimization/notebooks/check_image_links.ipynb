# %% [markdown]
# # Check for Infographic Content

# %%
import numpy as np
import plotly.express as px
from bs4 import BeautifulSoup

# %%
# %load_ext kedro.ipython
# Out:
# [07/23/24 15:59:34] INFO     Registered line magic '%reload_kedro'                                   ]8;id=737152;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=876864;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#58\58]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=263717;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=489540;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#60\60]8;;\
# ...

# %%
# ruff: noqa: F821
catalog.list()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'all_contents',
#     'missing_contents',
#     'all_contents_standardized',
#     'all_contents_added',
#     'all_contents_extracted',
#     'all_extracted_text',
#     'merged_data',
#     'raw_word_counts',
#     'log_word_counts',
#     'flag_for_removal_by_type',
#     'recipes_data',
#     'filtered_data_with_keywords',
#     'parameters',
#     'params:columns_to_keep',
#     'params:columns_to_keep.cost-and-financing',
#     'params:columns_to_keep.diseases-and-conditions',
#     'params:columns_to_keep.health-statistics',
#     'params:columns_to_keep.live-healthy-articles',
#     'params:columns_to_keep.medical-care-and-facilities',
#     'params:columns_to_keep.medications',
#     'params:columns_to_keep.program-sub-pages',
#     'params:columns_to_keep.programs',
#     'params:columns_to_keep.support-group-and-others',
# ...

# %%
merged_data = catalog.load("merged_data")

display(merged_data)
# Out:
#                     INFO     Loading data from merged_data (ParquetDataset)...                  ]8;id=558011;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=95553;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/io/data_catalog.py#508\508]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                      content_name  \
# 0     1435040           Breast Screening Subsidies in Singapore
# 1     1435071                   Marriage and Parenthood Schemes
# 2     1434993                                          MediSave
# 3     1435031  Hospital Bills Financial Assistance in Singapore
# 4     1435043   Community Health Assist Scheme (CHAS) Singapore
# ...

# %%
relevant_categories = [
    "cost-and-financing",
    "live-healthy-articles",
    "diseases-and-conditions",
    "medical-care-and-facilities",
    "support-group-and-others",
]

df_keep = merged_data[merged_data["content_category"].isin(relevant_categories)]

display(df_keep)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                      content_name  \
# 0     1435040           Breast Screening Subsidies in Singapore
# 1     1435071                   Marriage and Parenthood Schemes
# 2     1434993                                          MediSave
# 3     1435031  Hospital Bills Financial Assistance in Singapore
# 4     1435043   Community Health Assist Scheme (CHAS) Singapore
# ...       ...                                               ...
# 2608  1440763         Heart Failure Transitional Care Programme
# 2609  1440791              Brain and Head Injury Support Groups
# 2610  1440768                      Ambulatory Nutrition Support
# 2611  1440766              LapBandits Support Group (Singapore)
# 2612  1440762              Cardiac Rehabilitation Support Group
#
#                                                  title  \
# ...

# %%
def filter_low_word_count(text, threshold):
    if text is None:
        return False
    count = len(text.split())
    return count <= threshold

df_keep["low_word_count"] = df_keep["extracted_content_body"].apply(lambda x: filter_low_word_count(x, 90))
df_check = df_keep[(df_keep["low_word_count"]) & (df_keep["has_image"])]

display(df_check)
# Out:
#                     WARNING  /var/folders/3n/y5_h0fxs0bv2mhb7bf_fpmb80000gn/T/ipykernel_88726/25375 ]8;id=989047;file:///opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=456599;file:///opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/warnings.py#110\110]8;;\
#                              5331.py:7: SettingWithCopyWarning:
#                              A value is trying to be set on a copy of a slice from a DataFrame.
#                              Try using .loc[row_indexer,col_indexer] = value instead
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df_keep["low_word_count"] =
# ...
