# %%
# %load_ext kedro.ipython
# Out:
# [08/09/24 21:54:08] INFO     Registered line magic '%reload_kedro'                                   ]8;id=897223;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=723511;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#58\58]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=473518;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=171108;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#60\60]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=72655;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=712263;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#171\171]8;;\
#                              /Users/issacj/Desktop/Synapxe/healthhub-content-optimization/content-o
#                              ptimization.
#                              To set a different path, run '%reload_kedro <project_root>'
# [08/09/24 21:54:09] INFO     Kedro project Content Optimization                                     ]8;id=747012;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=768368;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#141\141]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=806475;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=631412;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#142\142]8;;\
#                              'pipelines'
#                     INFO     Registered line magic 'run_viz'                                        ]8;id=34179;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=757195;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/ipython/__init__.py#148\148]8;;\

# %%
import pandas as pd

# %%
def flag_duplicated(
    df: pd.DataFrame, whitelist: list[int], column: str
) -> pd.DataFrame:
    """
    Flags duplicated rows in the given DataFrame based on the specified column.
    This function only inspects for duplicates in two columns:
    `extracted_content_body` and `full_url`.

    Args:
        df (pd.DataFrame): The DataFrame to flag duplicated rows in.
        whitelist (list[int]): The list of article IDs to keep. See https://bitly.cx/IlwNV.
        column (str):
            The column to check for duplicated values. Must be either
            `extracted_content_body` and `full_url`.

    Returns:
        pd.DataFrame:
            The DataFrame with a new column `to_remove` indicating whether a row
            should be removed. The `remove_type` column is also updated with the type of
            "Duplicated Content" or "Duplicated URL".

    Raises:
        AssertionError: If the `column` parameter is None or not valid.
    """
    assert column is not None, "`column` cannot be None"
    assert column in ["extracted_content_body", "full_url"], "Invalid column"

    if column == "extracted_content_body":
        duplicated_df = df[
            (df[column].duplicated())  # we want duplicated articles
            & (df[column].notna())  # ignore null values
            & (df[column] != "")  # ignore empty extracted content
            # & (~df["to_remove"])  # ignore articles that were already flagged
        ]
        value = "Duplicated Content"

    elif column == "full_url":
        duplicated_df = df[
            (df[column].duplicated())  # we want duplicated URLs
            & (df[column].notna())  # ignore null values
            # & (~df["to_remove"])  # ignore articles that were already flagged
        ]
        value = "Duplicated URL"

    for i in range(len(duplicated_df)):
        # Get all indexes for duplicated content or URL
        duplicated_indexes = df[df[column] == duplicated_df.iloc[i][column]].index

        # Note: We could simply update all at once at `duplicated_indexes`
        # However, we'd overwrite the previous flags. This is kept as is, for now.
        for j in duplicated_indexes:
            if not df.iloc[j]["to_remove"]:
                # Ignore whitelisted articles
                if df.iloc[j]["id"] in whitelist:
                    continue
                # Update `to_remove`
                df.at[j, "to_remove"] = True

                # Set `remove_type` for all indexes (either "Duplicated Content" or "Duplicated URL")
                df.at[j, "remove_type"] = value

    return df

# %%
merged_data = catalog.load("merged_data")

df_keep = merged_data[[
    "id",
    "content_name",
    "title",
    "full_url",
    "content_body",
    "extracted_content_body",
    "pr_name",
    "date_modified",
    "content_category",
    "page_views",
    "to_remove",
    "remove_type",
]]

display(df_keep)
# Out:
#                     INFO     Loading data from merged_data (ParquetDataset)...                  ]8;id=875151;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=304890;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/io/data_catalog.py#508\508]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                      content_name  \
# 0     1435040           Breast Screening Subsidies in Singapore
# 1     1435071                   Marriage and Parenthood Schemes
# 2     1434993                                          MediSave
# 3     1435031  Hospital Bills Financial Assistance in Singapore
# 4     1435043   Community Health Assist Scheme (CHAS) Singapore
# ...       ...                                               ...
# 2608  1440763         Heart Failure Transitional Care Programme
# 2609  1440791              Brain and Head Injury Support Groups
# 2610  1440768                      Ambulatory Nutrition Support
# 2611  1440766              LapBandits Support Group (Singapore)
# 2612  1440762              Cardiac Rehabilitation Support Group
#
#                                                  title  \
# 0              Breast Screening Subsidies in Singapore
# 1                      Marriage and Parenthood Schemes
# 2                                             MediSave
# 3     Hospital Bills Financial Assistance in Singapore
# 4      Community Health Assist Scheme (CHAS) Singapore
# ...                                                ...
# 2608         Heart Failure Transitional Care Programme
# 2609              Brain and Head Injury Support Groups
# 2610                      Ambulatory Nutrition Support
# 2611              LapBandits Support Group (Singapore)
# 2612              Cardiac Rehabilitation Support Group
#
#                                                full_url  \
# 0     https://www.healthhub.sg/a-z/costs-and-financi...
# 1     https://www.healthhub.sg/a-z/costs-and-financi...
# 2     https://www.healthhub.sg/a-z/costs-and-financi...
# 3     https://www.healthhub.sg/a-z/costs-and-financi...
# 4     https://www.healthhub.sg/a-z/costs-and-financi...
# ...                                                 ...
# 2608  https://www.healthhub.sg/a-z/support-groups-an...
# 2609  https://www.healthhub.sg/a-z/support-groups-an...
# 2610  https://www.healthhub.sg/a-z/support-groups-an...
# 2611  https://www.healthhub.sg/a-z/support-groups-an...
# 2612  https://www.healthhub.sg/a-z/support-groups-an...
#
#                                            content_body  \
# 0     b'<div class="ExternalClass07C58E0D957B4AA7B14...
# 1     b'<div class="ExternalClassE1D82270F17241E4955...
# 2     b'<div class="ExternalClass67AD25F1F8B64B349E5...
# 3     b'<div class="ExternalClassE335708125E743FDAA3...
# 4     b'<h2>What is the Community Health Assist Sche...
# ...                                                 ...
# 2608  b'<div class="ExternalClassFC126593610D4F0587A...
# 2609  b'<div class="ExternalClass7C92735B78174928B28...
# 2610  b'<div class="ExternalClass3FABAC9D59A64BCAB96...
# 2611  b'<div class="ExternalClassA4C749C7DB7647FBB6D...
# 2612  b'<div class="ExternalClassD4367205B11F4638BFF...
#
#                                  extracted_content_body  \
# 0     Breast cancer is the number one cancer among w...
# 1     MediSave Maternity Package\nWith the MediSave ...
# 2     What is MediSave?\nMediSave, introduced in Apr...
# 3     Patients or family members who have difficulty...
# 4     What is the Community Health Assist Scheme (CH...
# ...                                                 ...
# 2608  Heart failure is the leading cause of rehospit...
# 2609  Brain Tumour Society (Singapore)\nThe Brain Tu...
# 2610  The Importance of Ambulatory Nutrition Support...
# 2611  About Khoo Teck Puat Hospitals LapBandits Supp...
# 2612  If you are caring for a loved one with cardiov...
#
#                                           pr_name  \
# 0                          Health Promotion Board
# 1                              Ministry of Health
# 2                              Ministry of Health
# 3                         Khoo Teck Puat Hospital
# 4                                            CHAS
# ...                                           ...
# 2608  National University Heart Centre, Singapore
# 2609              National Neuroscience Institute
# 2610                 National University Hospital
# 2611                      Khoo Teck Puat Hospital
# 2612                 National University Hospital
#
#                      date_modified          content_category  page_views  \
# 0     2023-08-08T05:27:42.0000000Z        cost-and-financing       10855
# 1     2021-11-02T05:46:52.0000000Z        cost-and-financing        5581
# 2     2019-01-29T05:06:22.0000000Z        cost-and-financing        3205
# 3     2019-09-13T03:08:41.0000000Z        cost-and-financing        3077
# 4     2022-09-30T10:44:05.0000000Z        cost-and-financing        3026
# ...                            ...                       ...         ...
# 2608  2021-12-21T03:07:24.0000000Z  support-group-and-others         302
# 2609  2019-09-13T02:35:52.0000000Z  support-group-and-others         291
# 2610  2021-05-25T02:27:00.0000000Z  support-group-and-others         258
# 2611  2020-11-02T04:38:01.0000000Z  support-group-and-others         247
# 2612  2019-09-13T02:35:52.0000000Z  support-group-and-others         232
#
#       to_remove       remove_type
# 0         False              None
# 1         False              None
# 2         False              None
# 3         False              None
# 4         False              None
# ...         ...               ...
# 2608      False              None
# 2609      False              None
# 2610      False              None
# 2611       True  Below Word Count
# 2612      False              None
#
# [2613 rows x 12 columns]

# %%
df_duplicated_all = df_keep[(df_keep["remove_type"] == "Duplicated Content") | (df_keep["remove_type"] == "Duplicated URL")].sort_values(["full_url", "extracted_content_body"])

display(df_duplicated_all)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                       content_name  \
# 1446  1495949                         conversations-about-vaping
# 1067  1445629                     Sliced Fish with Bee Hoon Soup
# 1215  1443608                                         Mee Goreng
# 1515  1445972                                      Eat Well, Mum
# 1370  1445829                               Recipe : Sayur Lodeh
# ...       ...                                                ...
# 2242  1434769  Parent Hub: 7-12 Years - Healthy Eating_health...
# 2232  1434774  Parent Hub: 7-12 Years - Sparkly Teeth and Eye...
# 2296  1434773  Parent Hub: 7-12 Years - Healthy at School_sch...
# 2332  1434838  Parent Hub: Teens - View All_all-items-adolesc...
# 2369  1434819  Parent Hub: Teens - Emotional Health_emotional...
#
#                                                   title  \
# 1446  Parenting Insights: Strategies for Conversatio...
# 1067                     Sliced Fish with Bee Hoon Soup
# 1215                                         Mee Goreng
# 1515                                      Eat Well, Mum
# 1370                               Recipe : Sayur Lodeh
# ...                                                 ...
# 2242            Parent Hub: 7-12 Years - Healthy Eating
# 2232    Parent Hub: 7-12 Years - Sparkly Teeth and Eyes
# 2296         Parent Hub: 7-12 Years - Healthy at School
# 2332                       Parent Hub: Teens - View All
# 2369               Parent Hub: Teens - Emotional Health
#
#                                                full_url  \
# 1446  https://www.healthhub.sg/live-healthy/conversa...
# 1067  https://www.healthhub.sg/live-healthy/fish-bee...
# 1215   https://www.healthhub.sg/live-healthy/mee-goreng
# 1515  https://www.healthhub.sg/live-healthy/parents-...
# 1370  https://www.healthhub.sg/live-healthy/sayur-lodeh
# ...                                                 ...
# 2242  https://www.healthhub.sg/programmes/parent-hub...
# 2232  https://www.healthhub.sg/programmes/parent-hub...
# 2296  https://www.healthhub.sg/programmes/parent-hub...
# 2332  https://www.healthhub.sg/programmes/parent-hub...
# 2369  https://www.healthhub.sg/programmes/parent-hub...
#
#                                            content_body  \
# 1446  b'<div class="ExternalClassB1D1BA8198604AF5897...
# 1067  b'<div class="ExternalClassF5C1DD3FA7E84963A88...
# 1215  b'<div class="ExternalClass60865CF1F8FA4603ABA...
# 1515  b'<h2><img alt="PY-Marina-Bay-Selfie_and_entry...
# 1370  b'<div class="ExternalClass8FB2510AE8C541EEADF...
# ...                                                 ...
# 2242  b'<div class="ExternalClass0A5C5A7F37E8484C914...
# 2232  b'<div class="ExternalClass679540320FCF4DE5817...
# 2296  b'<div class="ExternalClass2770EF056B0A4A02B2B...
# 2332  b'<div class="ExternalClassCD0CD6B849DE4FF198A...
# 2369  b'<div class="ExternalClassDBDC536DC28F463D89F...
#
#                                  extracted_content_body  \
# 1446  Synopsis: Learn proactive parenting strategies...
# 1067  Mouthwatering sliced fish with bee hoon soup\n...
# 1215  By KK Womens and Childrens Hospital and Ms Hen...
# 1515  Physical Activity Fun Both in and Out of the S...
# 1370  Looking to bring some wholesome goodness home?...
# ...                                                 ...
# 2242                         Wed love to hear from you!
# 2232                         Wed love to hear from you!
# 2296                         Wed love to hear from you!
# 2332                         Wed love to hear from you!
# 2369                         Wed love to hear from you!
#
#                                  pr_name                 date_modified  \
# 1446                                None                          None
# 1067              Health Promotion Board  2022-11-15T08:35:26.0000000Z
# 1215  KK Women's and Children's Hospital  2021-12-21T08:10:47.0000000Z
# 1515              Health Promotion Board  2022-11-15T08:46:52.0000000Z
# 1370              Health Promotion Board  2022-11-15T08:35:29.0000000Z
# ...                                  ...                           ...
# 2242              Health Promotion Board                          None
# 2232              Health Promotion Board                          None
# 2296              Health Promotion Board                          None
# 2332              Health Promotion Board                          None
# 2369              Health Promotion Board                          None
#
#            content_category  page_views  to_remove         remove_type
# 1446  live-healthy-articles          29       True  Duplicated Content
# 1067  live-healthy-articles         378       True      Duplicated URL
# 1215  live-healthy-articles         276       True      Duplicated URL
# 1515  live-healthy-articles           0       True  Duplicated Content
# 1370  live-healthy-articles         187       True      Duplicated URL
# ...                     ...         ...        ...                 ...
# 2242      program-sub-pages        1384       True  Duplicated Content
# 2232      program-sub-pages        1644       True  Duplicated Content
# 2296      program-sub-pages         562       True  Duplicated Content
# 2332      program-sub-pages         303       True  Duplicated Content
# 2369      program-sub-pages           0       True  Duplicated Content
#
# [66 rows x 12 columns]

# %%
whitelist = catalog.load("params:whitelist")

print(whitelist)
# Out:
# [08/09/24 21:54:10] INFO     Loading data from params:whitelist (MemoryDataset)...              ]8;id=570066;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=991140;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/io/data_catalog.py#508\508]8;;\
# [1445216, 1444496, 1446090, 1442907, 1443325, 1445019, 1442928, 1445021, 1444996, 1442952, 1445017, 1445212, 1445958, 1444997, 1445027, 1445024, 1445002, 1444991, 1445000, 1445733, 1445704, 1445707, 1497409, 1469472, 1446081, 1445828, 1445798, 1435335, 1435183, 1434614]

# %%
blacklist = catalog.load("params:blacklist")

print(blacklist)
# Out:
#                     INFO     Loading data from params:blacklist (MemoryDataset)...              ]8;id=547788;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=529969;file:///Users/issacj/Desktop/Synapxe/healthhub-content-optimization/env/lib/python3.11/site-packages/kedro/io/data_catalog.py#508\508]8;;\
# {1443526: 'Table of Contents', 1443534: 'Table of Contents', 1444997: 'Irrelevant Content', 1445002: 'Irrelevant Content', 1444991: 'Irrelevant Content', 1444996: 'Irrelevant Content', 1445000: 'Irrelevant Content'}

# %%
df_keep = flag_duplicated(df_keep, [], column="extracted_content_body")
df_duplicated_content = df_keep[(df_keep["remove_type"] == "Duplicated Content")].sort_values(["title", "date_modified", "extracted_content_body", "page_views"])

display(df_duplicated_content)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                       content_name  \
# 2365  1473807                                       sleep-test-2
# 2367  1473810                            sleep-test-2-change-css
# 2370  1473813                      sleep-test-3-css-change-again
# 2371  1473816                                     sleep-test-dup
# 2520  1434652             3 Be's To Beat Diabetes | Diabetes Hub
# ...       ...                                                ...
# 2458  1435245                         Persona B_persona-b_Level1
# 2481  1435160  Setting goals | Diabetes Hub_setting-goals_Level1
# 2423  1434979  Take the first step with your loved ones_healt...
# 2304  1434977  Take the first step with your loved ones_physi...
# 2377  1473804                                         sleep-test
#
#                                          title  \
# 2365     3 - 6 Years: Good Sleep Captain Sleep
# 2367     3 - 6 Years: Good Sleep Captain Sleep
# 2370     3 - 6 Years: Good Sleep Captain Sleep
# 2371     3 - 6 Years: Good Sleep Captain Sleep
# 2520    3 Be's To Beat Diabetes | Diabetes Hub
# ...                                        ...
# 2458                                 Persona B
# 2481              Setting goals | Diabetes Hub
# 2423  Take the first step with your loved ones
# 2304  Take the first step with your loved ones
# 2377                                sleep-test
#
#                                                full_url  \
# 2365  https://www.healthhub.sg/programmes/parent-hub...
# 2367  https://www.healthhub.sg/programmes/parent-hub...
# 2370  https://www.healthhub.sg/programmes/parent-hub...
# 2371  https://www.healthhub.sg/programmes/parent-hub...
# 2520   https://www.healthhub.sg/programmes/diabetes-hub
# ...                                                 ...
# 2458  https://www.healthhub.sg/programmes/ga-testing...
# 2481  https://www.healthhub.sg/programmes/diabetes-h...
# 2423  https://www.healthhub.sg/programmes/indian_out...
# 2304  https://www.healthhub.sg/programmes/howareyoud...
# 2377  https://www.healthhub.sg/programmes/parent-hub...
#
#                                            content_body  \
# 2365  b'<div class="ExternalClassC9333E76130B4280BE4...
# 2367  b'<div class="ExternalClassC9333E76130B4280BE4...
# 2370  b'<div class="ExternalClassC9333E76130B4280BE4...
# 2371  b'<div class="ExternalClassC9333E76130B4280BE4...
# 2520  b'<div class="ExternalClassFAC31D10071B445C93D...
# ...                                                 ...
# 2458  b'<div class="ExternalClassEC86420A61A64D089B7...
# 2481  b'<div class="ExternalClass1EE8A09B31F6418C97F...
# 2423  b'<div class="ExternalClass25A0E1C4C944475AA3B...
# 2304  b'<div class="ExternalClass37ECDF16831C42DFB97...
# 2377  b'<div class="ExternalClassC9333E76130B4280BE4...
#
#                                  extracted_content_body  \
# 2365  INSERT YOUR CHILDS NAME HERE\nMAX 15 CHAR\n\nP...
# 2367  INSERT YOUR CHILDS NAME HERE\nMAX 15 CHAR\n\nP...
# 2370  INSERT YOUR CHILDS NAME HERE\nMAX 15 CHAR\n\nP...
# 2371  INSERT YOUR CHILDS NAME HERE\nMAX 15 CHAR\n\nP...
# 2520  3 BES TO BEAT DIABETES \n1 Be Aware\nThe more ...
# ...                                                 ...
# 2458                                                 a-
# 2481  3 BES TO BEAT DIABETES \nOn this page\n1. Over...
# 2423  - Menu\n- Home\n- Healthy Eating\n- Physical A...
# 2304  - Menu\n- Home\n- Healthy Eating\n- Physical A...
# 2377  INSERT YOUR CHILDS NAME HERE\nMAX 15 CHAR\n\nP...
#
#                      pr_name date_modified   content_category  page_views  \
# 2365                    None          None  program-sub-pages           0
# 2367                    None          None  program-sub-pages           0
# 2370                    None          None  program-sub-pages           0
# 2371                    None          None  program-sub-pages           0
# 2520      Ministry of Health          None           programs       20626
# ...                      ...           ...                ...         ...
# 2458  Health Promotion Board          None  program-sub-pages           0
# 2481      Ministry of Health          None  program-sub-pages           0
# 2423  Health Promotion Board          None  program-sub-pages           0
# 2304  Health Promotion Board          None  program-sub-pages         519
# 2377                    None          None  program-sub-pages           0
#
#       to_remove         remove_type
# 2365       True  Duplicated Content
# 2367       True  Duplicated Content
# 2370       True  Duplicated Content
# 2371       True  Duplicated Content
# 2520       True  Duplicated Content
# ...         ...                 ...
# 2458       True  Duplicated Content
# 2481       True  Duplicated Content
# 2423       True  Duplicated Content
# 2304       True  Duplicated Content
# 2377       True  Duplicated Content
#
# [68 rows x 12 columns]

# %%
df_content_kept = df_duplicated_content.drop_duplicates(subset=["extracted_content_body"], keep="last")

display(df_content_kept)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                       content_name  \
# 2385  1435297           Diabetes Hub: Food Diet_food-diet_Level1
# 2521  1434614           Diabetes Hub: Guide to Managing Diabetes
# 2248  1435281  Diabetes Hub: Guide to Managing Diabetes_what-...
# 2261  1435188  Download resources | Diabetes Hub_download-res...
# 2513  1434580                 Eat, Drink, Shop Healthy Challenge
# 2561  1434570      National Steps Challenge™ Community Challenge
# 2335  1434883  Parent Hub - Events: Postnatal Workshop_postna...
# 2206  1435225  Parent Hub - Events: Your Child's First Influe...
# 2204  1434829  Parent Hub: We're Expecting - View All_all-ite...
# 1420  1497409                           conversations-abt-vaping
# 1497  1469472               parents-model-little-habits-everyday
# 2458  1435245                         Persona B_persona-b_Level1
# 2481  1435160  Setting goals | Diabetes Hub_setting-goals_Level1
# 2304  1434977  Take the first step with your loved ones_physi...
# 2377  1473804                                         sleep-test
#
#                                                   title  \
# 2385                            Diabetes Hub: Food Diet
# 2521           Diabetes Hub: Guide to Managing Diabetes
# 2248           Diabetes Hub: Guide to Managing Diabetes
# 2261                  Download resources | Diabetes Hub
# 2513                 Eat, Drink, Shop Healthy Challenge
# 2561      National Steps Challenge™ Community Challenge
# 2335            Parent Hub - Events: Postnatal Workshop
# 2206  Parent Hub - Events: Your Child's First Influe...
# 2204             Parent Hub: We're Expecting - View All
# 1420  Parenting Insights: Strategies for Conversatio...
# 1497  Parents Model the Way With Little Habits Every...
# 2458                                          Persona B
# 2481                       Setting goals | Diabetes Hub
# 2304           Take the first step with your loved ones
# 2377                                         sleep-test
#
#                                                full_url  \
# 2385  https://www.healthhub.sg/programmes/diabetes-h...
# 2521   https://www.healthhub.sg/programmes/diabetes-hub
# 2248  https://www.healthhub.sg/programmes/diabetes-h...
# 2261  https://www.healthhub.sg/programmes/diabetes-h...
# 2513  https://www.healthhub.sg/programmes/eat-drink-...
# 2561  https://www.healthhub.sg/programmes/community-...
# 2335  https://www.healthhub.sg/programmes/parent-hub...
# 2206  https://www.healthhub.sg/programmes/parent-hub...
# 2204  https://www.healthhub.sg/programmes/parent-hub...
# 1420  https://www.healthhub.sg/live-healthy/conversa...
# 1497  https://www.healthhub.sg/live-healthy/parents-...
# 2458  https://www.healthhub.sg/programmes/ga-testing...
# 2481  https://www.healthhub.sg/programmes/diabetes-h...
# 2304  https://www.healthhub.sg/programmes/howareyoud...
# 2377  https://www.healthhub.sg/programmes/parent-hub...
#
#                                            content_body  \
# 2385  b'<div class="ExternalClassDBD84B4B9B3D4351B32...
# 2521  b'<div class="ExternalClassFAC31D10071B445C93D...
# 2248  b'<div class="ExternalClass97CD7340880740FE8EA...
# 2261  b'<div class="ExternalClassFC921D6E662D4F8E8B5...
# 2513  b'<div class="hpb-container nutrition" data-pa...
# 2561  b'<div class="ExternalClass5327ED73209A4220AEF...
# 2335  b'<div class="ExternalClass8B5B2ED2AA604262BC6...
# 2206  b'<div class="ExternalClass2490DF68B4D6478EA82...
# 2204  b'<div class="ExternalClassDDD40EFE8BE2485598A...
# 1420  b'<div class="ExternalClassB1D1BA8198604AF5897...
# 1497  b'<h2>Physical Activity Fun Both in and Out of...
# 2458  b'<div class="ExternalClassEC86420A61A64D089B7...
# 2481  b'<div class="ExternalClass1EE8A09B31F6418C97F...
# 2304  b'<div class="ExternalClass37ECDF16831C42DFB97...
# 2377  b'<div class="ExternalClassC9333E76130B4280BE4...
#
#                                  extracted_content_body  \
# 2385                                                 aa
# 2521  3 BES TO BEAT DIABETES \n1 Be Aware\nThe more ...
# 2248  3 BES TO BEAT DIABETES \nOn this page\n1. What...
# 2261  3 BES TO BEAT DIABETES \n\nNational Diabetes R...
# 2513  Menu  \n\nWith effect from 28 Aug 2023, please...
# 2561  The National Steps Challenge\nSeason 5 Communi...
# 2335  you may also\n\nlike  Child Health Booklet\nAf...
# 2206  you may also\n\nlike  Child Health Booklet\nAf...
# 2204                         Wed love to hear from you!
# 1420  Synopsis: Learn proactive parenting strategies...
# 1497  Physical Activity Fun Both in and Out of the S...
# 2458                                                 a-
# 2481  3 BES TO BEAT DIABETES \nOn this page\n1. Over...
# 2304  - Menu\n- Home\n- Healthy Eating\n- Physical A...
# 2377  INSERT YOUR CHILDS NAME HERE\nMAX 15 CHAR\n\nP...
#
#                      pr_name date_modified       content_category  page_views  \
# 2385      Ministry of Health          None      program-sub-pages           0
# 2521      Ministry of Health          None               programs       20626
# 2248      Ministry of Health          None      program-sub-pages        1254
# 2261      Ministry of Health          None      program-sub-pages        1081
# 2513  Health Promotion Board          None               programs       45972
# 2561  Health Promotion Board          None               programs          15
# 2335  Health Promotion Board          None      program-sub-pages         259
# 2206  Health Promotion Board          None      program-sub-pages        3719
# 2204  Health Promotion Board          None      program-sub-pages        4152
# 1420                    None          None  live-healthy-articles          58
# 1497                    None          None  live-healthy-articles           3
# 2458  Health Promotion Board          None      program-sub-pages           0
# 2481      Ministry of Health          None      program-sub-pages           0
# 2304  Health Promotion Board          None      program-sub-pages         519
# 2377                    None          None      program-sub-pages           0
#
#       to_remove         remove_type
# 2385       True  Duplicated Content
# 2521       True  Duplicated Content
# 2248       True  Duplicated Content
# 2261       True  Duplicated Content
# 2513       True  Duplicated Content
# 2561       True  Duplicated Content
# 2335       True  Duplicated Content
# 2206       True  Duplicated Content
# 2204       True  Duplicated Content
# 1420       True  Duplicated Content
# 1497       True  Duplicated Content
# 2458       True  Duplicated Content
# 2481       True  Duplicated Content
# 2304       True  Duplicated Content
# 2377       True  Duplicated Content

# %%
df_content_kept["content_body"].iloc[0]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# b'<div class="ExternalClassDBD84B4B9B3D4351B325F2085E1351A8"><p>\xe2\x80\x8ba<br></p></div>'

# %%
df_content_dropped = df_duplicated_content[~df_duplicated_content["id"].isin(list(df_content_kept["id"]))]

display(df_content_dropped)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                       content_name  \
# 2365  1473807                                       sleep-test-2
# 2367  1473810                            sleep-test-2-change-css
# 2370  1473813                      sleep-test-3-css-change-again
# 2371  1473816                                     sleep-test-dup
# 2520  1434652             3 Be's To Beat Diabetes | Diabetes Hub
# 2249  1435129  Be Aware - What is diabetes_what-is-diabetes_L...
# 2407  1435299  Diabetes Hub: Exercise Activity_exercise-activ...
# 2262  1435331  Diabetes Hub: Guide to Managing Diabetes_downl...
# 2389  1435327  Diabetes Hub: Guide to Managing Diabetes_setti...
# 1515  1445972                                      Eat Well, Mum
# 2180  1435240  Eat, Drink, Shop Healthy Challenge_eat-drink-s...
# 2357  1434823  National Steps Challenge™_community-challenge_...
# 2211  1434837  Parent Hub - Events_activities-workshops-paren...
# 2305  1434859  Parent Hub - Events Positive Parenting Program...
# 2338  1435048  Parent Hub - Events: Dear Mama, It's Okay Pare...
# 2378  1435091  Parent Hub - Events: Dear Mama, It's Okay, Par...
# 2341  1435099  Parent Hub - Events: Dear Papa, It's Okay, Par...
# 2336  1434971  Parent Hub - Events: Eat Right Feel Right_eat-...
# 2339  1435047  Parent Hub - Events: Eat Right Feel Right Gran...
# 2347  1434877  Parent Hub - Events: Family Fun Time_family-fu...
# 2340  1435219  Parent Hub - Events: Family Fun Time Carnival_...
# 2368  1504038                               into-the-hawkerverse
# 2220  1435119  Parent Hub - Events: Mental Well-Being Worksho...
# 2213  1434845        Parent Hub - Events: Move It_move-it_Level2
# 2247  1435356  Parent Hub: 0-2 Years - 1st Few Months_first-f...
# 2326  1435360  Parent Hub: 0-2 Years - Baby Care_baby-care_Le...
# 2320  1434745  Parent Hub: 0-2 Years - Baby Safety_baby-safet...
# 2314  1434749  Parent Hub: 0-2 Years - Common Status_common-s...
# 2228  1434746  Parent Hub: 0-2 Years - Growth and Development...
# 2315  1435251  Parent Hub: 0-2 Years - Immunisation_immunisat...
# 2280  1434750  Parent Hub: 0-2 Years - Immunisation_0_2_immun...
# 2207  1434827  Parent Hub: 0-2 Years - View All_all-items-zer...
# 2313  1434767  Parent Hub: 3-6 Years - Common Conditions_comm...
# 2216  1434761  Parent Hub: 3-6 Years - Healthy, Active Family...
# 2202  1434757  Parent Hub: 3-6 Years - Nutrition and Healthy ...
# 2266  1434759  Parent Hub: 3-6 Years - Oral Care and Eye Care...
# 2294  1434763  Parent Hub: 3-6 Years - Safety and Hygiene_saf...
# 2254  1434833  Parent Hub: 3-6 Years - View All_all-items-thr...
# 2295  1434771  Parent Hub: 7-12 Years - Building Bonds_family...
# 2375  1434825  Parent Hub: 7-12 Years - Emotional Health_emot...
# 2242  1434769  Parent Hub: 7-12 Years - Healthy Eating_health...
# 2296  1434773  Parent Hub: 7-12 Years - Healthy at School_sch...
# 2232  1434774  Parent Hub: 7-12 Years - Sparkly Teeth and Eye...
# 2251  1434835  Parent Hub: 7-12 Years - View All_all-items-se...
# 2369  1434819  Parent Hub: Teens - Emotional Health_emotional...
# 2332  1434838  Parent Hub: Teens - View All_all-items-adolesc...
# 2226  1435083  Parent Hub: We're Expecting - Gestational Diab...
# 2229  1435351  Parent Hub: We're Expecting - Trimester 1_trim...
# 2239  1435353  Parent Hub: We're Expecting - Trimester 2_trim...
# 2276  1435355  Parent Hub: We're Expecting - Trimester 3_trim...
# 1446  1495949                         conversations-about-vaping
# 2480  1435247                         Persona A_persona-a_Level1
# 2423  1434979  Take the first step with your loved ones_healt...
#
#                                                   title  \
# 2365              3 - 6 Years: Good Sleep Captain Sleep
# 2367              3 - 6 Years: Good Sleep Captain Sleep
# 2370              3 - 6 Years: Good Sleep Captain Sleep
# 2371              3 - 6 Years: Good Sleep Captain Sleep
# 2520             3 Be's To Beat Diabetes | Diabetes Hub
# 2249                        Be Aware - What is diabetes
# 2407                    Diabetes Hub: Exercise Activity
# 2262           Diabetes Hub: Guide to Managing Diabetes
# 2389           Diabetes Hub: Guide to Managing Diabetes
# 1515                                      Eat Well, Mum
# 2180                 Eat, Drink, Shop Healthy Challenge
# 2357                          National Steps Challenge™
# 2211                                Parent Hub - Events
# 2305   Parent Hub - Events Positive Parenting Programme
# 2338  Parent Hub - Events: Dear Mama, It's Okay Pare...
# 2378  Parent Hub - Events: Dear Mama, It's Okay, Par...
# 2341  Parent Hub - Events: Dear Papa, It's Okay, Par...
# 2336          Parent Hub - Events: Eat Right Feel Right
# 2339  Parent Hub - Events: Eat Right Feel Right Gran...
# 2347               Parent Hub - Events: Family Fun Time
# 2340      Parent Hub - Events: Family Fun Time Carnival
# 2368          Parent Hub - Events: Into the Hawkerverse
# 2220  Parent Hub - Events: Mental Well-Being Worksho...
# 2213                       Parent Hub - Events: Move It
# 2247             Parent Hub: 0-2 Years - 1st Few Months
# 2326                  Parent Hub: 0-2 Years - Baby Care
# 2320                Parent Hub: 0-2 Years - Baby Safety
# 2314              Parent Hub: 0-2 Years - Common Status
# 2228     Parent Hub: 0-2 Years - Growth and Development
# 2315               Parent Hub: 0-2 Years - Immunisation
# 2280               Parent Hub: 0-2 Years - Immunisation
# 2207                   Parent Hub: 0-2 Years - View All
# 2313          Parent Hub: 3-6 Years - Common Conditions
# 2216     Parent Hub: 3-6 Years - Healthy, Active Family
# 2202  Parent Hub: 3-6 Years - Nutrition and Healthy ...
# 2266     Parent Hub: 3-6 Years - Oral Care and Eye Care
# 2294         Parent Hub: 3-6 Years - Safety and Hygiene
# 2254                   Parent Hub: 3-6 Years - View All
# 2295            Parent Hub: 7-12 Years - Building Bonds
# 2375          Parent Hub: 7-12 Years - Emotional Health
# 2242            Parent Hub: 7-12 Years - Healthy Eating
# 2296         Parent Hub: 7-12 Years - Healthy at School
# 2232    Parent Hub: 7-12 Years - Sparkly Teeth and Eyes
# 2251                  Parent Hub: 7-12 Years - View All
# 2369               Parent Hub: Teens - Emotional Health
# 2332                       Parent Hub: Teens - View All
# 2226  Parent Hub: We're Expecting - Gestational Diab...
# 2229          Parent Hub: We're Expecting - Trimester 1
# 2239          Parent Hub: We're Expecting - Trimester 2
# 2276          Parent Hub: We're Expecting - Trimester 3
# 1446  Parenting Insights: Strategies for Conversatio...
# 2480                                          Persona A
# 2423           Take the first step with your loved ones
#
#                                                full_url  \
# 2365  https://www.healthhub.sg/programmes/parent-hub...
# 2367  https://www.healthhub.sg/programmes/parent-hub...
# 2370  https://www.healthhub.sg/programmes/parent-hub...
# 2371  https://www.healthhub.sg/programmes/parent-hub...
# 2520   https://www.healthhub.sg/programmes/diabetes-hub
# 2249  https://www.healthhub.sg/programmes/diabetes-h...
# 2407  https://www.healthhub.sg/programmes/diabetes-h...
# 2262  https://www.healthhub.sg/programmes/diabetes-h...
# 2389  https://www.healthhub.sg/programmes/diabetes-h...
# 1515  https://www.healthhub.sg/live-healthy/parents-...
# 2180  https://www.healthhub.sg/programmes/nutrition-...
# 2357  https://www.healthhub.sg/programmes/nsc/commun...
# 2211  https://www.healthhub.sg/programmes/parent-hub...
# 2305  https://www.healthhub.sg/programmes/parent-hub...
# 2338  https://www.healthhub.sg/programmes/parent-hub...
# 2378  https://www.healthhub.sg/programmes/parent-hub...
# 2341  https://www.healthhub.sg/programmes/parent-hub...
# 2336  https://www.healthhub.sg/programmes/parent-hub...
# 2339  https://www.healthhub.sg/programmes/parent-hub...
# 2347  https://www.healthhub.sg/programmes/parent-hub...
# 2340  https://www.healthhub.sg/programmes/parent-hub...
# 2368  https://www.healthhub.sg/programmes/parent-hub...
# 2220  https://www.healthhub.sg/programmes/parent-hub...
# 2213  https://www.healthhub.sg/programmes/parent-hub...
# 2247  https://www.healthhub.sg/programmes/parent-hub...
# 2326  https://www.healthhub.sg/programmes/parent-hub...
# 2320  https://www.healthhub.sg/programmes/parent-hub...
# 2314  https://www.healthhub.sg/programmes/parent-hub...
# 2228  https://www.healthhub.sg/programmes/parent-hub...
# 2315  https://www.healthhub.sg/programmes/parent-hub...
# 2280  https://www.healthhub.sg/programmes/parent-hub...
# 2207  https://www.healthhub.sg/programmes/parent-hub...
# 2313  https://www.healthhub.sg/programmes/parent-hub...
# 2216  https://www.healthhub.sg/programmes/parent-hub...
# 2202  https://www.healthhub.sg/programmes/parent-hub...
# 2266  https://www.healthhub.sg/programmes/parent-hub...
# 2294  https://www.healthhub.sg/programmes/parent-hub...
# 2254  https://www.healthhub.sg/programmes/parent-hub...
# 2295  https://www.healthhub.sg/programmes/parent-hub...
# 2375  https://www.healthhub.sg/programmes/parent-hub...
# 2242  https://www.healthhub.sg/programmes/parent-hub...
# 2296  https://www.healthhub.sg/programmes/parent-hub...
# 2232  https://www.healthhub.sg/programmes/parent-hub...
# 2251  https://www.healthhub.sg/programmes/parent-hub...
# 2369  https://www.healthhub.sg/programmes/parent-hub...
# 2332  https://www.healthhub.sg/programmes/parent-hub...
# 2226  https://www.healthhub.sg/programmes/parent-hub...
# 2229  https://www.healthhub.sg/programmes/parent-hub...
# 2239  https://www.healthhub.sg/programmes/parent-hub...
# 2276  https://www.healthhub.sg/programmes/parent-hub...
# 1446  https://www.healthhub.sg/live-healthy/conversa...
# 2480  https://www.healthhub.sg/programmes/ga-testing...
# 2423  https://www.healthhub.sg/programmes/indian_out...
#
#                                            content_body  \
# 2365  b'<div class="ExternalClassC9333E76130B4280BE4...
# 2367  b'<div class="ExternalClassC9333E76130B4280BE4...
# 2370  b'<div class="ExternalClassC9333E76130B4280BE4...
# 2371  b'<div class="ExternalClassC9333E76130B4280BE4...
# 2520  b'<div class="ExternalClassFAC31D10071B445C93D...
# 2249  b'<div class="ExternalClass97CD7340880740FE8EA...
# 2407  b'<div class="ExternalClass5EC0C9C8695B41A1AB3...
# 2262  b'<div class="ExternalClassFC921D6E662D4F8E8B5...
# 2389  b'<div class="ExternalClass1EE8A09B31F6418C97F...
# 1515  b'<h2><img alt="PY-Marina-Bay-Selfie_and_entry...
# 2180  b'<div class="hpb-container nutrition" data-pa...
# 2357  b'<div class="ExternalClass5327ED73209A4220AEF...
# 2211  b'<div class="ExternalClass152DF7EF76D14E678A8...
# 2305  b'<div class="ExternalClassACDC258C95DD48B6976...
# 2338  b'<div class="ExternalClass4BE78AE2C4B449AFB1E...
# 2378  b'<div class="ExternalClass4BE78AE2C4B449AFB1E...
# 2341  b'<div class="ExternalClass4BE78AE2C4B449AFB1E...
# 2336  b'<div class="ExternalClassC55663C3713E48D69A5...
# 2339  b'<div class="ExternalClass1C41737F30ED49EFB88...
# 2347  b'<div class="ExternalClassC55663C3713E48D69A5...
# 2340  b'<div class="ExternalClassFCC294BDA3FE410AADF...
# 2368  b'<div class="ExternalClass2490DF68B4D6478EA82...
# 2220  b'<div class="ExternalClassFCC294BDA3FE410AADF...
# 2213  b'<div class="ExternalClassC55663C3713E48D69A5...
# 2247  b'<div class="ExternalClass26545EBC3C104CDA815...
# 2326  b'<div class="ExternalClass08626FC4DE294799A6F...
# 2320  b'<div class="ExternalClassE6BA7438FBF24AA49B4...
# 2314  b'<div class="ExternalClass17E59A22848241DEB1E...
# 2228  b'<div class="ExternalClassC59ED8215A29449DAEA...
# 2315  b'<div class="ExternalClass755AC6EC2AFC4E349FA...
# 2280  b'<div class="ExternalClass2939547DB9914F0C97F...
# 2207  b'<div class="ExternalClass0E3B179033BA4689B98...
# 2313  b'<div class="ExternalClass420433C2E9AA49599A1...
# 2216  b'<div class="ExternalClassB7D0EAE3714447EB99D...
# 2202  b'<div class="ExternalClassB6D31967A77942B6912...
# 2266  b'<div class="ExternalClass11908BB426DC4C40827...
# 2294  b'<div class="ExternalClass2A7F77FF5A0A44248C0...
# 2254  b'<div class="ExternalClass944D808844F241D5837...
# 2295  b'<div class="ExternalClass62121EE81900469F877...
# 2375  b'<div class="ExternalClass16A2C186E7294AD5BB1...
# 2242  b'<div class="ExternalClass0A5C5A7F37E8484C914...
# 2296  b'<div class="ExternalClass2770EF056B0A4A02B2B...
# 2232  b'<div class="ExternalClass679540320FCF4DE5817...
# 2251  b'<div class="ExternalClass62121EE81900469F877...
# 2369  b'<div class="ExternalClassDBDC536DC28F463D89F...
# 2332  b'<div class="ExternalClassCD0CD6B849DE4FF198A...
# 2226  b'<div class="ExternalClassE1C4E80A9D8341CCAA6...
# 2229  b'<div class="ExternalClass668658BAA1674692ADF...
# 2239  b'<div class="ExternalClass4CF9852EAFD84EFB88B...
# 2276  b'<div class="ExternalClass52B3866B4B1E4807993...
# 1446  b'<div class="ExternalClassB1D1BA8198604AF5897...
# 2480  b'<div class="ExternalClass9137B4B3E30343FFA15...
# 2423  b'<div class="ExternalClass25A0E1C4C944475AA3B...
#
#                                  extracted_content_body  \
# 2365  INSERT YOUR CHILDS NAME HERE\nMAX 15 CHAR\n\nP...
# 2367  INSERT YOUR CHILDS NAME HERE\nMAX 15 CHAR\n\nP...
# 2370  INSERT YOUR CHILDS NAME HERE\nMAX 15 CHAR\n\nP...
# 2371  INSERT YOUR CHILDS NAME HERE\nMAX 15 CHAR\n\nP...
# 2520  3 BES TO BEAT DIABETES \n1 Be Aware\nThe more ...
# 2249  3 BES TO BEAT DIABETES \nOn this page\n1. What...
# 2407                                                 aa
# 2262  3 BES TO BEAT DIABETES \n\nNational Diabetes R...
# 2389  3 BES TO BEAT DIABETES \nOn this page\n1. Over...
# 1515  Physical Activity Fun Both in and Out of the S...
# 2180  Menu  \n\nWith effect from 28 Aug 2023, please...
# 2357  The National Steps Challenge\nSeason 5 Communi...
# 2211  you may also\n\nlike  Child Health Booklet\nAf...
# 2305  you may also\n\nlike  Child Health Booklet\nAf...
# 2338  you may also\n\nlike  Child Health Booklet\nAf...
# 2378  you may also\n\nlike  Child Health Booklet\nAf...
# 2341  you may also\n\nlike  Child Health Booklet\nAf...
# 2336  you may also\n\nlike  Child Health Booklet\nAf...
# 2339  you may also\n\nlike  Child Health Booklet\nAf...
# 2347  you may also\n\nlike  Child Health Booklet\nAf...
# 2340  you may also\n\nlike  Child Health Booklet\nAf...
# 2368  you may also\n\nlike  Child Health Booklet\nAf...
# 2220  you may also\n\nlike  Child Health Booklet\nAf...
# 2213  you may also\n\nlike  Child Health Booklet\nAf...
# 2247                         Wed love to hear from you!
# 2326                         Wed love to hear from you!
# 2320                         Wed love to hear from you!
# 2314                         Wed love to hear from you!
# 2228                         Wed love to hear from you!
# 2315                         Wed love to hear from you!
# 2280                         Wed love to hear from you!
# 2207                         Wed love to hear from you!
# 2313                         Wed love to hear from you!
# 2216                         Wed love to hear from you!
# 2202                         Wed love to hear from you!
# 2266                         Wed love to hear from you!
# 2294                         Wed love to hear from you!
# 2254                         Wed love to hear from you!
# 2295                         Wed love to hear from you!
# 2375                         Wed love to hear from you!
# 2242                         Wed love to hear from you!
# 2296                         Wed love to hear from you!
# 2232                         Wed love to hear from you!
# 2251                         Wed love to hear from you!
# 2369                         Wed love to hear from you!
# 2332                         Wed love to hear from you!
# 2226                         Wed love to hear from you!
# 2229                         Wed love to hear from you!
# 2239                         Wed love to hear from you!
# 2276                         Wed love to hear from you!
# 1446  Synopsis: Learn proactive parenting strategies...
# 2480                                                 a-
# 2423  - Menu\n- Home\n- Healthy Eating\n- Physical A...
#
#                      pr_name                 date_modified  \
# 2365                    None                          None
# 2367                    None                          None
# 2370                    None                          None
# 2371                    None                          None
# 2520      Ministry of Health                          None
# 2249      Ministry of Health                          None
# 2407      Ministry of Health                          None
# 2262      Ministry of Health                          None
# 2389      Ministry of Health                          None
# 1515  Health Promotion Board  2022-11-15T08:46:52.0000000Z
# 2180  Health Promotion Board                          None
# 2357  Health Promotion Board                          None
# 2211  Health Promotion Board                          None
# 2305  Health Promotion Board                          None
# 2338  Health Promotion Board                          None
# 2378  Health Promotion Board                          None
# 2341  Health Promotion Board                          None
# 2336  Health Promotion Board                          None
# 2339  Health Promotion Board                          None
# 2347  Health Promotion Board                          None
# 2340  Health Promotion Board                          None
# 2368                    None                          None
# 2220  Health Promotion Board                          None
# 2213  Health Promotion Board                          None
# 2247  Health Promotion Board                          None
# 2326  Health Promotion Board                          None
# 2320  Health Promotion Board                          None
# 2314  Health Promotion Board                          None
# 2228  Health Promotion Board                          None
# 2315  Health Promotion Board                          None
# 2280  Health Promotion Board                          None
# 2207  Health Promotion Board                          None
# 2313  Health Promotion Board                          None
# 2216  Health Promotion Board                          None
# 2202  Health Promotion Board                          None
# 2266  Health Promotion Board                          None
# 2294  Health Promotion Board                          None
# 2254  Health Promotion Board                          None
# 2295  Health Promotion Board                          None
# 2375  Health Promotion Board                          None
# 2242  Health Promotion Board                          None
# 2296  Health Promotion Board                          None
# 2232  Health Promotion Board                          None
# 2251  Health Promotion Board                          None
# 2369  Health Promotion Board                          None
# 2332  Health Promotion Board                          None
# 2226  Health Promotion Board                          None
# 2229  Health Promotion Board                          None
# 2239  Health Promotion Board                          None
# 2276  Health Promotion Board                          None
# 1446                    None                          None
# 2480  Health Promotion Board                          None
# 2423  Health Promotion Board                          None
#
#            content_category  page_views  to_remove         remove_type
# 2365      program-sub-pages           0       True  Duplicated Content
# 2367      program-sub-pages           0       True  Duplicated Content
# 2370      program-sub-pages           0       True  Duplicated Content
# 2371      program-sub-pages           0       True  Duplicated Content
# 2520               programs       20626       True  Duplicated Content
# 2249      program-sub-pages        1254       True  Duplicated Content
# 2407      program-sub-pages           0       True  Duplicated Content
# 2262      program-sub-pages        1081       True  Duplicated Content
# 2389      program-sub-pages           0       True  Duplicated Content
# 1515  live-healthy-articles           0       True  Duplicated Content
# 2180      program-sub-pages       11764       True  Duplicated Content
# 2357      program-sub-pages         129       True  Duplicated Content
# 2211      program-sub-pages        3330       True  Duplicated Content
# 2305      program-sub-pages         476       True  Duplicated Content
# 2338      program-sub-pages         216       True  Duplicated Content
# 2378      program-sub-pages           0       True  Duplicated Content
# 2341      program-sub-pages         216       True  Duplicated Content
# 2336      program-sub-pages         259       True  Duplicated Content
# 2339      program-sub-pages         216       True  Duplicated Content
# 2347      program-sub-pages         173       True  Duplicated Content
# 2340      program-sub-pages         216       True  Duplicated Content
# 2368      program-sub-pages           0       True  Duplicated Content
# 2220      program-sub-pages        2163       True  Duplicated Content
# 2213      program-sub-pages        3200       True  Duplicated Content
# 2247      program-sub-pages        1254       True  Duplicated Content
# 2326      program-sub-pages         346       True  Duplicated Content
# 2320      program-sub-pages         389       True  Duplicated Content
# 2314      program-sub-pages         432       True  Duplicated Content
# 2228      program-sub-pages        1773       True  Duplicated Content
# 2315      program-sub-pages         432       True  Duplicated Content
# 2280      program-sub-pages         778       True  Duplicated Content
# 2207      program-sub-pages        3546       True  Duplicated Content
# 2313      program-sub-pages         475       True  Duplicated Content
# 2216      program-sub-pages        2768       True  Duplicated Content
# 2202      program-sub-pages        4455       True  Duplicated Content
# 2266      program-sub-pages        1037       True  Duplicated Content
# 2294      program-sub-pages         562       True  Duplicated Content
# 2254      program-sub-pages        1167       True  Duplicated Content
# 2295      program-sub-pages         562       True  Duplicated Content
# 2375      program-sub-pages           0       True  Duplicated Content
# 2242      program-sub-pages        1384       True  Duplicated Content
# 2296      program-sub-pages         562       True  Duplicated Content
# 2232      program-sub-pages        1644       True  Duplicated Content
# 2251      program-sub-pages        1211       True  Duplicated Content
# 2369      program-sub-pages           0       True  Duplicated Content
# 2332      program-sub-pages         303       True  Duplicated Content
# 2226      program-sub-pages        1816       True  Duplicated Content
# 2229      program-sub-pages        1773       True  Duplicated Content
# 2239      program-sub-pages        1470       True  Duplicated Content
# 2276      program-sub-pages         822       True  Duplicated Content
# 1446  live-healthy-articles          29       True  Duplicated Content
# 2480      program-sub-pages           0       True  Duplicated Content
# 2423      program-sub-pages           0       True  Duplicated Content

# %%
df_keep = flag_duplicated(df_keep, [], column="full_url")
df_duplicated_url = df_keep[(df_keep["remove_type"] == "Duplicated URL")].sort_values(["full_url", "date_modified"])

display(df_duplicated_url)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                       content_name  \
# 1067  1445629                     Sliced Fish with Bee Hoon Soup
# 1066  1445828             Recipe : Sliced Fish and Bee Hoon Soup
# 620   1446081                        Outdoor Activities for Kids
# 621   1444496           Weekend Activities: 5 Ideas for Families
# 1215  1443608                                         Mee Goreng
# 1212  1445798                                Recipe : Mee Goreng
# 1370  1445829                               Recipe : Sayur Lodeh
# 1369  1444751          Cooking with Chef Mel Dean... Sayur Lodeh
# 657   1444417      The A-Z Guide to Healthy Lifestyle Activities
# 656   1446090    The A-Z Guide To A Healthy And Active Lifestyle
# 2306  1435335  Diabetes Hub: Guide to Managing Diabetes_care-...
# 2307  1435183  Care team resources | Diabetes Hub_care-team-r...
#
#                                                 title  \
# 1067                   Sliced Fish with Bee Hoon Soup
# 1066           Recipe : Sliced Fish and Bee Hoon Soup
# 620                       Outdoor Activities for Kids
# 621              Outdoor Activities for Your Children
# 1215                                       Mee Goreng
# 1212                              Recipe : Mee Goreng
# 1370                             Recipe : Sayur Lodeh
# 1369        Cooking with Chef Mel Dean... Sayur Lodeh
# 657     The A-Z Guide to Healthy Lifestyle Activities
# 656   The A-Z Guide To A Healthy And Active Lifestyle
# 2306         Diabetes Hub: Guide to Managing Diabetes
# 2307               Care team resources | Diabetes Hub
#
#                                                full_url  \
# 1067  https://www.healthhub.sg/live-healthy/fish-bee...
# 1066  https://www.healthhub.sg/live-healthy/fish-bee...
# 620   https://www.healthhub.sg/live-healthy/ideas-fo...
# 621   https://www.healthhub.sg/live-healthy/ideas-fo...
# 1215   https://www.healthhub.sg/live-healthy/mee-goreng
# 1212   https://www.healthhub.sg/live-healthy/mee-goreng
# 1370  https://www.healthhub.sg/live-healthy/sayur-lodeh
# 1369  https://www.healthhub.sg/live-healthy/sayur-lodeh
# 657   https://www.healthhub.sg/live-healthy/the-a-z-...
# 656   https://www.healthhub.sg/live-healthy/the-a-z-...
# 2306  https://www.healthhub.sg/programmes/diabetes-h...
# 2307  https://www.healthhub.sg/programmes/diabetes-h...
#
#                                            content_body  \
# 1067  b'<div class="ExternalClassF5C1DD3FA7E84963A88...
# 1066  b'<div class="ExternalClassB39C037E02BC47C6A3C...
# 620   b'<div class="ExternalClass196D7C5AC7594C8E8BC...
# 621   b'<div class="ExternalClass196D7C5AC7594C8E8BC...
# 1215  b'<div class="ExternalClass60865CF1F8FA4603ABA...
# 1212  b'<div class="ExternalClass875BB3A3A2F84BE4A49...
# 1370  b'<div class="ExternalClass8FB2510AE8C541EEADF...
# 1369  b'<div class="ExternalClassF0D563DE92F04D3C9F6...
# 657   b'<div class="ExternalClassBA1FDDD033444100B98...
# 656   b'<div class="ExternalClassBA1FDDD033444100B98...
# 2306  b'<div class="ExternalClass0F99B891157147D4A5D...
# 2307  b'<div class="ExternalClassFDB7091A35194B5EBBA...
#
#                                  extracted_content_body  \
# 1067  Mouthwatering sliced fish with bee hoon soup\n...
# 1066  Looking to bring some wholesome goodness home?...
# 620   The lack of outdoor activity among children co...
# 621   The lack of insufficient outdoor activity amon...
# 1215  By KK Womens and Childrens Hospital and Ms Hen...
# 1212  Looking to bring some wholesome goodness home?...
# 1370  Looking to bring some wholesome goodness home?...
# 1369  Sayur Lodeh is everyone's favourite dish, espe...
# 657   Physical activity is key to staying healthy, b...
# 656   Physical activity is key to staying healthy, b...
# 2306  -  \n Home>\nCare Team Resources\n- Downloads\...
# 2307  3 BES TO BEAT DIABETES \n\nCare Team Resources...
#
#                                  pr_name                 date_modified  \
# 1067              Health Promotion Board  2022-11-15T08:35:26.0000000Z
# 1066              Health Promotion Board  2022-11-15T08:35:31.0000000Z
# 620               Health Promotion Board  2022-11-15T08:51:15.0000000Z
# 621               Health Promotion Board  2023-03-23T08:09:13.0000000Z
# 1215  KK Women's and Children's Hospital  2021-12-21T08:10:47.0000000Z
# 1212              Health Promotion Board  2022-11-15T08:35:25.0000000Z
# 1370              Health Promotion Board  2022-11-15T08:35:29.0000000Z
# 1369              Health Promotion Board  2022-11-15T08:35:36.0000000Z
# 657               Health Promotion Board  2022-11-15T08:41:41.0000000Z
# 656               Health Promotion Board  2023-04-04T03:01:38.0000000Z
# 2306                  Ministry of Health                          None
# 2307                  Ministry of Health                          None
#
#            content_category  page_views  to_remove     remove_type
# 1067  live-healthy-articles         378       True  Duplicated URL
# 1066  live-healthy-articles         378       True  Duplicated URL
# 620   live-healthy-articles        1179       True  Duplicated URL
# 621   live-healthy-articles        1179       True  Duplicated URL
# 1215  live-healthy-articles         276       True  Duplicated URL
# 1212  live-healthy-articles         276       True  Duplicated URL
# 1370  live-healthy-articles         187       True  Duplicated URL
# 1369  live-healthy-articles         187       True  Duplicated URL
# 657   live-healthy-articles        1047       True  Duplicated URL
# 656   live-healthy-articles        1047       True  Duplicated URL
# 2306      program-sub-pages         476       True  Duplicated URL
# 2307      program-sub-pages         476       True  Duplicated URL

# %%
df_url_kept = df_duplicated_url.drop_duplicates(subset=["full_url"], keep="last")

display(df_url_kept)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                       content_name  \
# 1066  1445828             Recipe : Sliced Fish and Bee Hoon Soup
# 621   1444496           Weekend Activities: 5 Ideas for Families
# 1212  1445798                                Recipe : Mee Goreng
# 1369  1444751          Cooking with Chef Mel Dean... Sayur Lodeh
# 656   1446090    The A-Z Guide To A Healthy And Active Lifestyle
# 2307  1435183  Care team resources | Diabetes Hub_care-team-r...
#
#                                                 title  \
# 1066           Recipe : Sliced Fish and Bee Hoon Soup
# 621              Outdoor Activities for Your Children
# 1212                              Recipe : Mee Goreng
# 1369        Cooking with Chef Mel Dean... Sayur Lodeh
# 656   The A-Z Guide To A Healthy And Active Lifestyle
# 2307               Care team resources | Diabetes Hub
#
#                                                full_url  \
# 1066  https://www.healthhub.sg/live-healthy/fish-bee...
# 621   https://www.healthhub.sg/live-healthy/ideas-fo...
# 1212   https://www.healthhub.sg/live-healthy/mee-goreng
# 1369  https://www.healthhub.sg/live-healthy/sayur-lodeh
# 656   https://www.healthhub.sg/live-healthy/the-a-z-...
# 2307  https://www.healthhub.sg/programmes/diabetes-h...
#
#                                            content_body  \
# 1066  b'<div class="ExternalClassB39C037E02BC47C6A3C...
# 621   b'<div class="ExternalClass196D7C5AC7594C8E8BC...
# 1212  b'<div class="ExternalClass875BB3A3A2F84BE4A49...
# 1369  b'<div class="ExternalClassF0D563DE92F04D3C9F6...
# 656   b'<div class="ExternalClassBA1FDDD033444100B98...
# 2307  b'<div class="ExternalClassFDB7091A35194B5EBBA...
#
#                                  extracted_content_body  \
# 1066  Looking to bring some wholesome goodness home?...
# 621   The lack of insufficient outdoor activity amon...
# 1212  Looking to bring some wholesome goodness home?...
# 1369  Sayur Lodeh is everyone's favourite dish, espe...
# 656   Physical activity is key to staying healthy, b...
# 2307  3 BES TO BEAT DIABETES \n\nCare Team Resources...
#
#                      pr_name                 date_modified  \
# 1066  Health Promotion Board  2022-11-15T08:35:31.0000000Z
# 621   Health Promotion Board  2023-03-23T08:09:13.0000000Z
# 1212  Health Promotion Board  2022-11-15T08:35:25.0000000Z
# 1369  Health Promotion Board  2022-11-15T08:35:36.0000000Z
# 656   Health Promotion Board  2023-04-04T03:01:38.0000000Z
# 2307      Ministry of Health                          None
#
#            content_category  page_views  to_remove     remove_type
# 1066  live-healthy-articles         378       True  Duplicated URL
# 621   live-healthy-articles        1179       True  Duplicated URL
# 1212  live-healthy-articles         276       True  Duplicated URL
# 1369  live-healthy-articles         187       True  Duplicated URL
# 656   live-healthy-articles        1047       True  Duplicated URL
# 2307      program-sub-pages         476       True  Duplicated URL

# %%
list(df_duplicated_url["full_url"])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'https://www.healthhub.sg/live-healthy/fish-bee-hoon-soup',
#     'https://www.healthhub.sg/live-healthy/fish-bee-hoon-soup',
#     'https://www.healthhub.sg/live-healthy/ideas-for-an-active-weekend',
#     'https://www.healthhub.sg/live-healthy/ideas-for-an-active-weekend',
#     'https://www.healthhub.sg/live-healthy/mee-goreng',
#     'https://www.healthhub.sg/live-healthy/mee-goreng',
#     'https://www.healthhub.sg/live-healthy/sayur-lodeh',
#     'https://www.healthhub.sg/live-healthy/sayur-lodeh',
#     'https://www.healthhub.sg/live-healthy/the-a-z-guide-to-an-active-lifestyle',
#     'https://www.healthhub.sg/live-healthy/the-a-z-guide-to-an-active-lifestyle',
#     'https://www.healthhub.sg/programmes/diabetes-hub/care-team-resources/',
#     'https://www.healthhub.sg/programmes/diabetes-hub/care-team-resources/'
# ]

# %%
df_url_dropped = df_duplicated_url[~df_duplicated_url["id"].isin(list(df_url_kept["id"]))]

display(df_url_dropped)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id                                       content_name  \
# 1067  1445629                     Sliced Fish with Bee Hoon Soup
# 620   1446081                        Outdoor Activities for Kids
# 1215  1443608                                         Mee Goreng
# 1370  1445829                               Recipe : Sayur Lodeh
# 657   1444417      The A-Z Guide to Healthy Lifestyle Activities
# 2306  1435335  Diabetes Hub: Guide to Managing Diabetes_care-...
#
#                                               title  \
# 1067                 Sliced Fish with Bee Hoon Soup
# 620                     Outdoor Activities for Kids
# 1215                                     Mee Goreng
# 1370                           Recipe : Sayur Lodeh
# 657   The A-Z Guide to Healthy Lifestyle Activities
# 2306       Diabetes Hub: Guide to Managing Diabetes
#
#                                                full_url  \
# 1067  https://www.healthhub.sg/live-healthy/fish-bee...
# 620   https://www.healthhub.sg/live-healthy/ideas-fo...
# 1215   https://www.healthhub.sg/live-healthy/mee-goreng
# 1370  https://www.healthhub.sg/live-healthy/sayur-lodeh
# 657   https://www.healthhub.sg/live-healthy/the-a-z-...
# 2306  https://www.healthhub.sg/programmes/diabetes-h...
#
#                                            content_body  \
# 1067  b'<div class="ExternalClassF5C1DD3FA7E84963A88...
# 620   b'<div class="ExternalClass196D7C5AC7594C8E8BC...
# 1215  b'<div class="ExternalClass60865CF1F8FA4603ABA...
# 1370  b'<div class="ExternalClass8FB2510AE8C541EEADF...
# 657   b'<div class="ExternalClassBA1FDDD033444100B98...
# 2306  b'<div class="ExternalClass0F99B891157147D4A5D...
#
#                                  extracted_content_body  \
# 1067  Mouthwatering sliced fish with bee hoon soup\n...
# 620   The lack of outdoor activity among children co...
# 1215  By KK Womens and Childrens Hospital and Ms Hen...
# 1370  Looking to bring some wholesome goodness home?...
# 657   Physical activity is key to staying healthy, b...
# 2306  -  \n Home>\nCare Team Resources\n- Downloads\...
#
#                                  pr_name                 date_modified  \
# 1067              Health Promotion Board  2022-11-15T08:35:26.0000000Z
# 620               Health Promotion Board  2022-11-15T08:51:15.0000000Z
# 1215  KK Women's and Children's Hospital  2021-12-21T08:10:47.0000000Z
# 1370              Health Promotion Board  2022-11-15T08:35:29.0000000Z
# 657               Health Promotion Board  2022-11-15T08:41:41.0000000Z
# 2306                  Ministry of Health                          None
#
#            content_category  page_views  to_remove     remove_type
# 1067  live-healthy-articles         378       True  Duplicated URL
# 620   live-healthy-articles        1179       True  Duplicated URL
# 1215  live-healthy-articles         276       True  Duplicated URL
# 1370  live-healthy-articles         187       True  Duplicated URL
# 657   live-healthy-articles        1047       True  Duplicated URL
# 2306      program-sub-pages         476       True  Duplicated URL
