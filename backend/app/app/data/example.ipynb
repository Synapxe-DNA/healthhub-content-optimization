# %%
# %pip install dask
# %pip install fastparquet
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.3/915.3 kB 7.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.6 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import dask.dataframe as dd

# %%
df = dd.read_parquet('./merged_data.parquet', engine="fastparquet")
# Out:
# /Users/tjay/opt/anaconda3/envs/cont-opt/lib/python3.12/site-packages/dask/dataframe/io/parquet/core.py:1241: FutureWarning: The fastparquet engine is deprecated and will be removed in a future release. Please install pyarrow.
#   warnings.warn(

# %%
df.compute()
# Out:
#            id                                      content_name  \
# 0     1435040           Breast Screening Subsidies in Singapore
# 1     1435071                   Marriage and Parenthood Schemes
# 2     1434993                                          MediSave
# 3     1435031  Hospital Bills Financial Assistance in Singapore
# 4     1435043   Community Health Assist Scheme (CHAS) Singapore
# ...       ...                                               ...
# 2608  1440763         Heart Failure Transitional Care Programme
# 2609  1440791              Brain and Head Injury Support Groups
# 2610  1440768                      Ambulatory Nutrition Support
# 2611  1440766              LapBandits Support Group (Singapore)
# 2612  1440762              Cardiac Rehabilitation Support Group
#
#                                                  title  \
# 0              Breast Screening Subsidies in Singapore
# 1                      Marriage and Parenthood Schemes
# ...
